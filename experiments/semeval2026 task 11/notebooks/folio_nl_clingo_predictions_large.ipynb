# %%
'''
task: FOL classification based on NL + CLINGO text
model: FOLIO NL + CLINGO t5-large
dataset: SemEval-2026
evaluation: supervised fine-tuning
'''
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# load train, val and test splits
train = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SemEval2026/data/train.csv")
val = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SemEval2026/data/val.csv")
test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SemEval2026/data/test.csv")

# transform data to acceptable format for model training
train_df = pd.DataFrame(train)
val_df = pd.DataFrame(val)
test_df = pd.DataFrame(test)

train_df = train_df.applymap(str)
val_df = val_df.applymap(str)
test_df = test_df.applymap(str)
# Out:
# /tmp/ipython-input-1243017007.py:13: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   train_df = train_df.applymap(str)
# /tmp/ipython-input-1243017007.py:14: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   val_df = val_df.applymap(str)
# /tmp/ipython-input-1243017007.py:15: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   test_df = test_df.applymap(str)

# %%
# start preparing for QA pipeline
# !pip install datasets
! pip install -U accelerate
! pip install -U transformers
# !pip install transformers
# !pip install evaluate
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets) (3.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.36.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.13.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2026.1.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.12.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from accelerate) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate) (6.0.3)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (2.9.0+cu126)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (0.36.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate) (0.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (3.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (2025.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (1.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.21.0->accelerate) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.21.0->accelerate) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.21.0->accelerate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.21.0->accelerate) (2026.1.4)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.6)
# Collecting transformers
#   Downloading transformers-5.0.0-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.3)
# Collecting huggingface-hub<2.0,>=1.3.0 (from transformers)
#   Downloading huggingface_hub-1.3.5-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.28.1)
# Requirement already satisfied: shellingham in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.5.4)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (4.15.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim->transformers) (8.3.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.16.0)
# Downloading transformers-5.0.0-py3-none-any.whl (10.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 101.2 MB/s eta 0:00:00
# Downloading huggingface_hub-1.3.5-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.7/536.7 kB 44.3 MB/s eta 0:00:00
# Installing collected packages: huggingface-hub, transformers
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.36.0
#     Uninstalling huggingface-hub-0.36.0:
#       Successfully uninstalled huggingface-hub-0.36.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.57.6
#     Uninstalling transformers-4.57.6:
#       Successfully uninstalled transformers-4.57.6
# Successfully installed huggingface-hub-1.3.5 transformers-5.0.0
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.3)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (1.3.5)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.28.1)
# Requirement already satisfied: shellingham in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.5.4)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (4.15.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim->transformers) (8.3.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.16.0)
# Collecting evaluate
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (4.0.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.0.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.32.4)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.12/dist-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from evaluate) (3.6.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (1.3.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from evaluate) (25.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (3.20.3)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (18.1.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (3.13.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (0.28.1)
# Requirement already satisfied: shellingham in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (1.5.4)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (0.21.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2026.1.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2025.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.22.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.7.0->evaluate) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.7.0->evaluate) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.7.0->evaluate) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim->huggingface-hub>=0.7.0->evaluate) (8.3.1)
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 8.2 MB/s eta 0:00:00
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.6

# %%
import torch
import json
from tqdm import tqdm
import torch.nn as nn
from torch.optim import Adam
import nltk
import spacy
import string
import evaluate  # Bleu
from torch.utils.data import Dataset, DataLoader, RandomSampler
import pandas as pd
import numpy as np
import transformers
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from transformers import T5Tokenizer, T5Model, T5ForConditionalGeneration, T5TokenizerFast

import warnings
warnings.filterwarnings("ignore")

# %%
MODEL = T5ForConditionalGeneration.from_pretrained("/content/drive/MyDrive/Colab Notebooks/folio/models/flan-t5-large_logic_nl_clingo_model")
TOKENIZER = T5TokenizerFast.from_pretrained("/content/drive/MyDrive/Colab Notebooks/folio/models/flan-t5-large_logic_nl_clingo_tokenizer")
# Out:
# Loading weights:   0%|          | 0/558 [00:01<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning

# %%
# set model parameters
Q_LEN = 512   # Question Length
T_LEN = 512    # Target Length
BATCH_SIZE = 4
DEVICE = "cuda:0"
OPTIMIZER = Adam(MODEL.parameters(), lr=0.00001)

# %%
class QA_Dataset(Dataset):
    def __init__(self, tokenizer, dataframe, q_len, t_len):
        self.tokenizer = tokenizer
        self.q_len = q_len
        self.t_len = t_len
        self.data = dataframe
        self.subject = self.data["syllogism"]  + " " + self.data["clingo"]
        self.relation = self.data['validity']

    def __len__(self):
        return len(self.subject)

    def __getitem__(self, idx):
        subject = self.subject[idx]
        relation = self.relation[idx]

        subject_tokenized = self.tokenizer(subject, max_length=self.q_len, padding="max_length",
                                                    truncation=True, add_special_tokens=True)
        relation_tokenized = self.tokenizer(relation, max_length=self.t_len, padding="max_length",
                                          truncation=True, add_special_tokens=True)

        labels = torch.tensor(relation_tokenized["input_ids"], dtype=torch.long)
        labels[labels == 0] = -100

        return {
            "input_ids": torch.tensor(subject_tokenized["input_ids"], dtype=torch.long),
            "attention_mask": torch.tensor(subject_tokenized["attention_mask"], dtype=torch.long),
            "labels": labels,
            "decoder_attention_mask": torch.tensor(relation_tokenized["attention_mask"], dtype=torch.long)
        }

# %%
train_dataset = QA_Dataset(TOKENIZER, train_df, Q_LEN, T_LEN)
val_dataset = QA_Dataset(TOKENIZER, val_df, Q_LEN, T_LEN)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)

# %%
#torch.cuda.empty_cache()
MODEL.to('cuda')
# Out:
# T5ForConditionalGeneration(
#   (shared): Embedding(32128, 1024)
#   (encoder): T5Stack(
#     (embed_tokens): Embedding(32128, 1024)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=1024, bias=False)
#               (k): Linear(in_features=1024, out_features=1024, bias=False)
#               (v): Linear(in_features=1024, out_features=1024, bias=False)
#               (o): Linear(in_features=1024, out_features=1024, bias=False)
#               (relative_attention_bias): Embedding(32, 16)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=1024, out_features=2816, bias=False)
#               (wi_1): Linear(in_features=1024, out_features=2816, bias=False)
#               (wo): Linear(in_features=2816, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-23): 23 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=1024, bias=False)
#               (k): Linear(in_features=1024, out_features=1024, bias=False)
#               (v): Linear(in_features=1024, out_features=1024, bias=False)
#               (o): Linear(in_features=1024, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=1024, out_features=2816, bias=False)
#               (wi_1): Linear(in_features=1024, out_features=2816, bias=False)
#               (wo): Linear(in_features=2816, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): T5Stack(
#     (embed_tokens): Embedding(32128, 1024)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=1024, bias=False)
#               (k): Linear(in_features=1024, out_features=1024, bias=False)
#               (v): Linear(in_features=1024, out_features=1024, bias=False)
#               (o): Linear(in_features=1024, out_features=1024, bias=False)
#               (relative_attention_bias): Embedding(32, 16)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=1024, bias=False)
#               (k): Linear(in_features=1024, out_features=1024, bias=False)
#               (v): Linear(in_features=1024, out_features=1024, bias=False)
#               (o): Linear(in_features=1024, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=1024, out_features=2816, bias=False)
#               (wi_1): Linear(in_features=1024, out_features=2816, bias=False)
#               (wo): Linear(in_features=2816, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-23): 23 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=1024, bias=False)
#               (k): Linear(in_features=1024, out_features=1024, bias=False)
#               (v): Linear(in_features=1024, out_features=1024, bias=False)
#               (o): Linear(in_features=1024, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=1024, bias=False)
#               (k): Linear(in_features=1024, out_features=1024, bias=False)
#               (v): Linear(in_features=1024, out_features=1024, bias=False)
#               (o): Linear(in_features=1024, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=1024, out_features=2816, bias=False)
#               (wi_1): Linear(in_features=1024, out_features=2816, bias=False)
#               (wo): Linear(in_features=2816, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=1024, out_features=32128, bias=False)
# )

# %%
train_loss = 0
val_loss = 0
train_batch_count = 0
val_batch_count = 0

for epoch in range(5):
    MODEL.train()
    for batch in tqdm(train_loader, desc="Training batches"):
        input_ids = batch["input_ids"].to(DEVICE)
        attention_mask = batch["attention_mask"].to(DEVICE)
        labels = batch["labels"].to(DEVICE)
        decoder_attention_mask = batch["decoder_attention_mask"].to(DEVICE)

        outputs = MODEL(
                          input_ids=input_ids,
                          attention_mask=attention_mask,
                          labels=labels,
                          decoder_attention_mask=decoder_attention_mask
                        )

        OPTIMIZER.zero_grad()
        outputs.loss.backward()
        OPTIMIZER.step()
        train_loss += outputs.loss.item()
        train_batch_count += 1

    #Evaluation
    MODEL.eval()
    for batch in tqdm(val_loader, desc="Validation batches"):
        input_ids = batch["input_ids"].to(DEVICE)
        attention_mask = batch["attention_mask"].to(DEVICE)
        labels = batch["labels"].to(DEVICE)
        decoder_attention_mask = batch["decoder_attention_mask"].to(DEVICE)

        outputs = MODEL(
                          input_ids=input_ids,
                          attention_mask=attention_mask,
                          labels=labels,
                          decoder_attention_mask=decoder_attention_mask
                        )

        OPTIMIZER.zero_grad()
        outputs.loss.backward()
        OPTIMIZER.step()
        val_loss += outputs.loss.item()
        val_batch_count += 1

    print(f"{epoch+1}/{5} -> Train loss: {train_loss / train_batch_count}\tValidation loss: {val_loss/val_batch_count}")
# Out:
# Training batches: 100%|██████████| 141/141 [02:00<00:00,  1.17it/s]
# Validation batches: 100%|██████████| 94/94 [01:17<00:00,  1.22it/s]
# 1/5 -> Train loss: 2.8503672028264257	Validation loss: 1.0376910123419254
# Training batches: 100%|██████████| 141/141 [01:58<00:00,  1.19it/s]
# Validation batches: 100%|██████████| 94/94 [01:17<00:00,  1.22it/s]
# 2/5 -> Train loss: 2.5781302735315146	Validation loss: 0.9055295462938066
# Training batches: 100%|██████████| 141/141 [01:58<00:00,  1.19it/s]
# Validation batches: 100%|██████████| 94/94 [01:17<00:00,  1.22it/s]
# 3/5 -> Train loss: 2.3526715437571206	Validation loss: 0.812078779893564
# Training batches: 100%|██████████| 141/141 [01:58<00:00,  1.19it/s]
# Validation batches: 100%|██████████| 94/94 [01:17<00:00,  1.22it/s]
# 4/5 -> Train loss: 2.1539363713129194	Validation loss: 0.7398492149374587
# Training batches: 100%|██████████| 141/141 [01:58<00:00,  1.19it/s]
# Validation batches: 100%|██████████| 94/94 [01:17<00:00,  1.22it/s]
# 5/5 -> Train loss: 1.9896136113092409	Validation loss: 0.6837544207877301

# %%
MODEL.save_pretrained("/content/drive/MyDrive/Colab Notebooks/SemEval2026/models/flan-t5-large_folio_nl_clingo_model")
TOKENIZER.save_pretrained("/content/drive/MyDrive/Colab Notebooks/SemEval2026/models/flan-t5-large_folio_nl_clingo_tokenizer")
# Out:
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# ('/content/drive/MyDrive/Colab Notebooks/SemEval2026/models/flan-t5-large_folio_nl_clingo_tokenizer/tokenizer_config.json',
#  '/content/drive/MyDrive/Colab Notebooks/SemEval2026/models/flan-t5-large_folio_nl_clingo_tokenizer/tokenizer.json')

# %%
# evaluation metrics

import numpy as np
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report


def predict_answer(subject, ref_relation=None):
    inputs = TOKENIZER(subject, return_tensors="pt").to(MODEL.device)

    outputs = MODEL.generate(input_ids=inputs["input_ids"], max_new_tokens=10)

    predicted_relation = TOKENIZER.batch_decode(outputs.detach().cpu().numpy(), skip_special_tokens=True)[0]

    print("syllogism: \n", subject)
    print("true label: \n", ref_relation)
    print("predicted label: \n", predicted_relation)

    return predicted_relation

# %%
# test predictions
reference_labels = []
predicted_labels = []
for index, row in test_df.iterrows():
  premises = row["syllogism"] + " " + row["clingo"]
  label = row["validity"]

  predicted_label = predict_answer(premises, label)
  reference_labels.append(label)
  predicted_labels.append(predicted_label)

# calculate classification metrics
print("Accuracy:", accuracy_score(reference_labels, predicted_labels))
print("Precision:", precision_score(reference_labels, predicted_labels, average="macro"))
print("Recall:", recall_score(reference_labels, predicted_labels, average="macro"))
print("F1:", f1_score(reference_labels, predicted_labels, average="macro"))
print("Classification Report:", classification_report(reference_labels, predicted_labels))
# Out:
# syllogism:
#  All forms of bacteria are classified as communities. There are some organs that do not belong to the category of communities. Therefore, some organs are not types of bacteria. forall (formofbacteria(x) -: classifiedascommunitie(x))
#   (organthatdonot(x) , categoryofcommunitie(x))
#  forall (someorgan(x) -: nottypeofbacteria(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Every cat is a mammal. The set of dolphins contains no cats. Every single dolphin is a mammal. forall (cat(x) -: mammal(x))
#  forall (setofdolphincontainnocat(x))
#  forall (singledolphin(x) -: mammal(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  Anything that is a tomato is also a planet. There is no planet that is a food. It is thus the case that no food is a tomato. forall (anythingthat(x) -: tomatoalsoaplanet(x))
#  forall (there(x) -: noplanetthatafood(x))
#  forall (it(x) -: thing(x))
#  forall (casethatnofood(x) -: tomato(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Every single eagle is a bird. Nothing that is a bat is a bird. From this, it can be concluded that no bat is an eagle. forall (singleeagle(x) -: bird(x))
#  forall (nothingthat(x) -: batabird(x))
#  forall (fromthiitcanbeconcludedthatnobat(x) -: eagle(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Any creature that is a bird is an animal. A portion of animals are kept as pets. Some pets are not birds. forall (creaturethat(x) -: birdananimal(x))
#   (animal(x) , keptaspet(x))
#   (pet(x) , notbird(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  Anything which is a cloud is made of rock. Some weather phenomena are known to be clouds. Consequently, some weather phenomena are made of rock. forall (anythingwhich(x) -: cloudmadeofrock(x))
#   (weatherphenomena(x) , knowntobecloud(x))
#  forall (someweatherphenomena(x) -: madeofrock(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  It is true that some things that are trees do not have roots. Everything that is a tree is a plant. It logically follows that there are some plants that do not have roots.  (thingthat(x) , treedonothaverooteverythingthatatreeaplantitlogicallyfollowthattheresomeplantthatdonothaveroot(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Anything that is a table is not a tree. There are tables, and some of them can be identified as furniture. Based on this, a portion of furniture pieces must not be trees. forall (anythingthat(x) -: tablenotatree(x))
#  forall (there(x) -: tableandsomeofthemcanbeidentifiedasfurniture(x))
#   (basedonth(x) , notaportionoffurniturepiecemustnotbetree(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Every single dog is a mammal. All mammals are birds. Consequently, every single bird is a dog. forall (singledog(x) -: mammal(x))
#  forall (mammal(x) -: bird(x))
#  forall (everysinglebird(x) -: dog(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  Anything that is a human is a primate. Every single whale is a mammal. Not a single whale is a human. forall (anythingthat(x) -: humanaprimate(x))
#  forall (singlewhale(x) -: mammal(x))
#  forall (whale(x) -: nothuman(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  The category of moons and the category of celestial bodies do not overlap. All celestial bodies are planets. A subset of planets are moons. forall (categoryofmoonandthecategoryofcelestialbodiedonotoverlap(x))
#  forall (celestialbodie(x) -: planet(x))
#   (planet(x) , moon(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  Every single person is a human. Anything that is a human is a husband. Consequently, it follows that all husbands are people. forall (singleperson(x) -: human(x))
#  forall (anythingthat(x) -: humanahusband(x))
#  forall (itfollowthatallhusband(x) -: people(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  Teapots are never classified as utensils. Some soldiers are not considered utensils. Consequently, some soldiers are indeed teapots. forall (teapot(x) -: neverclassifiedasutensil(x))
#   (soldier(x) , notconsideredutensil(x))
#  forall (somesoldier(x) -: indeedteapot(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  Every single star is a planet. No planets are suns. It is therefore a sound deduction that some suns are not stars. forall (singlestar(x) -: planet(x))
#  forall (planet(x) -: notsun(x))
#  forall (it(x) -: thing(x))
#  forall (sounddeductionthatsomesun(x) -: notstar(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  All fish are birds. It is true that no bird is aquatic. It follows that no aquatic thing is a fish. forall (fish(x) -: bird(x))
#  forall (bird(x) -: notaquaticitfollowthatnoaquaticthingafish(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  A group of numbers are planets. Every planet is a celestial body. As a result, a portion of celestial bodies are numbers. forall (groupofnumber(x) -: planet(x))
#  forall (planet(x) -: celestialbody(x))
#  forall (aportionofcelestialbodie(x) -: number(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Every single mammal is an animal. There are no fish which are mammals. Consequently, there are no fish which are animals. forall (singlemammal(x) -: animal(x))
#   (nofishwhich(x) , mammal(x))
#  forall (there(x) -: nofishwhichanimal(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  None of the items that are carrots are bell peppers. There are vegetables that are bell peppers. It is correct to infer that some vegetables are not carrots. forall (of(x) -: notitemthatcarrotbellpepper(x))
#   (vegetablethat(x) , bellpepper(x))
#  forall (it(x) -: correcttoinferthatsomevegetablenotcarrot(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  All things that are made of wood can catch on fire. There are some chairs that are wooden objects. It follows, then, that some chairs can be set on fire. forall (thingthat(x) -: madeofwoodcancatchonfire(x))
#   (chairthat(x) , woodenobject(x))
#  forall (thenthatsomechaircanbesetonfire(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  All things that are cars are vehicles. There is no vehicle that is a bicycle. Therefore, there is no bicycle that is a car. forall (thingthat(x) -: carvehicle(x))
#  forall (there(x) -: novehiclethatabicycle(x))
#  forall (there(x) -: nobicyclethatacar(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Every single four-sided-shape is a rectangle. All four-sided-shapes are squares. It follows from this that some squares are not rectangles. forall (singlefoursidedshape(x) -: rectangle(x))
#  forall (foursidedshape(x) -: square(x))
#  forall (fromthithatsomesquare(x) -: notrectangle(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  It's the case that all furniture is made of wood. Anything that is a chair is also made of wood. Some chairs fail to be furniture. forall (itsthecasethatallfurniture(x) -: madeofwood(x))
#  forall (anythingthat(x) -: chairalsomadeofwood(x))
#  forall (chairfailtobefurniture(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  Nothing that is an emotion is a feeling. Certain emotions are classified as sadness. It must be the case that some sadness is not a feeling. forall (nothingthat(x) -: emotionafeeling(x))
#   (emotion(x) , classifiedassadnes(x))
#  forall (itmustbethecasethatsomesadnes(x) -: notafeeling(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  There are some mammals that can fly. It is the case that no bird can fly. Therefore, all birds are mammals. forall (there(x) -: mammalthatcanfly(x))
#  forall (it(x) -: casethatnobirdcanfly(x))
#  forall (allbird(x) -: mammal(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  A group of animals are vertebrates. It is a fact that some animals are not insects. It is necessarily true that no insects are vertebrates. forall (groupofanimal(x) -: vertebrate(x))
#   (animal(x) , notinsectitnecessarilytruethatnoinsectvertebrate(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  Some animals are human. There are politicians who are human. This means that some politicians are animals.  (animal(x) , human(x))
#   (politicianwho(x) , human(x))
#  forall (thimeanthatsomepolitician(x) -: animal(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  Every single thing that is a bird is an animal. Anything that is a pigeon is, without exception, a bird. This means that all pigeons are animals. forall (singlethingthat(x) -: birdananimal(x))
#  forall (anythingthat(x) -: pigeonwithoutexceptionabird(x))
#  forall (thimeanthatallpigeon(x) -: animal(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  It is impossible for a spider to be a bird. A portion of spiders are considered arachnids. It is necessarily the case that some arachnids are not birds. forall (it(x) -: impossibleforaspidertobeabird(x))
#   (spider(x) , consideredarachnid(x))
#  forall (it(x) -: necessarilythecasethatsomearachnidnotbird(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Every airplane is a cloud. It is true that every bird is a cloud. This means that every single bird is an airplane. forall (airplane(x) -: cloud(x))
#  forall (bird(x) -: cloudthimeanthateverysinglebirdanairplane(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  Anything that is a car is not an airplane. There are no vehicles that are cars. Consequently, every vehicle is an airplane. forall (anythingthat(x) -: carnotanairplane(x))
#   (novehiclethat(x) , car(x))
#  forall (everyvehicle(x) -: airplane(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  Rockets are in no way considered vehicles. Every single rocket functions as a scavenger. A portion of scavengers exists that are not vehicles. forall (rocket(x) -: innowayconsideredvehicle(x))
#  forall (singlerocketfunctionasascavenger(x))
#   (scavengerexistthat(x) , notvehicle(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  There are some capitals that are polluted. All capitals are, by definition, cities. One must conclude that some cities are polluted.  (capitalthat(x) , polluted(x))
#  forall (capital(x) -: bydefinitioncitie(x))
#  forall (onemustconcludethatsomecitie(x) -: polluted(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  It is a fact that every single dog is a mammal. Likewise, it is true that all poodles are mammals. Therefore, it has been asserted that every poodle is a dog. forall (singledog(x) -: mammallikewiseittruethatallpoodlemammalthereforeithasbeenassertedthateverypoodleadog(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  It is the case that no creature that is a mammal is a fish. There exists at least one creature that is a mammal and also a dolphin. This proves that at least one dolphin is not a fish. forall (it(x) -: casethatnocreaturethatamammalafish(x))
#  forall (thereexistatleastonecreaturethat(x) -: mammalandalsoadolphin(x))
#  forall (thiprovethatatleastonedolphin(x) -: notafish(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Every single dog is an animal. Everything that is an animal is a mammal. It must therefore be true that every mammal is an animal. forall (singledog(x) -: animal(x))
#  forall (everythingthat(x) -: animalamammal(x))
#  forall (itmust(x))
#  forall (betruethateverymammal(x) -: animal(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  Arrangements cannot be formations. A subset of vases exists that are not formations. Therefore, all things classified as arrangements are vases. forall (arrangementcannotbeformation(x))
#   (vaseexistthat(x) , notformation(x))
#  forall (allthingclassifiedasarrangement(x) -: vase(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  Anything which is an ocean is a desert. There are no Atlantic Oceans that are not oceans. There exists at least one Atlantic Ocean that is a desert. forall (anythingwhich(x) -: oceanadesert(x))
#   (noatlanticoceanthat(x) , notocean(x))
#  forall (thereexistatleastoneatlanticoceanthat(x) -: desert(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  There are no squares which are round. There are no circles which are squares. It follows, then, that some circles are square.  (nosquarewhich(x) , round(x))
#   (nocirclewhich(x) , square(x))
#  forall (thenthatsomecircle(x) -: square(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  It is not the case that every human is a male. Every single human is a creature with ten legs. From this, it follows that some creatures with ten legs are males. forall (it(x) -: notthecasethateveryhumanamale(x))
#  forall (singlehuman(x) -: creaturewithtenleg(x))
#  forall (fromth(x) -: thing(x))
#   (creaturewithtenleg(x) , male(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  There are no chairs that can be considered musical instruments. Certain chairs exist that are also antiques. The conclusion that a portion of antiques are not musical instruments is inescapable.  (nochairthat(x) , musicalinstrument(x))
#   (chairexistthat(x) , alsoantique(x))
#  forall (conclusionthataportionofantique(x) -: notmusicalinstrumentinescapable(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Any golden retriever is a mammal. It is the case that some golden retrievers are dogs. This means that a few dogs are mammals. forall (goldenretriever(x) -: mammal(x))
#  forall (it(x) -: casethatsomegoldenretrieverdog(x))
#  forall (thimeanthatafewdog(x) -: mammal(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  It is a fact that every tulip is a flower. It is also true that all roses are flowers. Therefore, it is concluded that a few flowers are roses. forall (tulip(x) -: floweritalsotruethatallroseflowerthereforeitconcludedthatafewflowerrose(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  No giant balls of gas are stars. Suns are, without exception, giant balls of gas. No star can be considered a sun. forall (giant(x) -: notballofgasstar(x))
#  forall (sun(x) -: withoutexceptiongiantballofgas(x))
#  forall (star(x) -: notconsideredasun(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Every poodle is a dog. No cat is a poodle. Therefore, no cat is a dog. forall (poodle(x) -: dog(x))
#  forall (cat(x) -: notpoodle(x))
#  forall (nocat(x) -: dog(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  There is no table that is a desk. No desks are chairs whatsoever. Therefore, we can conclude that no chair is a table. forall (there(x) -: notablethatadesk(x))
#  forall (desk(x) -: notchairwhatsoever(x))
#  forall (wecanconcludethatnochair(x) -: table(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  Some aquatic animals can be considered fish. Not a single human is an aquatic animal. As a result, no human is a fish.  (aquaticanimal(x) , fish(x))
#  forall (human(x) -: notaquaticanimal(x))
#  forall (nohuman(x) -: fish(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  Each and every kitchen is a room. Each and every kitchen is a place for cooking. This implies that some places for cooking are rooms. forall (kitchen(x) -: room(x))
#  forall (kitchen(x) -: placeforcooking(x))
#  forall (thiimpliethatsomeplaceforcooking(x) -: room(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  There are no objects that are furniture. Each and every table is an object. It follows that no table can be an item of furniture.  (noobjectthat(x) , furniture(x))
#  forall (table(x) -: object(x))
#  forall (table(x) -: notitemoffurniture(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Every single country has a capital city. The entity known as France is a country. There is at least some part of France that has a capital city. forall (singlecountryhasacapitalcity(x))
#  forall (entityknownasfrance(x) -: country(x))
#  forall (there(x) -: atleastsomepartoffrancethathasacapitalcity(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  It is true that all fish live in water. No birds are fish. Therefore, no bird lives in water. forall (fishliveinwaternobird(x) -: fishthereforenobirdliveinwater(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  It is not true that any dog is an animal. Nothing that is a mammal is a dog. This leads to the conclusion that no mammal is an animal. forall (it(x) -: nottruethatanydogananimal(x))
#  forall (nothingthat(x) -: mammaladog(x))
#  forall (thileadtotheconclusionthatnomammal(x) -: animal(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  It is a fact that all birds can fly. There are some animals which are birds. Therefore, every single animal can fly. forall (birdcanflythere(x) -: animalwhichbirdthereforeeverysingleanimalcanfly(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  There are some researchers who are also academics. A person who is an academic is also part of the university faculty. Therefore, some university faculty are researchers.  (researcherwho(x) , alsoacademic(x))
#  forall (personwho(x) -: academicalsopartoftheuniversityfaculty(x))
#  forall (someuniversityfaculty(x) -: researcher(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  A car is never an airplane. It is also the case that no boat is an airplane. Consequently, all boats are cars. forall (car(x) -: neveranairplane(x))
#  forall (it(x) -: alsothecasethatnoboatanairplane(x))
#  forall (allboat(x) -: car(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  Every single feline is a mammal. Anything that is a cat is a feline. At least one cat is a mammal. forall (singlefeline(x) -: mammal(x))
#  forall (anythingthat(x) -: catafeline(x))
#  forall (atleastonecat(x) -: mammal(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Every single creature that lives in water is a high-speed projectile. All groups involved in manufacturing are aquatic creatures. It logically follows that all entities that manufacture things are high-speed projectiles. forall (singlecreaturethatliveinwater(x) -: highspeedprojectile(x))
#  forall (groupinvolvedinmanufacturing(x) -: aquaticcreature(x))
#  forall (entitiethatmanufacturething(x) -: highspeedprojectile(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  There are some animals that are not mammals. Everything that is a dog is a mammal. Thus, every dog is an animal.  (animalthat(x) , notmammal(x))
#  forall (everythingthat(x) -: dogamammal(x))
#  forall (everydog(x) -: animal(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  There are certain leaders who are politicians. All of those who are politicians are also human beings. Hence, a group of human beings are leaders.  (leaderwho(x) , politician(x))
#  forall (ofthosewho(x) -: politicianalsohumanbeing(x))
#  forall (henceagroupofhumanbeing(x) -: leader(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Every single thing that is a dog is a mammal. Every mammal is an animal. From this, it follows that some animals are indeed dogs. forall (singlethingthat(x) -: dogamammal(x))
#  forall (mammal(x) -: animal(x))
#  forall (fromth(x) -: thing(x))
#   (animal(x) , indeeddog(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  There exist vegetables that grow. Every single vegetable is a plant. It follows that not a single plant is a vegetable. forall (thereex(x) -: tvegetablethatgrow(x))
#  forall (singlevegetable(x) -: plant(x))
#  forall (plant(x) -: notvegetable(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  Every doctor is a professional. The set of children does not contain professionals. At least one child is not a doctor. forall (doctor(x) -: professional(x))
#  forall (setofchildrendoenotcontainprofessional(x))
#  forall (atleastonechild(x) -: notadoctor(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Every object that is a car has an engine. Some motorized vehicles are cars. Therefore, all motorized vehicles have engines. forall (objectthat(x) -: carhasanengine(x))
#   (motorizedvehicle(x) , car(x))
#  forall (allmotorizedvehicle(x) -: engine(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  Everything that is a chair is furniture. Every single table is furniture. It follows from this that some tables are chairs. forall (everythingthat(x) -: chairfurniture(x))
#  forall (singletable(x) -: furniture(x))
#  forall (fromthithatsometable(x) -: chair(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  Any celestial body which is a planet is a cube. A portion of celestial bodies are planets. Consequently, some celestial bodies are cubes. forall (celestialbodywhich(x) -: planetacube(x))
#   (celestialbodie(x) , planet(x))
#  forall (somecelestialbodie(x) -: cube(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  There are no dogs who are cats. A few dogs are pets. This implies that some pets are cats.  (nodogwho(x) , cat(x))
#  forall (fewdog(x) -: pet(x))
#  forall (thiimpliethatsomepet(x) -: cat(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  Every sparrow is a type of animal. Some sparrows can be described as birds. Therefore, a certain number of birds are animals. forall (sparrow(x) -: typeofanimal(x))
#  forall (sparrowcanbedescribedasbird(x))
#  forall (acertainnumberofbird(x) -: animal(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  The category of fish is a subset of the category of animals. All animals that are dogs are also animals. Nothing that is a dog is a fish. forall (categoryoffish(x) -: subsetofthecategoryofanimal(x))
#  forall (animalthat(x) -: dogalsoanimal(x))
#  forall (nothingthat(x) -: dogafish(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  Everything that is a human is also a primate. Everything that is a human is also a bipedal animal. Consequently, some bipedal animals are primates. forall (everythingthat(x) -: humanalsoaprimate(x))
#  forall (everythingthat(x) -: humanalsoabipedalanimal(x))
#  forall (somebipedalanimal(x) -: primate(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Some things that are potatoes are not living things. Every single thing that is a potato is a human. A logical consequence of this is that some humans are not living things.  (thingthat(x) , potatoenotlivingthing(x))
#  forall (singlethingthat(x) -: potatoahuman(x))
#  forall (logicalconsequenceofthi(x) -: thatsomehumannotlivingthing(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Not a single mammal is an object that can think. The entire group of objects that can think is a subset of people. It is a logical consequence that some people are not mammals. forall (mammal(x) -: notobjectthatcanthink(x))
#  forall (entiregroupofobjectthatcanthink(x) -: subsetofpeople(x))
#  forall (it(x) -: logicalconsequencethatsomepeoplenotmammal(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Every single writing tool is a pencil. No pen is a pencil. This means no pen is a writing tool. forall (singlewritingtool(x) -: pencil(x))
#  forall (pen(x) -: notpencil(x))
#  forall (thimeannopen(x) -: writingtool(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Some fruits are bicycles. Every bicycle is a vehicle. Therefore, some vehicles are fruits.  (fruit(x) , bicycle(x))
#  forall (bicycle(x) -: vehicle(x))
#  forall (somevehicle(x) -: fruit(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Anything that is a bicycle is a vehicle. It is known that no trucks are bicycles. This leads to the conclusion that no truck is a vehicle. forall (anythingthat(x) -: bicycleavehicle(x))
#  forall (it(x) -: knownthatnotruckbicycle(x))
#  forall (thileadtotheconclusionthatnotruck(x) -: vehicle(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  Everything that is a vehicle is a magical item. A portion of vehicles are cars. It necessarily follows that some cars are magical items. forall (everythingthat(x) -: vehicleamagicalitem(x))
#   (vehicle(x) , car(x))
#  forall (itnecessarilyfollowthatsomecar(x) -: magicalitem(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Anything that is a animal is an idea. There are no ideas that are dogs. This necessarily suggests that some dogs are not animals. forall (anythingthat(x) -: animalanidea(x))
#   (noideathat(x) , dog(x))
#  forall (thinecessarilysuggestthatsomedog(x) -: notanimal(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Anything that is a mammal is warm-blooded. Every single dog is a mammal. At least one dog is warm-blooded. forall (anythingthat(x) -: mammalwarmblooded(x))
#  forall (singledog(x) -: mammal(x))
#  forall (atleastonedog(x) -: warmblooded(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Anything that is an elephant is a mammal. Every whale is also a mammal. From this, it is concluded that no whale is an elephant. forall (anythingthat(x) -: elephantamammal(x))
#  forall (whale(x) -: alsoamammal(x))
#  forall (fromthiit(x) -: concludedthatnowhaleanelephant(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  All of the things that are robins are birds. There are no birds whatsoever that are fish. It logically follows that no fish are robins. forall (ofthethingthat(x) -: robinbird(x))
#   (nobirdwhatsoeverthat(x) , fish(x))
#  forall (fish(x) -: notrobin(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Every bird is a fish. There are no fish which are sparrows. This necessarily suggests that some sparrows are not birds. forall (bird(x) -: fish(x))
#   (nofishwhich(x) , sparrow(x))
#  forall (thinecessarilysuggestthatsomesparrow(x) -: notbird(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Anything that can be called a musician is also an artist. A portion of artists are painters. A certain portion of painters are not musicians. forall (anythingthatcanbecalledamusician(x) -: alsoanartist(x))
#   (artist(x) , painter(x))
#  forall (certainportionofpainter(x) -: notmusician(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  It is the case that no cars are bicycles. Every single thing that is a Ferrari is a car. Therefore, some Ferraris are not bicycles. forall (it(x) -: casethatnocarbicycle(x))
#  forall (singlethingthat(x) -: ferrariacar(x))
#  forall (someferrari(x) -: notbicycle(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  It is not the case that animals are non-birds. Of the items that are hummingbirds, some are non-birds. It must be the case that every single hummingbird is not an animal. forall (it(x) -: notthecasethatanimalnonbird(x))
#  forall (oftheitemthat(x) -: hummingbirdsomenonbird(x))
#  forall (itmustbethecasethateverysinglehummingbird(x) -: notananimal(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  There are some celestial bodies that are stars. There are some planets which are celestial bodies. Planets are in no way stars.  (celestialbodiethat(x) , star(x))
#   (planetwhich(x) , celestialbodie(x))
#  forall (planet(x) -: innowaystar(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  Drums are completely separate from trumpets. A trumpet is, without exception, a musical instrument. Some musical instruments cannot be classified as drums. forall (drum(x) -: completelyseparatefromtrumpet(x))
#  forall (trumpet(x) -: withoutexceptionamusicalinstrument(x))
#  forall (musicalinstrumentcannotbeclassifiedasdrum(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  The group of professionals is a subset of the group of people. Everything that is a doctor is a professional. Therefore, there are some people who are not doctors. forall (groupofprofessional(x) -: subsetofthegroupofpeople(x))
#  forall (everythingthat(x) -: doctoraprofessional(x))
#  forall (there(x) -: peoplewhonotdoctor(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  There are no animals that are also plants. At least one tree is a plant. At least one tree is not an animal.  (noanimalthat(x) , alsoplant(x))
#  forall (atleastonetree(x) -: plant(x))
#  forall (atleastonetree(x) -: notananimal(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  There are no fiction books that are not non-fiction. Anything that is a novel is a fiction book. Therefore, some novels are non-fiction.  (nofictionbookthat(x) , notnonfiction(x))
#  forall (anythingthat(x) -: novelafictionbook(x))
#  forall (somenovel(x) -: nonfiction(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  There exist no machines that are also humans. Anything that can be called a student is, without exception, a human. No students are machines.  (nomachinethat(x) , alsohuman(x))
#  forall (anythingthatcanbecalledastudent(x) -: withoutexceptionahuman(x))
#  forall (student(x) -: notmachine(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  It is true that anything that is an apple is an edible thing. Every apple is a fruit. It follows that some fruits are edible things. forall (anythingthat(x) -: appleanediblethingeveryappleafruititfollowthatsomefruitediblething(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  There are some creatures that are animals and not vertebrates. All cats are also vertebrates. This leads to the conclusion that there are some cats which are animals.  (creaturethat(x) , animalandnotvertebrate(x))
#  forall (cat(x) -: alsovertebrate(x))
#  forall (thileadtotheconclusionthatthere(x) -: catwhichanimal(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  There are some animals that are sparrows. All things that are sparrows are birds. Consequently, every single thing that is a bird is an animal.  (animalthat(x) , sparrow(x))
#  forall (thingthat(x) -: sparrowbird(x))
#  forall (everysinglethingthat(x) -: birdananimal(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  Every single integer is divisible by two. All integers are even numbers. It follows from this that some even numbers are not divisible by two. forall (singleinteger(x) -: divisiblebytwo(x))
#  forall (integer(x) -: evennumber(x))
#  forall (fromthithatsomeevennumber(x) -: notdivisiblebytwo(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  Nothing that is a pet animal is also a feline. Some cats happen to be pet animals. This leads to the conclusion that a certain number of cats are not felines. forall (nothingthat(x) -: petanimalalsoafeline(x))
#  forall (cathappentobepetanimal(x))
#  forall (thileadtotheconclusionthatacertainnumberofcat(x) -: notfeline(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Any and all reptiles are lizards. There are reptiles that are mammals. It must follow that all mammals are lizards. forall (andallreptile(x) -: lizard(x))
#   (reptilethat(x) , mammal(x))
#  forall (itmustfollowthatallmammal(x) -: lizard(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  Dogs are never cats. Some domestic animals are indeed felines. Therefore, a portion of domestic animals is not dogs. forall (dog(x) -: nevercat(x))
#   (domesticanimal(x) , indeedfeline(x))
#  forall (aportionofdomesticanimal(x) -: notdog(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  There are no birds which are cats. There are no dogs that are birds. It follows, then, that some dogs are cats.  (nobirdwhich(x) , cat(x))
#   (nodogthat(x) , bird(x))
#  forall (thenthatsomedog(x) -: cat(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  There are no dogs that are reptiles. Everything that is a fish is a dog. Thus, every fish is a reptile.  (nodogthat(x) , reptile(x))
#  forall (everythingthat(x) -: fishadog(x))
#  forall (everyfish(x) -: reptile(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  Every item that is a mammal is an animal. Some lions are mammals. Therefore, all lions can be said to be animals. forall (itemthat(x) -: mammalananimal(x))
#   (lion(x) , mammal(x))
#  forall (alllioncanbesaidtobeanimal(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  Every single cat is an animal. Anything that can be called a dog is, without exception, an animal. Every dog is a cat. forall (singlecat(x) -: animal(x))
#  forall (anythingthatcanbecalledadog(x) -: withoutexceptionananimal(x))
#  forall (dog(x) -: cat(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  There exist cats that are also mammals. A subset of dogs can be classified as mammals. It follows that at least some dogs are not cats.  (catthat(x) , alsomammal(x))
#  forall (subsetofdogcanbeclassifiedasmammal(x))
#  forall (atleastsomedog(x) -: notcat(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  Humans are in no way animals. Anything that is a human is a mammal. There are some mammals which are not animals. forall (human(x) -: innowayanimal(x))
#  forall (anythingthat(x) -: humanamammal(x))
#   (mammalwhich(x) , notanimal(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  It is the case that every fish lives in a tree. There exist some sea basses which do not live in trees. It necessarily follows that some sea basses are not fish. forall (it(x) -: casethateveryfishliveinatree(x))
#   (thereex(x) , nottsomeseabassewhichdonotliveintree(x))
#  forall (itnecessarilyfollowthatsomeseabasse(x) -: notfish(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  There are some dogs that are cats. There are no cats that are reptiles. As a result, some reptiles are dogs.  (dogthat(x) , cat(x))
#   (nocatthat(x) , reptile(x))
#  forall (somereptile(x) -: dog(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  There are some individuals who find pleasure in reading who are librarians. Every single person who is a librarian is a student. It is the case that some of the people who are students are people who enjoy reading.  (individualwhofindpleasureinreadingwho(x) , librarian(x))
#  forall (singlepersonwho(x) -: librarianastudent(x))
#  forall (it(x) -: casethatsomeofthepeoplewhostudentpeoplewhoenjoyreading(x))
#
# true label:
#  True
# predicted label:
#  True
# Accuracy: 0.5
# Precision: 0.25
# Recall: 0.5
# F1: 0.3333333333333333
# Classification Report:               precision    recall  f1-score   support
#
#        False       0.00      0.00      0.00        52
#         True       0.50      1.00      0.67        52
#
#     accuracy                           0.50       104
#    macro avg       0.25      0.50      0.33       104
# weighted avg       0.25      0.50      0.33       104
