# %%
'''
task: FOL classification based on NL + CLINGO text
model: FOLIO NL + CLINGO t5-large
dataset: SemEval-2026
evaluation: supervised fine-tuning
'''
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# load train, val and test splits
train = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SemEval2026/data/train.csv")
val = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SemEval2026/data/val.csv")
test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SemEval2026/data/test.csv")

# transform data to acceptable format for model training
train_df = pd.DataFrame(train)
val_df = pd.DataFrame(val)
test_df = pd.DataFrame(test)

train_df = train_df.applymap(str)
val_df = val_df.applymap(str)
test_df = test_df.applymap(str)
# Out:
# /tmp/ipython-input-1243017007.py:13: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   train_df = train_df.applymap(str)
# /tmp/ipython-input-1243017007.py:14: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   val_df = val_df.applymap(str)
# /tmp/ipython-input-1243017007.py:15: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   test_df = test_df.applymap(str)

# %%
# start preparing for QA pipeline
# !pip install datasets
! pip install -U accelerate
! pip install -U transformers
# !pip install transformers
# !pip install evaluate
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets) (3.20.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.36.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.13.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2026.1.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.12.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from accelerate) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate) (6.0.3)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (2.9.0+cu126)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (0.36.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate) (0.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (3.20.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (2025.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (1.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.21.0->accelerate) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.21.0->accelerate) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.21.0->accelerate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.21.0->accelerate) (2026.1.4)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.3)
# Collecting transformers
#   Downloading transformers-4.57.6-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2026.1.4)
# Downloading transformers-4.57.6-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 145.9 MB/s eta 0:00:00
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.57.3
#     Uninstalling transformers-4.57.3:
#       Successfully uninstalled transformers-4.57.3
# Successfully installed transformers-4.57.6
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2026.1.4)
# Collecting evaluate
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (4.0.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.0.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.32.4)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.12/dist-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from evaluate) (3.6.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.36.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from evaluate) (25.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (3.20.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (18.1.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (3.13.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2026.1.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2025.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 8.0 MB/s eta 0:00:00
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.6

# %%
import torch
import json
from tqdm import tqdm
import torch.nn as nn
from torch.optim import Adam
import nltk
import spacy
import string
import evaluate  # Bleu
from torch.utils.data import Dataset, DataLoader, RandomSampler
import pandas as pd
import numpy as np
import transformers
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from transformers import T5Tokenizer, T5Model, T5ForConditionalGeneration, T5TokenizerFast

import warnings
warnings.filterwarnings("ignore")

# %%
MODEL = T5ForConditionalGeneration.from_pretrained("/content/drive/MyDrive/Colab Notebooks/folio/models/flan-t5-large_logic_nl_clingo_model")
TOKENIZER = T5TokenizerFast.from_pretrained("/content/drive/MyDrive/Colab Notebooks/folio/models/flan-t5-large_logic_nl_clingo_tokenizer")

# %%
# set model parameters
Q_LEN = 512   # Question Length
T_LEN = 512    # Target Length
BATCH_SIZE = 4
DEVICE = "cuda:0"
OPTIMIZER = Adam(MODEL.parameters(), lr=0.00001)

# %%
class QA_Dataset(Dataset):
    def __init__(self, tokenizer, dataframe, q_len, t_len):
        self.tokenizer = tokenizer
        self.q_len = q_len
        self.t_len = t_len
        self.data = dataframe
        self.subject = self.data["syllogism"]  + " " + self.data["clingo"]
        self.relation = self.data['validity']

    def __len__(self):
        return len(self.subject)

    def __getitem__(self, idx):
        subject = self.subject[idx]
        relation = self.relation[idx]

        subject_tokenized = self.tokenizer(subject, max_length=self.q_len, padding="max_length",
                                                    truncation=True, add_special_tokens=True)
        relation_tokenized = self.tokenizer(relation, max_length=self.t_len, padding="max_length",
                                          truncation=True, add_special_tokens=True)

        labels = torch.tensor(relation_tokenized["input_ids"], dtype=torch.long)
        labels[labels == 0] = -100

        return {
            "input_ids": torch.tensor(subject_tokenized["input_ids"], dtype=torch.long),
            "attention_mask": torch.tensor(subject_tokenized["attention_mask"], dtype=torch.long),
            "labels": labels,
            "decoder_attention_mask": torch.tensor(relation_tokenized["attention_mask"], dtype=torch.long)
        }

# %%
train_dataset = QA_Dataset(TOKENIZER, train_df, Q_LEN, T_LEN)
val_dataset = QA_Dataset(TOKENIZER, val_df, Q_LEN, T_LEN)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)

# %%
#torch.cuda.empty_cache()
MODEL.to('cuda')
# Out:
# T5ForConditionalGeneration(
#   (shared): Embedding(32128, 1024)
#   (encoder): T5Stack(
#     (embed_tokens): Embedding(32128, 1024)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=1024, bias=False)
#               (k): Linear(in_features=1024, out_features=1024, bias=False)
#               (v): Linear(in_features=1024, out_features=1024, bias=False)
#               (o): Linear(in_features=1024, out_features=1024, bias=False)
#               (relative_attention_bias): Embedding(32, 16)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=1024, out_features=2816, bias=False)
#               (wi_1): Linear(in_features=1024, out_features=2816, bias=False)
#               (wo): Linear(in_features=2816, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-23): 23 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=1024, bias=False)
#               (k): Linear(in_features=1024, out_features=1024, bias=False)
#               (v): Linear(in_features=1024, out_features=1024, bias=False)
#               (o): Linear(in_features=1024, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=1024, out_features=2816, bias=False)
#               (wi_1): Linear(in_features=1024, out_features=2816, bias=False)
#               (wo): Linear(in_features=2816, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): T5Stack(
#     (embed_tokens): Embedding(32128, 1024)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=1024, bias=False)
#               (k): Linear(in_features=1024, out_features=1024, bias=False)
#               (v): Linear(in_features=1024, out_features=1024, bias=False)
#               (o): Linear(in_features=1024, out_features=1024, bias=False)
#               (relative_attention_bias): Embedding(32, 16)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=1024, bias=False)
#               (k): Linear(in_features=1024, out_features=1024, bias=False)
#               (v): Linear(in_features=1024, out_features=1024, bias=False)
#               (o): Linear(in_features=1024, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=1024, out_features=2816, bias=False)
#               (wi_1): Linear(in_features=1024, out_features=2816, bias=False)
#               (wo): Linear(in_features=2816, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-23): 23 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=1024, bias=False)
#               (k): Linear(in_features=1024, out_features=1024, bias=False)
#               (v): Linear(in_features=1024, out_features=1024, bias=False)
#               (o): Linear(in_features=1024, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=1024, bias=False)
#               (k): Linear(in_features=1024, out_features=1024, bias=False)
#               (v): Linear(in_features=1024, out_features=1024, bias=False)
#               (o): Linear(in_features=1024, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=1024, out_features=2816, bias=False)
#               (wi_1): Linear(in_features=1024, out_features=2816, bias=False)
#               (wo): Linear(in_features=2816, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=1024, out_features=32128, bias=False)
# )

# %%
train_loss = 0
val_loss = 0
train_batch_count = 0
val_batch_count = 0

for epoch in range(5):
    MODEL.train()
    for batch in tqdm(train_loader, desc="Training batches"):
        input_ids = batch["input_ids"].to(DEVICE)
        attention_mask = batch["attention_mask"].to(DEVICE)
        labels = batch["labels"].to(DEVICE)
        decoder_attention_mask = batch["decoder_attention_mask"].to(DEVICE)

        outputs = MODEL(
                          input_ids=input_ids,
                          attention_mask=attention_mask,
                          labels=labels,
                          decoder_attention_mask=decoder_attention_mask
                        )

        OPTIMIZER.zero_grad()
        outputs.loss.backward()
        OPTIMIZER.step()
        train_loss += outputs.loss.item()
        train_batch_count += 1

    #Evaluation
    MODEL.eval()
    for batch in tqdm(val_loader, desc="Validation batches"):
        input_ids = batch["input_ids"].to(DEVICE)
        attention_mask = batch["attention_mask"].to(DEVICE)
        labels = batch["labels"].to(DEVICE)
        decoder_attention_mask = batch["decoder_attention_mask"].to(DEVICE)

        outputs = MODEL(
                          input_ids=input_ids,
                          attention_mask=attention_mask,
                          labels=labels,
                          decoder_attention_mask=decoder_attention_mask
                        )

        OPTIMIZER.zero_grad()
        outputs.loss.backward()
        OPTIMIZER.step()
        val_loss += outputs.loss.item()
        val_batch_count += 1

    print(f"{epoch+1}/{5} -> Train loss: {train_loss / train_batch_count}\tValidation loss: {val_loss/val_batch_count}")
# Out:
# Training batches: 100%|██████████| 141/141 [02:00<00:00,  1.17it/s]
# Validation batches: 100%|██████████| 94/94 [01:17<00:00,  1.22it/s]
# 1/5 -> Train loss: 0.24905157892416555	Validation loss: 0.1836637959399439
# Training batches: 100%|██████████| 141/141 [01:58<00:00,  1.19it/s]
# Validation batches: 100%|██████████| 94/94 [01:16<00:00,  1.22it/s]
# 2/5 -> Train loss: 0.20991010315293537	Validation loss: 0.12947655898243923
# Training batches: 100%|██████████| 141/141 [01:58<00:00,  1.19it/s]
# Validation batches: 100%|██████████| 94/94 [01:16<00:00,  1.22it/s]
# 3/5 -> Train loss: 0.17971539661292665	Validation loss: 0.09289375608496418
# Training batches: 100%|██████████| 141/141 [01:58<00:00,  1.19it/s]
# Validation batches: 100%|██████████| 94/94 [01:16<00:00,  1.22it/s]
# 4/5 -> Train loss: 0.15527117134788956	Validation loss: 0.07145265859191491
# Training batches: 100%|██████████| 141/141 [01:58<00:00,  1.19it/s]
# Validation batches: 100%|██████████| 94/94 [01:17<00:00,  1.22it/s]
# 5/5 -> Train loss: 0.1367446569363415	Validation loss: 0.05829682696811629

# %%
MODEL.save_pretrained("/content/drive/MyDrive/Colab Notebooks/SemEval2026/models/flan-t5-large_folio_nl_clingo_model")
TOKENIZER.save_pretrained("/content/drive/MyDrive/Colab Notebooks/SemEval2026/models/flan-t5-large_folio_nl_clingo_tokenizer")
# Out:
# ('/content/drive/MyDrive/Colab Notebooks/SemEval2026/models/flan-t5-large_folio_nl_fol_tokenizer/tokenizer_config.json',
#  '/content/drive/MyDrive/Colab Notebooks/SemEval2026/models/flan-t5-large_folio_nl_fol_tokenizer/special_tokens_map.json',
#  '/content/drive/MyDrive/Colab Notebooks/SemEval2026/models/flan-t5-large_folio_nl_fol_tokenizer/spiece.model',
#  '/content/drive/MyDrive/Colab Notebooks/SemEval2026/models/flan-t5-large_folio_nl_fol_tokenizer/added_tokens.json',
#  '/content/drive/MyDrive/Colab Notebooks/SemEval2026/models/flan-t5-large_folio_nl_fol_tokenizer/tokenizer.json')

# %%
# evaluation metrics

import numpy as np
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report


def predict_answer(subject, ref_relation=None):
    inputs = TOKENIZER(subject, return_tensors="pt").to(MODEL.device)

    outputs = MODEL.generate(input_ids=inputs["input_ids"], max_new_tokens=10)

    predicted_relation = TOKENIZER.batch_decode(outputs.detach().cpu().numpy(), skip_special_tokens=True)[0]

    print("syllogism: \n", subject)
    print("true label: \n", ref_relation)
    print("predicted label: \n", predicted_relation)

    return predicted_relation

# %%
# test predictions
reference_labels = []
predicted_labels = []
for index, row in test_df.iterrows():
  premises = row["syllogism"] + " " + row["clingo"]
  label = row["validity"]

  predicted_label = predict_answer(premises, label)
  reference_labels.append(label)
  predicted_labels.append(predicted_label)

# calculate classification metrics
print("Accuracy:", accuracy_score(reference_labels, predicted_labels))
print("Precision:", precision_score(reference_labels, predicted_labels, average="macro"))
print("Recall:", recall_score(reference_labels, predicted_labels, average="macro"))
print("F1:", f1_score(reference_labels, predicted_labels, average="macro"))
print("Classification Report:", classification_report(reference_labels, predicted_labels))
# Out:
# syllogism:
#  All forms of bacteria are classified as communities. There are some organs that do not belong to the category of communities. Therefore, some organs are not types of bacteria. ∀x (FormOfBacteria(x) → ClassifiedAsCommunitie(x))
#  ∃x (OrganThatDoNot(x) ∧ CategoryOfCommunitie(x))
#  ∀x (SomeOrgan(x) → NotTypeOfBacteria(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Every cat is a mammal. The set of dolphins contains no cats. Every single dolphin is a mammal. ∀x (Cat(x) → Mammal(x))
#  ∀x (SetOfDolphinContainNoCat(x))
#  ∀x (SingleDolphin(x) → Mammal(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Anything that is a tomato is also a planet. There is no planet that is a food. It is thus the case that no food is a tomato. ∀x (AnythingThat(x) → TomatoAlsoAPlanet(x))
#  ∀x (There(x) → NoPlanetThatAFood(x))
#  ∀x (It(x) → Thing(x))
#  ∀x (CaseThatNoFood(x) → Tomato(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Every single eagle is a bird. Nothing that is a bat is a bird. From this, it can be concluded that no bat is an eagle. ∀x (SingleEagle(x) → Bird(x))
#  ∀x (NothingThat(x) → BatABird(x))
#  ∀x (FromThiItCanBeConcludedThatNoBat(x) → Eagle(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Any creature that is a bird is an animal. A portion of animals are kept as pets. Some pets are not birds. ∀x (CreatureThat(x) → BirdAnAnimal(x))
#  ∃x (Animal(x) ∧ KeptAsPet(x))
#  ∃x (Pet(x) ∧ NotBird(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Anything which is a cloud is made of rock. Some weather phenomena are known to be clouds. Consequently, some weather phenomena are made of rock. ∀x (AnythingWhich(x) → CloudMadeOfRock(x))
#  ∃x (WeatherPhenomena(x) ∧ KnownToBeCloud(x))
#  ∀x (SomeWeatherPhenomena(x) → MadeOfRock(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  It is true that some things that are trees do not have roots. Everything that is a tree is a plant. It logically follows that there are some plants that do not have roots. ∃x (ThingThat(x) ∧ TreeDoNotHaveRootEverythingThatATreeAPlantItLogicallyFollowThatThereSomePlantThatDoNotHaveRoot(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Anything that is a table is not a tree. There are tables, and some of them can be identified as furniture. Based on this, a portion of furniture pieces must not be trees. ∀x (AnythingThat(x) → TableNotATree(x))
#  ∀x (There(x) → TableAndSomeOfThemCanBeIdentifiedAsFurniture(x))
#  ∃x (BasedOnTh(x) ∧ ¬APortionOfFurniturePieceMustNotBeTree(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Every single dog is a mammal. All mammals are birds. Consequently, every single bird is a dog. ∀x (SingleDog(x) → Mammal(x))
#  ∀x (Mammal(x) → Bird(x))
#  ∀x (EverySingleBird(x) → Dog(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Anything that is a human is a primate. Every single whale is a mammal. Not a single whale is a human. ∀x (AnythingThat(x) → HumanAPrimate(x))
#  ∀x (SingleWhale(x) → Mammal(x))
#  ∀x (Whale(x) → ¬Human(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  The category of moons and the category of celestial bodies do not overlap. All celestial bodies are planets. A subset of planets are moons. ∀x (CategoryOfMoonAndTheCategoryOfCelestialBodieDoNotOverlap(x))
#  ∀x (CelestialBodie(x) → Planet(x))
#  ∃x (Planet(x) ∧ Moon(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Every single person is a human. Anything that is a human is a husband. Consequently, it follows that all husbands are people. ∀x (SinglePerson(x) → Human(x))
#  ∀x (AnythingThat(x) → HumanAHusband(x))
#  ∀x (ItFollowThatAllHusband(x) → People(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Teapots are never classified as utensils. Some soldiers are not considered utensils. Consequently, some soldiers are indeed teapots. ∀x (Teapot(x) → NeverClassifiedAsUtensil(x))
#  ∃x (Soldier(x) ∧ NotConsideredUtensil(x))
#  ∀x (SomeSoldier(x) → IndeedTeapot(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Every single star is a planet. No planets are suns. It is therefore a sound deduction that some suns are not stars. ∀x (SingleStar(x) → Planet(x))
#  ∀x (Planet(x) → ¬Sun(x))
#  ∀x (It(x) → Thing(x))
#  ∀x (SoundDeductionThatSomeSun(x) → NotStar(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  All fish are birds. It is true that no bird is aquatic. It follows that no aquatic thing is a fish. ∀x (Fish(x) → Bird(x))
#  ∀x (Bird(x) → ¬AquaticItFollowThatNoAquaticThingAFish(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  A group of numbers are planets. Every planet is a celestial body. As a result, a portion of celestial bodies are numbers. ∀x (GroupOfNumber(x) → Planet(x))
#  ∀x (Planet(x) → CelestialBody(x))
#  ∀x (APortionOfCelestialBodie(x) → Number(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Every single mammal is an animal. There are no fish which are mammals. Consequently, there are no fish which are animals. ∀x (SingleMammal(x) → Animal(x))
#  ∃x (NoFishWhich(x) ∧ Mammal(x))
#  ∀x (There(x) → NoFishWhichAnimal(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  None of the items that are carrots are bell peppers. There are vegetables that are bell peppers. It is correct to infer that some vegetables are not carrots. ∀x (Of(x) → ¬ItemThatCarrotBellPepper(x))
#  ∃x (VegetableThat(x) ∧ BellPepper(x))
#  ∀x (It(x) → CorrectToInferThatSomeVegetableNotCarrot(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  All things that are made of wood can catch on fire. There are some chairs that are wooden objects. It follows, then, that some chairs can be set on fire. ∀x (ThingThat(x) → MadeOfWoodCanCatchOnFire(x))
#  ∃x (ChairThat(x) ∧ WoodenObject(x))
#  ∀x (ThenThatSomeChairCanBeSetOnFire(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  All things that are cars are vehicles. There is no vehicle that is a bicycle. Therefore, there is no bicycle that is a car. ∀x (ThingThat(x) → CarVehicle(x))
#  ∀x (There(x) → NoVehicleThatABicycle(x))
#  ∀x (There(x) → NoBicycleThatACar(x))
#
# true label:
#  True
# predicted label:
#  False
# syllogism:
#  Every single four-sided-shape is a rectangle. All four-sided-shapes are squares. It follows from this that some squares are not rectangles. ∀x (SingleFoursidedshape(x) → Rectangle(x))
#  ∀x (Foursidedshape(x) → Square(x))
#  ∀x (FromThiThatSomeSquare(x) → NotRectangle(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  It's the case that all furniture is made of wood. Anything that is a chair is also made of wood. Some chairs fail to be furniture. ∀x (ItsTheCaseThatAllFurniture(x) → MadeOfWood(x))
#  ∀x (AnythingThat(x) → ChairAlsoMadeOfWood(x))
#  ∀x (ChairFailToBeFurniture(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Nothing that is an emotion is a feeling. Certain emotions are classified as sadness. It must be the case that some sadness is not a feeling. ∀x (NothingThat(x) → EmotionAFeeling(x))
#  ∃x (Emotion(x) ∧ ClassifiedAsSadnes(x))
#  ∀x (ItMustBeTheCaseThatSomeSadnes(x) → NotAFeeling(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  There are some mammals that can fly. It is the case that no bird can fly. Therefore, all birds are mammals. ∀x (There(x) → MammalThatCanFly(x))
#  ∀x (It(x) → CaseThatNoBirdCanFly(x))
#  ∀x (AllBird(x) → Mammal(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  A group of animals are vertebrates. It is a fact that some animals are not insects. It is necessarily true that no insects are vertebrates. ∀x (GroupOfAnimal(x) → Vertebrate(x))
#  ∃x (Animal(x) ∧ NotInsectItNecessarilyTrueThatNoInsectVertebrate(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Some animals are human. There are politicians who are human. This means that some politicians are animals. ∃x (Animal(x) ∧ Human(x))
#  ∃x (PoliticianWho(x) ∧ Human(x))
#  ∀x (ThiMeanThatSomePolitician(x) → Animal(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Every single thing that is a bird is an animal. Anything that is a pigeon is, without exception, a bird. This means that all pigeons are animals. ∀x (SingleThingThat(x) → BirdAnAnimal(x))
#  ∀x (AnythingThat(x) → PigeonWithoutExceptionABird(x))
#  ∀x (ThiMeanThatAllPigeon(x) → Animal(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  It is impossible for a spider to be a bird. A portion of spiders are considered arachnids. It is necessarily the case that some arachnids are not birds. ∀x (It(x) → ImpossibleForASpiderToBeABird(x))
#  ∃x (Spider(x) ∧ ConsideredArachnid(x))
#  ∀x (It(x) → NecessarilyTheCaseThatSomeArachnidNotBird(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Every airplane is a cloud. It is true that every bird is a cloud. This means that every single bird is an airplane. ∀x (Airplane(x) → Cloud(x))
#  ∀x (Bird(x) → CloudThiMeanThatEverySingleBirdAnAirplane(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Anything that is a car is not an airplane. There are no vehicles that are cars. Consequently, every vehicle is an airplane. ∀x (AnythingThat(x) → CarNotAnAirplane(x))
#  ∃x (NoVehicleThat(x) ∧ Car(x))
#  ∀x (EveryVehicle(x) → Airplane(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Rockets are in no way considered vehicles. Every single rocket functions as a scavenger. A portion of scavengers exists that are not vehicles. ∀x (Rocket(x) → InNoWayConsideredVehicle(x))
#  ∀x (SingleRocketFunctionAsAScavenger(x))
#  ∃x (ScavengerExistThat(x) ∧ NotVehicle(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  There are some capitals that are polluted. All capitals are, by definition, cities. One must conclude that some cities are polluted. ∃x (CapitalThat(x) ∧ Polluted(x))
#  ∀x (Capital(x) → ByDefinitionCitie(x))
#  ∀x (OneMustConcludeThatSomeCitie(x) → Polluted(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  It is a fact that every single dog is a mammal. Likewise, it is true that all poodles are mammals. Therefore, it has been asserted that every poodle is a dog. ∀x (SingleDog(x) → MammalLikewiseItTrueThatAllPoodleMammalThereforeItHasBeenAssertedThatEveryPoodleADog(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  It is the case that no creature that is a mammal is a fish. There exists at least one creature that is a mammal and also a dolphin. This proves that at least one dolphin is not a fish. ∀x (It(x) → CaseThatNoCreatureThatAMammalAFish(x))
#  ∀x (ThereExistAtLeastOneCreatureThat(x) → MammalAndAlsoADolphin(x))
#  ∀x (ThiProveThatAtLeastOneDolphin(x) → NotAFish(x))
#
# true label:
#  True
# predicted label:
#  False
# syllogism:
#  Every single dog is an animal. Everything that is an animal is a mammal. It must therefore be true that every mammal is an animal. ∀x (SingleDog(x) → Animal(x))
#  ∀x (EverythingThat(x) → AnimalAMammal(x))
#  ∀x (ItMust(x))
#  ∀x (BeTrueThatEveryMammal(x) → Animal(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Arrangements cannot be formations. A subset of vases exists that are not formations. Therefore, all things classified as arrangements are vases. ∀x (ArrangementCannotBeFormation(x))
#  ∃x (VaseExistThat(x) ∧ NotFormation(x))
#  ∀x (AllThingClassifiedAsArrangement(x) → Vase(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Anything which is an ocean is a desert. There are no Atlantic Oceans that are not oceans. There exists at least one Atlantic Ocean that is a desert. ∀x (AnythingWhich(x) → OceanADesert(x))
#  ∃x (NoAtlanticOceanThat(x) ∧ NotOcean(x))
#  ∀x (ThereExistAtLeastOneAtlanticOceanThat(x) → Desert(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  There are no squares which are round. There are no circles which are squares. It follows, then, that some circles are square. ∃x (NoSquareWhich(x) ∧ Round(x))
#  ∃x (NoCircleWhich(x) ∧ Square(x))
#  ∀x (ThenThatSomeCircle(x) → Square(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  It is not the case that every human is a male. Every single human is a creature with ten legs. From this, it follows that some creatures with ten legs are males. ∀x (It(x) → NotTheCaseThatEveryHumanAMale(x))
#  ∀x (SingleHuman(x) → CreatureWithTenLeg(x))
#  ∀x (FromTh(x) → Thing(x))
#  ∃x (CreatureWithTenLeg(x) ∧ Male(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  There are no chairs that can be considered musical instruments. Certain chairs exist that are also antiques. The conclusion that a portion of antiques are not musical instruments is inescapable. ∃x (NoChairThat(x) ∧ MusicalInstrument(x))
#  ∃x (ChairExistThat(x) ∧ AlsoAntique(x))
#  ∀x (ConclusionThatAPortionOfAntique(x) → NotMusicalInstrumentInescapable(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Any golden retriever is a mammal. It is the case that some golden retrievers are dogs. This means that a few dogs are mammals. ∀x (GoldenRetriever(x) → Mammal(x))
#  ∀x (It(x) → CaseThatSomeGoldenRetrieverDog(x))
#  ∀x (ThiMeanThatAFewDog(x) → Mammal(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  It is a fact that every tulip is a flower. It is also true that all roses are flowers. Therefore, it is concluded that a few flowers are roses. ∀x (Tulip(x) → FlowerItAlsoTrueThatAllRoseFlowerThereforeItConcludedThatAFewFlowerRose(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  No giant balls of gas are stars. Suns are, without exception, giant balls of gas. No star can be considered a sun. ∀x (Giant(x) → ¬BallOfGasStar(x))
#  ∀x (Sun(x) → WithoutExceptionGiantBallOfGas(x))
#  ∀x (Star(x) → ¬ConsideredASun(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Every poodle is a dog. No cat is a poodle. Therefore, no cat is a dog. ∀x (Poodle(x) → Dog(x))
#  ∀x (Cat(x) → ¬Poodle(x))
#  ∀x (NoCat(x) → Dog(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  There is no table that is a desk. No desks are chairs whatsoever. Therefore, we can conclude that no chair is a table. ∀x (There(x) → NoTableThatADesk(x))
#  ∀x (Desk(x) → ¬ChairWhatsoever(x))
#  ∀x (WeCanConcludeThatNoChair(x) → Table(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Some aquatic animals can be considered fish. Not a single human is an aquatic animal. As a result, no human is a fish. ∃x (AquaticAnimal(x) ∧ Fish(x))
#  ∀x (Human(x) → ¬AquaticAnimal(x))
#  ∀x (NoHuman(x) → Fish(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  Each and every kitchen is a room. Each and every kitchen is a place for cooking. This implies that some places for cooking are rooms. ∀x (Kitchen(x) → Room(x))
#  ∀x (Kitchen(x) → PlaceForCooking(x))
#  ∀x (ThiImplieThatSomePlaceForCooking(x) → Room(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  There are no objects that are furniture. Each and every table is an object. It follows that no table can be an item of furniture. ∃x (NoObjectThat(x) ∧ Furniture(x))
#  ∀x (Table(x) → Object(x))
#  ∀x (Table(x) → ¬ItemOfFurniture(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Every single country has a capital city. The entity known as France is a country. There is at least some part of France that has a capital city. ∀x (SingleCountryHasACapitalCity(x))
#  ∀x (EntityKnownAsFrance(x) → Country(x))
#  ∀x (There(x) → AtLeastSomePartOfFranceThatHasACapitalCity(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  It is true that all fish live in water. No birds are fish. Therefore, no bird lives in water. ∀x (FishLiveInWaterNoBird(x) → FishThereforeNoBirdLiveInWater(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  It is not true that any dog is an animal. Nothing that is a mammal is a dog. This leads to the conclusion that no mammal is an animal. ∀x (It(x) → NotTrueThatAnyDogAnAnimal(x))
#  ∀x (NothingThat(x) → MammalADog(x))
#  ∀x (ThiLeadToTheConclusionThatNoMammal(x) → Animal(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  It is a fact that all birds can fly. There are some animals which are birds. Therefore, every single animal can fly. ∀x (BirdCanFlyThere(x) → AnimalWhichBirdThereforeEverySingleAnimalCanFly(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  There are some researchers who are also academics. A person who is an academic is also part of the university faculty. Therefore, some university faculty are researchers. ∃x (ResearcherWho(x) ∧ AlsoAcademic(x))
#  ∀x (PersonWho(x) → AcademicAlsoPartOfTheUniversityFaculty(x))
#  ∀x (SomeUniversityFaculty(x) → Researcher(x))
#
# true label:
#  True
# predicted label:
#  False
# syllogism:
#  A car is never an airplane. It is also the case that no boat is an airplane. Consequently, all boats are cars. ∀x (Car(x) → NeverAnAirplane(x))
#  ∀x (It(x) → AlsoTheCaseThatNoBoatAnAirplane(x))
#  ∀x (AllBoat(x) → Car(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Every single feline is a mammal. Anything that is a cat is a feline. At least one cat is a mammal. ∀x (SingleFeline(x) → Mammal(x))
#  ∀x (AnythingThat(x) → CatAFeline(x))
#  ∀x (AtLeastOneCat(x) → Mammal(x))
#
# true label:
#  True
# predicted label:
#  False
# syllogism:
#  Every single creature that lives in water is a high-speed projectile. All groups involved in manufacturing are aquatic creatures. It logically follows that all entities that manufacture things are high-speed projectiles. ∀x (SingleCreatureThatLiveInWater(x) → HighspeedProjectile(x))
#  ∀x (GroupInvolvedInManufacturing(x) → AquaticCreature(x))
#  ∀x (EntitieThatManufactureThing(x) → HighspeedProjectile(x))
#
# true label:
#  True
# predicted label:
#  False
# syllogism:
#  There are some animals that are not mammals. Everything that is a dog is a mammal. Thus, every dog is an animal. ∃x (AnimalThat(x) ∧ NotMammal(x))
#  ∀x (EverythingThat(x) → DogAMammal(x))
#  ∀x (EveryDog(x) → Animal(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  There are certain leaders who are politicians. All of those who are politicians are also human beings. Hence, a group of human beings are leaders. ∃x (LeaderWho(x) ∧ Politician(x))
#  ∀x (OfThoseWho(x) → PoliticianAlsoHumanBeing(x))
#  ∀x (HenceAGroupOfHumanBeing(x) → Leader(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Every single thing that is a dog is a mammal. Every mammal is an animal. From this, it follows that some animals are indeed dogs. ∀x (SingleThingThat(x) → DogAMammal(x))
#  ∀x (Mammal(x) → Animal(x))
#  ∀x (FromTh(x) → Thing(x))
#  ∃x (Animal(x) ∧ IndeedDog(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  There exist vegetables that grow. Every single vegetable is a plant. It follows that not a single plant is a vegetable. ∀x (ThereEx(x) → TVegetableThatGrow(x))
#  ∀x (SingleVegetable(x) → Plant(x))
#  ∀x (Plant(x) → ¬Vegetable(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Every doctor is a professional. The set of children does not contain professionals. At least one child is not a doctor. ∀x (Doctor(x) → Professional(x))
#  ∀x (SetOfChildrenDoeNotContainProfessional(x))
#  ∀x (AtLeastOneChild(x) → NotADoctor(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Every object that is a car has an engine. Some motorized vehicles are cars. Therefore, all motorized vehicles have engines. ∀x (ObjectThat(x) → CarHasAnEngine(x))
#  ∃x (MotorizedVehicle(x) ∧ Car(x))
#  ∀x (AllMotorizedVehicle(x) → Engine(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Everything that is a chair is furniture. Every single table is furniture. It follows from this that some tables are chairs. ∀x (EverythingThat(x) → ChairFurniture(x))
#  ∀x (SingleTable(x) → Furniture(x))
#  ∀x (FromThiThatSomeTable(x) → Chair(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Any celestial body which is a planet is a cube. A portion of celestial bodies are planets. Consequently, some celestial bodies are cubes. ∀x (CelestialBodyWhich(x) → PlanetACube(x))
#  ∃x (CelestialBodie(x) ∧ Planet(x))
#  ∀x (SomeCelestialBodie(x) → Cube(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  There are no dogs who are cats. A few dogs are pets. This implies that some pets are cats. ∃x (NoDogWho(x) ∧ Cat(x))
#  ∀x (FewDog(x) → Pet(x))
#  ∀x (ThiImplieThatSomePet(x) → Cat(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Every sparrow is a type of animal. Some sparrows can be described as birds. Therefore, a certain number of birds are animals. ∀x (Sparrow(x) → TypeOfAnimal(x))
#  ∀x (SparrowCanBeDescribedAsBird(x))
#  ∀x (ACertainNumberOfBird(x) → Animal(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  The category of fish is a subset of the category of animals. All animals that are dogs are also animals. Nothing that is a dog is a fish. ∀x (CategoryOfFish(x) → SubsetOfTheCategoryOfAnimal(x))
#  ∀x (AnimalThat(x) → DogAlsoAnimal(x))
#  ∀x (NothingThat(x) → DogAFish(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Everything that is a human is also a primate. Everything that is a human is also a bipedal animal. Consequently, some bipedal animals are primates. ∀x (EverythingThat(x) → HumanAlsoAPrimate(x))
#  ∀x (EverythingThat(x) → HumanAlsoABipedalAnimal(x))
#  ∀x (SomeBipedalAnimal(x) → Primate(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Some things that are potatoes are not living things. Every single thing that is a potato is a human. A logical consequence of this is that some humans are not living things. ∃x (ThingThat(x) ∧ PotatoeNotLivingThing(x))
#  ∀x (SingleThingThat(x) → PotatoAHuman(x))
#  ∀x (LogicalConsequenceOfThi(x) → ThatSomeHumanNotLivingThing(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Not a single mammal is an object that can think. The entire group of objects that can think is a subset of people. It is a logical consequence that some people are not mammals. ∀x (Mammal(x) → ¬ObjectThatCanThink(x))
#  ∀x (EntireGroupOfObjectThatCanThink(x) → SubsetOfPeople(x))
#  ∀x (It(x) → LogicalConsequenceThatSomePeopleNotMammal(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Every single writing tool is a pencil. No pen is a pencil. This means no pen is a writing tool. ∀x (SingleWritingTool(x) → Pencil(x))
#  ∀x (Pen(x) → ¬Pencil(x))
#  ∀x (ThiMeanNoPen(x) → WritingTool(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Some fruits are bicycles. Every bicycle is a vehicle. Therefore, some vehicles are fruits. ∃x (Fruit(x) ∧ Bicycle(x))
#  ∀x (Bicycle(x) → Vehicle(x))
#  ∀x (SomeVehicle(x) → Fruit(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Anything that is a bicycle is a vehicle. It is known that no trucks are bicycles. This leads to the conclusion that no truck is a vehicle. ∀x (AnythingThat(x) → BicycleAVehicle(x))
#  ∀x (It(x) → KnownThatNoTruckBicycle(x))
#  ∀x (ThiLeadToTheConclusionThatNoTruck(x) → Vehicle(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Everything that is a vehicle is a magical item. A portion of vehicles are cars. It necessarily follows that some cars are magical items. ∀x (EverythingThat(x) → VehicleAMagicalItem(x))
#  ∃x (Vehicle(x) ∧ Car(x))
#  ∀x (ItNecessarilyFollowThatSomeCar(x) → MagicalItem(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Anything that is a animal is an idea. There are no ideas that are dogs. This necessarily suggests that some dogs are not animals. ∀x (AnythingThat(x) → AnimalAnIdea(x))
#  ∃x (NoIdeaThat(x) ∧ Dog(x))
#  ∀x (ThiNecessarilySuggestThatSomeDog(x) → NotAnimal(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Anything that is a mammal is warm-blooded. Every single dog is a mammal. At least one dog is warm-blooded. ∀x (AnythingThat(x) → MammalWarmblooded(x))
#  ∀x (SingleDog(x) → Mammal(x))
#  ∀x (AtLeastOneDog(x) → Warmblooded(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Anything that is an elephant is a mammal. Every whale is also a mammal. From this, it is concluded that no whale is an elephant. ∀x (AnythingThat(x) → ElephantAMammal(x))
#  ∀x (Whale(x) → AlsoAMammal(x))
#  ∀x (FromThiIt(x) → ConcludedThatNoWhaleAnElephant(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  All of the things that are robins are birds. There are no birds whatsoever that are fish. It logically follows that no fish are robins. ∀x (OfTheThingThat(x) → RobinBird(x))
#  ∃x (NoBirdWhatsoeverThat(x) ∧ Fish(x))
#  ∀x (Fish(x) → ¬Robin(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Every bird is a fish. There are no fish which are sparrows. This necessarily suggests that some sparrows are not birds. ∀x (Bird(x) → Fish(x))
#  ∃x (NoFishWhich(x) ∧ Sparrow(x))
#  ∀x (ThiNecessarilySuggestThatSomeSparrow(x) → NotBird(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Anything that can be called a musician is also an artist. A portion of artists are painters. A certain portion of painters are not musicians. ∀x (AnythingThatCanBeCalledAMusician(x) → AlsoAnArtist(x))
#  ∃x (Artist(x) ∧ Painter(x))
#  ∀x (CertainPortionOfPainter(x) → NotMusician(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  It is the case that no cars are bicycles. Every single thing that is a Ferrari is a car. Therefore, some Ferraris are not bicycles. ∀x (It(x) → CaseThatNoCarBicycle(x))
#  ∀x (SingleThingThat(x) → FerrariACar(x))
#  ∀x (SomeFerrari(x) → NotBicycle(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  It is not the case that animals are non-birds. Of the items that are hummingbirds, some are non-birds. It must be the case that every single hummingbird is not an animal. ∀x (It(x) → NotTheCaseThatAnimalNonbird(x))
#  ∀x (OfTheItemThat(x) → HummingbirdSomeNonbird(x))
#  ∀x (ItMustBeTheCaseThatEverySingleHummingbird(x) → NotAnAnimal(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  There are some celestial bodies that are stars. There are some planets which are celestial bodies. Planets are in no way stars. ∃x (CelestialBodieThat(x) ∧ Star(x))
#  ∃x (PlanetWhich(x) ∧ CelestialBodie(x))
#  ∀x (Planet(x) → InNoWayStar(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Drums are completely separate from trumpets. A trumpet is, without exception, a musical instrument. Some musical instruments cannot be classified as drums. ∀x (Drum(x) → CompletelySeparateFromTrumpet(x))
#  ∀x (Trumpet(x) → WithoutExceptionAMusicalInstrument(x))
#  ∀x (MusicalInstrumentCannotBeClassifiedAsDrum(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  The group of professionals is a subset of the group of people. Everything that is a doctor is a professional. Therefore, there are some people who are not doctors. ∀x (GroupOfProfessional(x) → SubsetOfTheGroupOfPeople(x))
#  ∀x (EverythingThat(x) → DoctorAProfessional(x))
#  ∀x (There(x) → PeopleWhoNotDoctor(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  There are no animals that are also plants. At least one tree is a plant. At least one tree is not an animal. ∃x (NoAnimalThat(x) ∧ AlsoPlant(x))
#  ∀x (AtLeastOneTree(x) → Plant(x))
#  ∀x (AtLeastOneTree(x) → NotAnAnimal(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  There are no fiction books that are not non-fiction. Anything that is a novel is a fiction book. Therefore, some novels are non-fiction. ∃x (NoFictionBookThat(x) ∧ NotNonfiction(x))
#  ∀x (AnythingThat(x) → NovelAFictionBook(x))
#  ∀x (SomeNovel(x) → Nonfiction(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  There exist no machines that are also humans. Anything that can be called a student is, without exception, a human. No students are machines. ∃x (NoMachineThat(x) ∧ AlsoHuman(x))
#  ∀x (AnythingThatCanBeCalledAStudent(x) → WithoutExceptionAHuman(x))
#  ∀x (Student(x) → ¬Machine(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  It is true that anything that is an apple is an edible thing. Every apple is a fruit. It follows that some fruits are edible things. ∀x (AnythingThat(x) → AppleAnEdibleThingEveryAppleAFruitItFollowThatSomeFruitEdibleThing(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  There are some creatures that are animals and not vertebrates. All cats are also vertebrates. This leads to the conclusion that there are some cats which are animals. ∃x (CreatureThat(x) ∧ AnimalAndNotVertebrate(x))
#  ∀x (Cat(x) → AlsoVertebrate(x))
#  ∀x (ThiLeadToTheConclusionThatThere(x) → CatWhichAnimal(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  There are some animals that are sparrows. All things that are sparrows are birds. Consequently, every single thing that is a bird is an animal. ∃x (AnimalThat(x) ∧ Sparrow(x))
#  ∀x (ThingThat(x) → SparrowBird(x))
#  ∀x (EverySingleThingThat(x) → BirdAnAnimal(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Every single integer is divisible by two. All integers are even numbers. It follows from this that some even numbers are not divisible by two. ∀x (SingleInteger(x) → DivisibleByTwo(x))
#  ∀x (Integer(x) → EvenNumber(x))
#  ∀x (FromThiThatSomeEvenNumber(x) → NotDivisibleByTwo(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Nothing that is a pet animal is also a feline. Some cats happen to be pet animals. This leads to the conclusion that a certain number of cats are not felines. ∀x (NothingThat(x) → PetAnimalAlsoAFeline(x))
#  ∀x (CatHappenToBePetAnimal(x))
#  ∀x (ThiLeadToTheConclusionThatACertainNumberOfCat(x) → NotFeline(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Any and all reptiles are lizards. There are reptiles that are mammals. It must follow that all mammals are lizards. ∀x (AndAllReptile(x) → Lizard(x))
#  ∃x (ReptileThat(x) ∧ Mammal(x))
#  ∀x (ItMustFollowThatAllMammal(x) → Lizard(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Dogs are never cats. Some domestic animals are indeed felines. Therefore, a portion of domestic animals is not dogs. ∀x (Dog(x) → NeverCat(x))
#  ∃x (DomesticAnimal(x) ∧ IndeedFeline(x))
#  ∀x (APortionOfDomesticAnimal(x) → NotDog(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  There are no birds which are cats. There are no dogs that are birds. It follows, then, that some dogs are cats. ∃x (NoBirdWhich(x) ∧ Cat(x))
#  ∃x (NoDogThat(x) ∧ Bird(x))
#  ∀x (ThenThatSomeDog(x) → Cat(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  There are no dogs that are reptiles. Everything that is a fish is a dog. Thus, every fish is a reptile. ∃x (NoDogThat(x) ∧ Reptile(x))
#  ∀x (EverythingThat(x) → FishADog(x))
#  ∀x (EveryFish(x) → Reptile(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Every item that is a mammal is an animal. Some lions are mammals. Therefore, all lions can be said to be animals. ∀x (ItemThat(x) → MammalAnAnimal(x))
#  ∃x (Lion(x) ∧ Mammal(x))
#  ∀x (AllLionCanBeSaidToBeAnimal(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Every single cat is an animal. Anything that can be called a dog is, without exception, an animal. Every dog is a cat. ∀x (SingleCat(x) → Animal(x))
#  ∀x (AnythingThatCanBeCalledADog(x) → WithoutExceptionAnAnimal(x))
#  ∀x (Dog(x) → Cat(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  There exist cats that are also mammals. A subset of dogs can be classified as mammals. It follows that at least some dogs are not cats. ∃x (CatThat(x) ∧ AlsoMammal(x))
#  ∀x (SubsetOfDogCanBeClassifiedAsMammal(x))
#  ∀x (AtLeastSomeDog(x) → NotCat(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Humans are in no way animals. Anything that is a human is a mammal. There are some mammals which are not animals. ∀x (Human(x) → InNoWayAnimal(x))
#  ∀x (AnythingThat(x) → HumanAMammal(x))
#  ∃x (MammalWhich(x) ∧ NotAnimal(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  It is the case that every fish lives in a tree. There exist some sea basses which do not live in trees. It necessarily follows that some sea basses are not fish. ∀x (It(x) → CaseThatEveryFishLiveInATree(x))
#  ∃x (ThereEx(x) ∧ ¬TSomeSeaBasseWhichDoNotLiveInTree(x))
#  ∀x (ItNecessarilyFollowThatSomeSeaBasse(x) → NotFish(x))
#
# true label:
#  True
# predicted label:
#  False
# syllogism:
#  There are some dogs that are cats. There are no cats that are reptiles. As a result, some reptiles are dogs. ∃x (DogThat(x) ∧ Cat(x))
#  ∃x (NoCatThat(x) ∧ Reptile(x))
#  ∀x (SomeReptile(x) → Dog(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  There are some individuals who find pleasure in reading who are librarians. Every single person who is a librarian is a student. It is the case that some of the people who are students are people who enjoy reading. ∃x (IndividualWhoFindPleasureInReadingWho(x) ∧ Librarian(x))
#  ∀x (SinglePersonWho(x) → LibrarianAStudent(x))
#  ∀x (It(x) → CaseThatSomeOfThePeopleWhoStudentPeopleWhoEnjoyReading(x))
#
# true label:
#  True
# predicted label:
#  True
# Accuracy: 0.9230769230769231
# Precision: 0.9255952380952381
# Recall: 0.9230769230769231
# F1: 0.922962962962963
# Classification Report:               precision    recall  f1-score   support
#
#        False       0.89      0.96      0.93        52
#         True       0.96      0.88      0.92        52
#
#     accuracy                           0.92       104
#    macro avg       0.93      0.92      0.92       104
# weighted avg       0.93      0.92      0.92       104
