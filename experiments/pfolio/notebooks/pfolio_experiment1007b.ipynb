# %%
'''
task: classify syllogism validity with NL + CLIF notation
models: gemma-2-2b-it
dataset: pfolio
evaluation: zero-shot + sef category
'''
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# start preparing for QA pipeline
! pip install -U accelerate
! pip install -U transformers
# !pip install transformers
# !pip install evaluate
# Out:
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.13.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from accelerate) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (26.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate) (6.0.3)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (2.10.0+cu128)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (1.8.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate) (0.7.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (0.28.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (4.67.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.0.0->accelerate) (1.5.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (0.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.3)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub>=0.21.0->accelerate) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub>=0.21.0->accelerate) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub>=0.21.0->accelerate) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub>=0.21.0->accelerate) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub>=0.21.0->accelerate) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub>=0.21.0->accelerate) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface_hub>=0.21.0->accelerate) (0.1.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.0.0)
# Collecting transformers
#   Downloading transformers-5.5.3-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (1.8.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers) (0.1.2)
# Downloading transformers-5.5.3-py3-none-any.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 162.8 MB/s eta 0:00:00
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
# Successfully installed transformers-5.5.3
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.5.3)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (1.8.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers) (0.1.2)
# Collecting evaluate
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (4.0.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.0.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.32.4)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.12/dist-packages (from evaluate) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from evaluate) (3.6.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (1.8.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from evaluate) (26.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (3.25.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (18.1.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (3.13.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2026.2.25)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2025.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.23.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.7.0->evaluate) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.7.0->evaluate) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.7.0->evaluate) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.7.0->evaluate) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.7.0->evaluate) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.7.0->evaluate) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.7.0->evaluate) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub>=0.7.0->evaluate) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub>=0.7.0->evaluate) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub>=0.7.0->evaluate) (0.1.2)
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 9.2 MB/s eta 0:00:00
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.6

# %%
import pandas as pd

pfolio_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/p-folio/data/pfolio_kr_gold_train_sef.csv")

# %%
# evaluation metrics

import numpy as np
import re
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report

def predict_answer(model, tokenizer, obj, subject, obj_clif, subject_clif, sef, ref_relation=None, source_knowledge=None):
  # define sef categories
  sef_disjunctive = r"""
  A disjunctive syllogism contains "∨" or "⊕". Here is an example:
  <PREMISES>All kids are young.
All toddlers are kids.
If someone is young, then they are not elderly.
All pirates are seafarers.
If Nancy is not a pirate, then Nancy is young.
If Nancy is not a toddler, then Nancy is a seafarer.</PREMISES>
  <CONCLUSION>Nancy is either both a pirate and a toddler, or neither a pirate nor a toddler.</CONCLUSION>
  <PREMISES-CLIF>forall x (kid(x) implies young(x))
forall x (toddler(x) implies kid(x))
forall x (young(x) implies not elderly(x))
forall x (pirate(x) implies seafarer(x))
not pirate(nancy) implies young(nancy)
not toddler(nancy) implies seafarer(nancy)</PREMISES-CLIF>
  <CONCLUSION-CLIF>not (pirate(nancy) xor toddler(nancy))</CONCLUSION-CLIF>
  """

  sef_complex = r"""
  A complex syllogism has more than 2 premises. Here is an example:
  <PREMISES>Aberdeen won the cup in the 2013 final.
Rangers won the cup in the 2014 final.
Aberdeen and Rangers are different teams.
Different teams cannot win the cup in the same year's final.</PREMISES>
  <CONCLUSION>Aberdeen has once won a cup.</CONCLUSION>
  <PREMISES-CLIF>woncup(aberdeen, year2013final)
woncup(rangers, year2014final)
not (aberdeen=rangers)
forall x forall y forall z forall w (not (x=y) and woncup(x, z) and woncup(y, w) implies not (z=w))</PREMISES-CLIF>
  <CONCLUSION-CLIF>exists x (woncup(aberdeen, x))</CONCLUSION-CLIF>
  """

  sef_categorical = r"""
  A categorical syllogism contains any word from the list ["all", "any", "some", "no", "few", "most", "none", "several"]. Here is an example:
    <PREMISES>Ordinary is an unincorporated community.
Located within Elliot County, Ordinary is on Kentucky Route 32.
Ordinary is located northwest of Sandy Hook.</PREMISES>
  <CONCLUSION>There is an unincorporated community located in Elliot County.</CONCLUSION>
  <PREMISES-CLIF>unincorporatedcommunity(ordinary)
locatedin(ordinary, elliotcounty) and on(ordinary, kentuckyroute32)
locatednorthwestof(ordinary, sandyhook)</PREMISES-CLIF>
  <CONCLUSION-CLIF>exists x (unincorporatedcommunity(x) and locatedin(x, elliotcounty))</CONCLUSION-CLIF>
  """

  sef_hypothetical = r"""
  A hypothetical syllogism is not disjunctive, complex or categorical. Here is an example:
  <PREMISES>No homework is fun.
Some reading is homework.</PREMISES>
  <CONCLUSION>Some reading is fun.</CONCLUSION>
  <PREMISES-CLIF>forall x (homework(x) implies not fun(x))
exists x (reading(x) and homework(x))</PREMISES-CLIF>
  <CONCLUSION-CLIF>exists x (reading(x) and fun(x))</CONCLUSION-CLIF>
  """

  sef_categories = dict()
  sef_categories["disjunctive"] = sef_disjunctive
  sef_categories["complex"] = sef_complex
  sef_categories["categorical"] = sef_categorical
  sef_categories["hypothetical"] = sef_hypothetical


  # define notation grammar
  grammar = r"""
    start: program
    program: [stat]+
    stat: proposition newline | keyword* quantifier* symbol* leftparen* (quantifier symbol)* proposition rightparen* newline | keyword* (quantifier symbol)* leftparen* (quantifier symbol)* proposition rightparen* newline
    proposition: atomicproposition | complexproposition
    complexproposition: keyword* proposition keyword leftparen* (quantifier symbol)* proposition rightparen*
    atomicproposition: leftparen* term* leftparen* term* rightparen*
    # !term: (LETTER+) (LETTER+|DIGIT+|"=" | "+" | "-" | "," | "≠")* | (DIGIT+) (LETTER+|DIGIT+|"=" | "+" | "-" | "," | "≠")*
    # !leftparen: "("
    # !rightparen: ")"
    # !keyword: "and" | "not" | "implies" | "or" | "xor" | "implies" | "implies"
    # !quantifier: "exists" | "forall"
    symbol: LETTER
    newline: /\n/

    # %import common.LETTER
    # %import common.DIGIT
    # %import common.INT -> NUMBER
    # %import common.ESCAPED_STRING -> STRING
    # %import common.WS
    # %ignore WS
"""
  # prepare prompt
  rag_prompt = f"""
  <start_of_turn>user
  You are an expert logician. You are given a syllogism in natural language with premises between <PREMISES></PREMISES> and conclusion between <CONCLUSION></CONCLUSION> tags and CLIF with premises between <PREMISES-CLIF></PREMISES-CLIF> and conclusion between <CONCLUSION-CLIF></CONCLUSION-CLIF> tags.
  The CLIF BNF grammar to understand and reason in the language is given in the <GRAMMAR></GRAMMAR> tags.
  <GRAMMAR>{grammar}</GRAMMAR>
  <PREMISES>{subject}</PREMISES>
  <CONCLUSION>{obj}</CONCLUSION>
  <PREMISES-CLIF>{subject_clif}</PREMISES-CLIF>
  <CONCLUSION-CLIF>{obj_clif}</CONCLUSION-CLIF>
  You are also given the category of the syllogism to help you understand it: {sef_categories[sef]}.
  Classify the conclusion as "T" if true, "F" if false or "U" if uncertain based on the premises. Present your answer only between <output></output> tags.
  <end_of_turn>
  <start_of_turn>model
  """
  input_ids = tokenizer(rag_prompt, return_tensors="pt").to(model.device)
  response = model.generate(**input_ids, max_new_tokens=500)
  predicted_relation = tokenizer.decode(response[0])
  matches = re.findall('<output>(.*)</output>', predicted_relation, flags=re.DOTALL)
  res = re.findall(r"<output>(.*)", matches[-1])  # from ['</output> tags.\n  <end_of_turn>\n  <start_of_turn>model\n  <output>T'] to ['T']
  predicted_label = res[0] if res else "None" # take first element from list ['T'] to get 'T'

  print("*** Premises: \n", subject)
  print("*** Conclusion: \n", obj)
  print("*** Premises-CLIF: \n", subject_clif)
  print("*** Conclusion-CLIF: \n", obj_clif)
  print("*** True Label: \n", ref_relation)
  print("*** Predicted Label: \n", predicted_label)
  return predicted_label

# %%
def infer_from_ontology(dataset, model, tokenizer, mode='default', notation='NL'):
  evaluation_metrics_df = pd.DataFrame(columns=["Accuracy", "Precision", "Recall", "F1"])
  reference_labels = []
  predicted_labels = []
  for index, row in dataset.iterrows():
      conclusion = row["Conclusions - " + notation]
      premises = row["Premises - " + notation]
      conclusion_clif = row["Conclusions - " + "CLIF"]
      premises_clif = row["Premises - " + "CLIF"]
      sef_category = row["sef"]
      label = row["Truth Values"]
      if mode.lower() == "grammar":
        # conduct query with RAG retrival of sources
        # set number of candidate answers to consider as half the total triple store axioms
        source_information = """BNF GRAMMAR"""
        print("*** RAG INFORMATION:", source_information)
      # predict answer with model
      predicted_label = predict_answer(model, tokenizer, conclusion, premises, conclusion_clif, premises_clif, sef_category, label)
      reference_labels.append(label)
      predicted_labels.append(predicted_label)
  # fill evaluation metrics dataframe
  accuracy_metric = accuracy_score(reference_labels, predicted_labels)
  precision_metric = precision_score(reference_labels, predicted_labels, average="macro")
  recall_metric = recall_score(reference_labels, predicted_labels, average="macro")
  f1_metric = f1_score(reference_labels, predicted_labels, average="macro")
  evaluation_metrics_df["Accuracy"] = [accuracy_metric]
  evaluation_metrics_df["Precision"] = [precision_metric]
  evaluation_metrics_df["Recall"] = [recall_metric]
  evaluation_metrics_df["F1"] = [f1_metric]
  print("Classification Report:", classification_report(reference_labels, predicted_labels))
  print("*************** INFERENCE COMPLETE ***************")
  return reference_labels, predicted_labels, evaluation_metrics_df, accuracy_metric, precision_metric, recall_metric, f1_metric

# %%
import torch
import json
from tqdm import tqdm
import torch.nn as nn
from torch.optim import Adam
import nltk
import spacy
import string
import evaluate  # Bleu
from torch.utils.data import Dataset, DataLoader, RandomSampler
import pandas as pd
import numpy as np
import transformers
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from transformers import AutoTokenizer, AutoModelForCausalLM

import warnings
warnings.filterwarnings("ignore")

# %%
# login to hugging face to have access to the model
# !pip install huggingface_hub
from huggingface_hub import notebook_login
notebook_login()
# Out:
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (1.8.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.67.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub) (0.16.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface_hub) (0.1.2)
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# try rag search with gemma
tokenizer = AutoTokenizer.from_pretrained("google/gemma-2b-it")
# CPU Enabled uncomment below 👇🏽
#model = AutoModelForCausalLM.from_pretrained("google/gemma-2b-it")
# GPU Enabled use below 👇🏽
model = AutoModelForCausalLM.from_pretrained("google/gemma-2b-it", device_map="auto")
# Out:
# config.json:   0%|          | 0.00/627 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/164 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]

# %%
# experiment: ZS prediction without Grammar
ref_labels, pred_labels, eval_metrics_df, acc_metric, pr_metric, re_metric, f_metric = infer_from_ontology(pfolio_df, model, tokenizer, mode='default', notation='CLIF')
# Out:
# Streaming output truncated to the last 5000 lines.
# named(amyodell, nameodell) and notableperson(amyodell) and named(jackodell, nameodell) and notableperson(jackodell) and named(matsodell, nameodell) and notableperson(matsodell)
# british(amyodell) and singer(amyodell) and songwriter(amyodell)
# english(jackodell) and toyinventor(jackodell)
# *** Conclusion-CLIF:
#  notableperson(jackodell)
# *** True Label:
#  T
# *** Predicted Label:
#  T
# *** Premises:
#  surname(nameodell) and from(nameodell, odellbedfordshire)
# mistakenspellingof(nameo'dell, nameodell) and (exists xexists y(family(x) and named(x, nameo'dell) and (not (x=y)) and family(y) and named(y, nameo'dell))
# named(amyodell, nameodell) and notableperson(amyodell) and named(jackodell, nameodell) and notableperson(jackodell) and named(matsodell, nameodell) and notableperson(matsodell)
# british(amyodell) and singer(amyodell) and songwriter(amyodell)
# english(jackodell) and toyinventor(jackodell)
# *** Conclusion:
#  named(amyodell, nameodell)
# *** Premises-CLIF:
#  surname(nameodell) and from(nameodell, odellbedfordshire)
# mistakenspellingof(nameo'dell, nameodell) and (exists xexists y(family(x) and named(x, nameo'dell) and (not (x=y)) and family(y) and named(y, nameo'dell))
# named(amyodell, nameodell) and notableperson(amyodell) and named(jackodell, nameodell) and notableperson(jackodell) and named(matsodell, nameodell) and notableperson(matsodell)
# british(amyodell) and singer(amyodell) and songwriter(amyodell)
# english(jackodell) and toyinventor(jackodell)
# *** Conclusion-CLIF:
#  named(amyodell, nameodell)
# *** True Label:
#  T
# *** Predicted Label:
#  T
# *** Premises:
#  surname(nameodell) and from(nameodell, odellbedfordshire)
# mistakenspellingof(nameo'dell, nameodell) and (exists xexists y(family(x) and named(x, nameo'dell) and (not (x=y)) and family(y) and named(y, nameo'dell))
# named(amyodell, nameodell) and notableperson(amyodell) and named(jackodell, nameodell) and notableperson(jackodell) and named(matsodell, nameodell) and notableperson(matsodell)
# british(amyodell) and singer(amyodell) and songwriter(amyodell)
# english(jackodell) and toyinventor(jackodell)
# *** Conclusion:
#  english(amyodell) and toyinventor(amyodell)
# *** Premises-CLIF:
#  surname(nameodell) and from(nameodell, odellbedfordshire)
# mistakenspellingof(nameo'dell, nameodell) and (exists xexists y(family(x) and named(x, nameo'dell) and (not (x=y)) and family(y) and named(y, nameo'dell))
# named(amyodell, nameodell) and notableperson(amyodell) and named(jackodell, nameodell) and notableperson(jackodell) and named(matsodell, nameodell) and notableperson(matsodell)
# british(amyodell) and singer(amyodell) and songwriter(amyodell)
# english(jackodell) and toyinventor(jackodell)
# *** Conclusion-CLIF:
#  english(amyodell) and toyinventor(amyodell)
# *** True Label:
#  U
# *** Predicted Label:
#  T
# *** Premises:
#  surname(nameodell) and from(nameodell, odellbedfordshire)
# mistakenspellingof(nameo'dell, nameodell) and (exists xexists y(family(x) and named(x, nameo'dell) and (not (x=y)) and family(y) and named(y, nameo'dell))
# named(amyodell, nameodell) and notableperson(amyodell) and named(jackodell, nameodell) and notableperson(jackodell) and named(matsodell, nameodell) and notableperson(matsodell)
# british(amyodell) and singer(amyodell) and songwriter(amyodell)
# english(jackodell) and toyinventor(jackodell)
# *** Conclusion:
#  named(amyodell, nameodell) and named(amyodell, nameo'dell)
# *** Premises-CLIF:
#  surname(nameodell) and from(nameodell, odellbedfordshire)
# mistakenspellingof(nameo'dell, nameodell) and (exists xexists y(family(x) and named(x, nameo'dell) and (not (x=y)) and family(y) and named(y, nameo'dell))
# named(amyodell, nameodell) and notableperson(amyodell) and named(jackodell, nameodell) and notableperson(jackodell) and named(matsodell, nameodell) and notableperson(matsodell)
# british(amyodell) and singer(amyodell) and songwriter(amyodell)
# english(jackodell) and toyinventor(jackodell)
# *** Conclusion-CLIF:
#  named(amyodell, nameodell) and named(amyodell, nameo'dell)
# *** True Label:
#  U
# *** Predicted Label:
#  T
# *** Premises:
#  czech(miroslavfiedler) and mathematician(miroslavfiedler)
# knownfor(miroslavfiedler, contributionstolinearalgebraandgraphtheory)
# honoredby(miroslavfiedler, fiedlereigenvalue)
# thesecondsmallesteigenvalueof(fiedlereigenvalue, thegraphlaplacian)
# *** Conclusion:
#  exists x (thesecondsmallesteigenvalueof(x, thegraphlaplacian) and honoredby(miroslavfiedler, x))
# *** Premises-CLIF:
#  czech(miroslavfiedler) and mathematician(miroslavfiedler)
# knownfor(miroslavfiedler, contributionstolinearalgebraandgraphtheory)
# honoredby(miroslavfiedler, fiedlereigenvalue)
# thesecondsmallesteigenvalueof(fiedlereigenvalue, thegraphlaplacian)
# *** Conclusion-CLIF:
#  exists x (thesecondsmallesteigenvalueof(x, thegraphlaplacian) and honoredby(miroslavfiedler, x))
# *** True Label:
#  T
# *** Predicted Label:
#  T
# *** Premises:
#  czech(miroslavfiedler) and mathematician(miroslavfiedler)
# knownfor(miroslavfiedler, contributionstolinearalgebraandgraphtheory)
# honoredby(miroslavfiedler, fiedlereigenvalue)
# thesecondsmallesteigenvalueof(fiedlereigenvalue, thegraphlaplacian)
# *** Conclusion:
#  french(miroslavfiedler) and mathematician(miroslavfiedler)
# *** Premises-CLIF:
#  czech(miroslavfiedler) and mathematician(miroslavfiedler)
# knownfor(miroslavfiedler, contributionstolinearalgebraandgraphtheory)
# honoredby(miroslavfiedler, fiedlereigenvalue)
# thesecondsmallesteigenvalueof(fiedlereigenvalue, thegraphlaplacian)
# *** Conclusion-CLIF:
#  french(miroslavfiedler) and mathematician(miroslavfiedler)
# *** True Label:
#  U
# *** Predicted Label:
#  T
# *** Premises:
#  czech(miroslavfiedler) and mathematician(miroslavfiedler)
# knownfor(miroslavfiedler, contributionstolinearalgebraandgraphtheory)
# honoredby(miroslavfiedler, fiedlereigenvalue)
# thesecondsmallesteigenvalueof(fiedlereigenvalue, thegraphlaplacian)
# *** Conclusion:
#  exists x (czech(x) and mathematician(x) and knownfor(x, contributionstolinearalgebraandgraphtheory))
# *** Premises-CLIF:
#  czech(miroslavfiedler) and mathematician(miroslavfiedler)
# knownfor(miroslavfiedler, contributionstolinearalgebraandgraphtheory)
# honoredby(miroslavfiedler, fiedlereigenvalue)
# thesecondsmallesteigenvalueof(fiedlereigenvalue, thegraphlaplacian)
# *** Conclusion-CLIF:
#  exists x (czech(x) and mathematician(x) and knownfor(x, contributionstolinearalgebraandgraphtheory))
# *** True Label:
#  T
# *** Predicted Label:
#  T
# *** Premises:
#  english(thomasbarber) and professionalfootballer(thomasbarber)
# playedfor(thomasbarber, astonvilla) and playedin(astonvilla,thefootballleague)
# playedas(thomasbarber, halfback) and playedas(thomasbarber, insideleft)
# scoredthewinninggoalin(thomasbarber, facupfinal1913)
# *** Conclusion:
#  playedfor(thomasbarber, boltonwanderers) and playedin(boltonwanderers,thefootballleague)
# *** Premises-CLIF:
#  english(thomasbarber) and professionalfootballer(thomasbarber)
# playedfor(thomasbarber, astonvilla) and playedin(astonvilla,thefootballleague)
# playedas(thomasbarber, halfback) and playedas(thomasbarber, insideleft)
# scoredthewinninggoalin(thomasbarber, facupfinal1913)
# *** Conclusion-CLIF:
#  playedfor(thomasbarber, boltonwanderers) and playedin(boltonwanderers,thefootballleague)
# *** True Label:
#  U
# *** Predicted Label:
#  T
# *** Premises:
#  english(thomasbarber) and professionalfootballer(thomasbarber)
# playedfor(thomasbarber, astonvilla) and playedin(astonvilla,thefootballleague)
# playedas(thomasbarber, halfback) and playedas(thomasbarber, insideleft)
# scoredthewinninggoalin(thomasbarber, facupfinal1913)
# *** Conclusion:
#  playedas(thomasbarber, insideleft)
# *** Premises-CLIF:
#  english(thomasbarber) and professionalfootballer(thomasbarber)
# playedfor(thomasbarber, astonvilla) and playedin(astonvilla,thefootballleague)
# playedas(thomasbarber, halfback) and playedas(thomasbarber, insideleft)
# scoredthewinninggoalin(thomasbarber, facupfinal1913)
# *** Conclusion-CLIF:
#  playedas(thomasbarber, insideleft)
# *** True Label:
#  T
# *** Predicted Label:
#  T
# *** Premises:
#  english(thomasbarber) and professionalfootballer(thomasbarber)
# playedfor(thomasbarber, astonvilla) and playedin(astonvilla,thefootballleague)
# playedas(thomasbarber, halfback) and playedas(thomasbarber, insideleft)
# scoredthewinninggoalin(thomasbarber, facupfinal1913)
# *** Conclusion:
#  exists x (english(x) and professionalfootballer(x) and scoredthewinninggoalin(x, facupfinal1913))
# *** Premises-CLIF:
#  english(thomasbarber) and professionalfootballer(thomasbarber)
# playedfor(thomasbarber, astonvilla) and playedin(astonvilla,thefootballleague)
# playedas(thomasbarber, halfback) and playedas(thomasbarber, insideleft)
# scoredthewinninggoalin(thomasbarber, facupfinal1913)
# *** Conclusion-CLIF:
#  exists x (english(x) and professionalfootballer(x) and scoredthewinninggoalin(x, facupfinal1913))
# *** True Label:
#  T
# *** Predicted Label:
#  T
# *** Premises:
#  game(thelegendofzelda) and exists x (japanese(x) and videogamecompany(x) and created(x, thelegendofzelda))
# forall x forall y ((game(x) and intop10(x) and created(y,x)) implies japanese(y))
# forall x ((game(x) and exists y(greaterthan(y, onemillion) and copiessold(x, y))) implies top10(x)))
# exists y(greaterthan(y, onemillion) and copiessold(thelegendofzelda,y))
# *** Conclusion:
#  top10(thelegendofzelda)
# *** Premises-CLIF:
#  game(thelegendofzelda) and exists x (japanese(x) and videogamecompany(x) and created(x, thelegendofzelda))
# forall x forall y ((game(x) and intop10(x) and created(y,x)) implies japanese(y))
# forall x ((game(x) and exists y(greaterthan(y, onemillion) and copiessold(x, y))) implies top10(x)))
# exists y(greaterthan(y, onemillion) and copiessold(thelegendofzelda,y))
# *** Conclusion-CLIF:
#  top10(thelegendofzelda)
# *** True Label:
#  T
# *** Predicted Label:
#  T
# *** Premises:
#  game(thelegendofzelda) and exists x (japanese(x) and videogamecompany(x) and created(x, thelegendofzelda))
# forall x forall y ((game(x) and intop10(x) and created(y,x)) implies japanese(y))
# forall x ((game(x) and exists y(greaterthan(y, onemillion) and copiessold(x, y))) implies top10(x)))
# exists y(greaterthan(y, onemillion) and copiessold(thelegendofzelda,y))
# *** Conclusion:
#  exists x(created(x, fifa22) and japanese(x) and videogamecompany(x))
# *** Premises-CLIF:
#  game(thelegendofzelda) and exists x (japanese(x) and videogamecompany(x) and created(x, thelegendofzelda))
# forall x forall y ((game(x) and intop10(x) and created(y,x)) implies japanese(y))
# forall x ((game(x) and exists y(greaterthan(y, onemillion) and copiessold(x, y))) implies top10(x)))
# exists y(greaterthan(y, onemillion) and copiessold(thelegendofzelda,y))
# *** Conclusion-CLIF:
#  exists x(created(x, fifa22) and japanese(x) and videogamecompany(x))
# *** True Label:
#  U
# *** Predicted Label:
#  T
# *** Premises:
#  game(thelegendofzelda) and exists x (japanese(x) and videogamecompany(x) and created(x, thelegendofzelda))
# forall x forall y ((game(x) and intop10(x) and created(y,x)) implies japanese(y))
# forall x ((game(x) and exists y(greaterthan(y, onemillion) and copiessold(x, y))) implies top10(x)))
# exists y(greaterthan(y, onemillion) and copiessold(thelegendofzelda,y))
# *** Conclusion:
#  not top10(thelegendofzelda)
# *** Premises-CLIF:
#  game(thelegendofzelda) and exists x (japanese(x) and videogamecompany(x) and created(x, thelegendofzelda))
# forall x forall y ((game(x) and intop10(x) and created(y,x)) implies japanese(y))
# forall x ((game(x) and exists y(greaterthan(y, onemillion) and copiessold(x, y))) implies top10(x)))
# exists y(greaterthan(y, onemillion) and copiessold(thelegendofzelda,y))
# *** Conclusion-CLIF:
#  not top10(thelegendofzelda)
# *** True Label:
#  F
# *** Predicted Label:
#  F
# *** Premises:
#  team(goldenstatewarriors) and from(goldenstatewarriors, sanfrancisco)
# won(goldenstatewarriors, nbafinals)
# forall x ((team(x) and attending(x, nbafinals)) implies wonmanygames(x))
# team(bostonceltics) and lost(bostonceltics, nbafinals)
# forall x ((team(x) and won(x, nbafinals)) implies moreincome(x))
# forall x ((won(x, nbafinals) or lost(x, nbafinals)) implies attending(x, nbafinals))
# *** Conclusion:
#  from(bostonceltics, sanfrancisco)
# *** Premises-CLIF:
#  team(goldenstatewarriors) and from(goldenstatewarriors, sanfrancisco)
# won(goldenstatewarriors, nbafinals)
# forall x ((team(x) and attending(x, nbafinals)) implies wonmanygames(x))
# team(bostonceltics) and lost(bostonceltics, nbafinals)
# forall x ((team(x) and won(x, nbafinals)) implies moreincome(x))
# forall x ((won(x, nbafinals) or lost(x, nbafinals)) implies attending(x, nbafinals))
# *** Conclusion-CLIF:
#  from(bostonceltics, sanfrancisco)
# *** True Label:
#  U
# *** Predicted Label:
#  T
# *** Premises:
#  team(goldenstatewarriors) and from(goldenstatewarriors, sanfrancisco)
# won(goldenstatewarriors, nbafinals)
# forall x ((team(x) and attending(x, nbafinals)) implies wonmanygames(x))
# team(bostonceltics) and lost(bostonceltics, nbafinals)
# forall x ((team(x) and won(x, nbafinals)) implies moreincome(x))
# forall x ((won(x, nbafinals) or lost(x, nbafinals)) implies attending(x, nbafinals))
# *** Conclusion:
#  hasmorethanthirtyyearsofhistory(bostonceltics)
# *** Premises-CLIF:
#  team(goldenstatewarriors) and from(goldenstatewarriors, sanfrancisco)
# won(goldenstatewarriors, nbafinals)
# forall x ((team(x) and attending(x, nbafinals)) implies wonmanygames(x))
# team(bostonceltics) and lost(bostonceltics, nbafinals)
# forall x ((team(x) and won(x, nbafinals)) implies moreincome(x))
# forall x ((won(x, nbafinals) or lost(x, nbafinals)) implies attending(x, nbafinals))
# *** Conclusion-CLIF:
#  hasmorethanthirtyyearsofhistory(bostonceltics)
# *** True Label:
#  T
# *** Predicted Label:
#  T
# *** Premises:
#  team(goldenstatewarriors) and from(goldenstatewarriors, sanfrancisco)
# won(goldenstatewarriors, nbafinals)
# forall x ((team(x) and attending(x, nbafinals)) implies wonmanygames(x))
# team(bostonceltics) and lost(bostonceltics, nbafinals)
# forall x ((team(x) and won(x, nbafinals)) implies moreincome(x))
# forall x ((won(x, nbafinals) or lost(x, nbafinals)) implies attending(x, nbafinals))
# *** Conclusion:
#  moreincome(goldenstatewarriors)
# *** Premises-CLIF:
#  team(goldenstatewarriors) and from(goldenstatewarriors, sanfrancisco)
# won(goldenstatewarriors, nbafinals)
# forall x ((team(x) and attending(x, nbafinals)) implies wonmanygames(x))
# team(bostonceltics) and lost(bostonceltics, nbafinals)
# forall x ((team(x) and won(x, nbafinals)) implies moreincome(x))
# forall x ((won(x, nbafinals) or lost(x, nbafinals)) implies attending(x, nbafinals))
# *** Conclusion-CLIF:
#  moreincome(goldenstatewarriors)
# *** True Label:
#  T
# *** Predicted Label:
#  T
# *** Premises:
#  forall x (subscribedto(x, amcalist) implies eligibleforthreefreemovies(x))
# exists x (cinemaeveryweek(x))
# forall x (prefer(x, tvseries) implies not watchtvin(x, cinemas))
# watchtvin(james, cinemas)
# subscribedto(james, amcalist)
# prefer(peter, tvseries)
# *** Conclusion:
#  not eligibleforthreefreemovies(james)
# *** Premises-CLIF:
#  forall x (subscribedto(x, amcalist) implies eligibleforthreefreemovies(x))
# exists x (cinemaeveryweek(x))
# forall x (prefer(x, tvseries) implies not watchtvin(x, cinemas))
# watchtvin(james, cinemas)
# subscribedto(james, amcalist)
# prefer(peter, tvseries)
# *** Conclusion-CLIF:
#  not eligibleforthreefreemovies(james)
# *** True Label:
#  F
# *** Predicted Label:
#  F
# *** Premises:
#  forall x (subscribedto(x, amcalist) implies eligibleforthreefreemovies(x))
# exists x (cinemaeveryweek(x))
# forall x (prefer(x, tvseries) implies not watchtvin(x, cinemas))
# watchtvin(james, cinemas)
# subscribedto(james, amcalist)
# prefer(peter, tvseries)
# *** Conclusion:
#  cinemaeveryweek(james)
# *** Premises-CLIF:
#  forall x (subscribedto(x, amcalist) implies eligibleforthreefreemovies(x))
# exists x (cinemaeveryweek(x))
# forall x (prefer(x, tvseries) implies not watchtvin(x, cinemas))
# watchtvin(james, cinemas)
# subscribedto(james, amcalist)
# prefer(peter, tvseries)
# *** Conclusion-CLIF:
#  cinemaeveryweek(james)
# *** True Label:
#  U
# *** Predicted Label:
#  T
# *** Premises:
#  forall x (subscribedto(x, amcalist) implies eligibleforthreefreemovies(x))
# exists x (cinemaeveryweek(x))
# forall x (prefer(x, tvseries) implies not watchtvin(x, cinemas))
# watchtvin(james, cinemas)
# subscribedto(james, amcalist)
# prefer(peter, tvseries)
# *** Conclusion:
#  not watchtvin(peter, cinemas)
# *** Premises-CLIF:
#  forall x (subscribedto(x, amcalist) implies eligibleforthreefreemovies(x))
# exists x (cinemaeveryweek(x))
# forall x (prefer(x, tvseries) implies not watchtvin(x, cinemas))
# watchtvin(james, cinemas)
# subscribedto(james, amcalist)
# prefer(peter, tvseries)
# *** Conclusion-CLIF:
#  not watchtvin(peter, cinemas)
# *** True Label:
#  T
# *** Predicted Label:
#  F
# *** Premises:
#  forall x ((book(x) and writtenby(x, cixinliu)) implies exists y(morethan(y, onemillion) and sold(x,y)))
# exists x (won(x, hugoaward) and book(x) and writtenby(x, cixinliu))
# forall x ((book(x) and aboutfuture(x)) implies fowardlooking(x))
# book(threebodyproblem) and exists y(morethan(y, onemillion) and sold(threebodyproblem,y))
# aboutfuture(threebodyproblem)
# *** Conclusion:
#  won(threebodyproblem, hugoaward)
# *** Premises-CLIF:
#  forall x ((book(x) and writtenby(x, cixinliu)) implies exists y(morethan(y, onemillion) and sold(x,y)))
# exists x (won(x, hugoaward) and book(x) and writtenby(x, cixinliu))
# forall x ((book(x) and aboutfuture(x)) implies fowardlooking(x))
# book(threebodyproblem) and exists y(morethan(y, onemillion) and sold(threebodyproblem,y))
# aboutfuture(threebodyproblem)
# *** Conclusion-CLIF:
#  won(threebodyproblem, hugoaward)
# *** True Label:
#  U
# *** Predicted Label:
#  T
# *** Premises:
#  forall x ((book(x) and writtenby(x, cixinliu)) implies exists y(morethan(y, onemillion) and sold(x,y)))
# exists x (won(x, hugoaward) and book(x) and writtenby(x, cixinliu))
# forall x ((book(x) and aboutfuture(x)) implies fowardlooking(x))
# book(threebodyproblem) and exists y(morethan(y, onemillion) and sold(threebodyproblem,y))
# aboutfuture(threebodyproblem)
# *** Conclusion:
#  aboutfuture(threebodyproblem)
# *** Premises-CLIF:
#  forall x ((book(x) and writtenby(x, cixinliu)) implies exists y(morethan(y, onemillion) and sold(x,y)))
# exists x (won(x, hugoaward) and book(x) and writtenby(x, cixinliu))
# forall x ((book(x) and aboutfuture(x)) implies fowardlooking(x))
# book(threebodyproblem) and exists y(morethan(y, onemillion) and sold(threebodyproblem,y))
# aboutfuture(threebodyproblem)
# *** Conclusion-CLIF:
#  aboutfuture(threebodyproblem)
# *** True Label:
#  T
# *** Predicted Label:
#  T
# *** Premises:
#  forall x ((book(x) and writtenby(x, cixinliu)) implies exists y(morethan(y, onemillion) and sold(x,y)))
# exists x (won(x, hugoaward) and book(x) and writtenby(x, cixinliu))
# forall x ((book(x) and aboutfuture(x)) implies fowardlooking(x))
# book(threebodyproblem) and exists y(morethan(y, onemillion) and sold(threebodyproblem,y))
# aboutfuture(threebodyproblem)
# *** Conclusion:
#  writtenby(threebodyproblem, cixinliu)
# *** Premises-CLIF:
#  forall x ((book(x) and writtenby(x, cixinliu)) implies exists y(morethan(y, onemillion) and sold(x,y)))
# exists x (won(x, hugoaward) and book(x) and writtenby(x, cixinliu))
# forall x ((book(x) and aboutfuture(x)) implies fowardlooking(x))
# book(threebodyproblem) and exists y(morethan(y, onemillion) and sold(threebodyproblem,y))
# aboutfuture(threebodyproblem)
# *** Conclusion-CLIF:
#  writtenby(threebodyproblem, cixinliu)
# *** True Label:
#  U
# *** Predicted Label:
#  T
# *** Premises:
#  forall x (easy(x) implies exists y (lessthan(y, percent20) and acrate(x,y)))
# forall x (recommended(x) implies easy(x))
# forall x (easy(x) xor hard(x))
# forall x (starred(x)) implies hard(x))
# recommended(twosum)
# starred(foursum)
# *** Conclusion:
#  easy(twosum)
# *** Premises-CLIF:
#  forall x (easy(x) implies exists y (lessthan(y, percent20) and acrate(x,y)))
# forall x (recommended(x) implies easy(x))
# forall x (easy(x) xor hard(x))
# forall x (starred(x)) implies hard(x))
# recommended(twosum)
# starred(foursum)
# *** Conclusion-CLIF:
#  easy(twosum)
# *** True Label:
#  T
# *** Predicted Label:
#  T
# *** Premises:
#  forall x (easy(x) implies exists y (lessthan(y, percent20) and acrate(x,y)))
# forall x (recommended(x) implies easy(x))
# forall x (easy(x) xor hard(x))
# forall x (starred(x)) implies hard(x))
# recommended(twosum)
# starred(foursum)
# *** Conclusion:
#  recommended(foursum)
# *** Premises-CLIF:
#  forall x (easy(x) implies exists y (lessthan(y, percent20) and acrate(x,y)))
# forall x (recommended(x) implies easy(x))
# forall x (easy(x) xor hard(x))
# forall x (starred(x)) implies hard(x))
# recommended(twosum)
# starred(foursum)
# *** Conclusion-CLIF:
#  recommended(foursum)
# *** True Label:
#  F
# *** Predicted Label:
#  T
# *** Premises:
#  forall x (easy(x) implies exists y (lessthan(y, percent20) and acrate(x,y)))
# forall x (recommended(x) implies easy(x))
# forall x (easy(x) xor hard(x))
# forall x (starred(x)) implies hard(x))
# recommended(twosum)
# starred(foursum)
# *** Conclusion:
#  exists y(greaterthan(y, percent20) and acrate(2sum,y))
# *** Premises-CLIF:
#  forall x (easy(x) implies exists y (lessthan(y, percent20) and acrate(x,y)))
# forall x (recommended(x) implies easy(x))
# forall x (easy(x) xor hard(x))
# forall x (starred(x)) implies hard(x))
# recommended(twosum)
# starred(foursum)
# *** Conclusion-CLIF:
#  exists y(greaterthan(y, percent20) and acrate(2sum,y))
# *** True Label:
#  F
# *** Predicted Label:
#  T
# *** Premises:
#  forall x (philateliclit(x) implies (stamp(x) or periodical(x) or auction(x) or book(x) or bibliography(x) or background(x)))
# not stamp(mort)
# not (periodical(mort) or auction(mort) or bibliography(mort) or background(mort))
# philateliclit(mort)
# *** Conclusion:
#  background(mort)
# *** Premises-CLIF:
#  forall x (philateliclit(x) implies (stamp(x) or periodical(x) or auction(x) or book(x) or bibliography(x) or background(x)))
# not stamp(mort)
# not (periodical(mort) or auction(mort) or bibliography(mort) or background(mort))
# philateliclit(mort)
# *** Conclusion-CLIF:
#  background(mort)
# *** True Label:
#  F
# *** Predicted Label:
#  T
# *** Premises:
#  forall x (philateliclit(x) implies (stamp(x) or periodical(x) or auction(x) or book(x) or bibliography(x) or background(x)))
# not stamp(mort)
# not (periodical(mort) or auction(mort) or bibliography(mort) or background(mort))
# philateliclit(mort)
# *** Conclusion:
#  philateliclit(eragon)
# *** Premises-CLIF:
#  forall x (philateliclit(x) implies (stamp(x) or periodical(x) or auction(x) or book(x) or bibliography(x) or background(x)))
# not stamp(mort)
# not (periodical(mort) or auction(mort) or bibliography(mort) or background(mort))
# philateliclit(mort)
# *** Conclusion-CLIF:
#  philateliclit(eragon)
# *** True Label:
#  U
# *** Predicted Label:
#  T
# *** Premises:
#  exists x exists y (mammal(x) and mammal(y) and (not (x=y)) and have(x, teeth) and have(y, teeth))
# not have(platypus, teeth)
# mammal(platypus)
# have(humans, teeth)
# *** Conclusion:
#  mammal(platypus) and (not have(platypus, teeth))
# *** Premises-CLIF:
#  exists x exists y (mammal(x) and mammal(y) and (not (x=y)) and have(x, teeth) and have(y, teeth))
# not have(platypus, teeth)
# mammal(platypus)
# have(humans, teeth)
# *** Conclusion-CLIF:
#  mammal(platypus) and (not have(platypus, teeth))
# *** True Label:
#  T
# *** Predicted Label:
#  T
# *** Premises:
#  exists x exists y (mammal(x) and mammal(y) and (not (x=y)) and have(x, teeth) and have(y, teeth))
# not have(platypus, teeth)
# mammal(platypus)
# have(humans, teeth)
# *** Conclusion:
#  reptile(platypus)
# *** Premises-CLIF:
#  exists x exists y (mammal(x) and mammal(y) and (not (x=y)) and have(x, teeth) and have(y, teeth))
# not have(platypus, teeth)
# mammal(platypus)
# have(humans, teeth)
# *** Conclusion-CLIF:
#  reptile(platypus)
# *** True Label:
#  U
# *** Predicted Label:
#  T
# *** Premises:
#  exists x exists y (mammal(x) and mammal(y) and (not (x=y)) and have(x, teeth) and have(y, teeth))
# not have(platypus, teeth)
# mammal(platypus)
# have(humans, teeth)
# *** Conclusion:
#  mammal(humans)
# *** Premises-CLIF:
#  exists x exists y (mammal(x) and mammal(y) and (not (x=y)) and have(x, teeth) and have(y, teeth))
# not have(platypus, teeth)
# mammal(platypus)
# have(humans, teeth)
# *** Conclusion-CLIF:
#  mammal(humans)
# *** True Label:
#  U
# *** Predicted Label:
#  T
# *** Premises:
#  districtin(xiufeng, guilin) and districtin(xiangshan, guilin) and districtin(diecai, guilin) and districtin(qixing, guilin) and city(guilin)
# not districtin(yangshuo, guilin)
# *** Conclusion:
#  exists x (districtin(xiangshan, x) and districtin(diecai, x) and city(x))
# *** Premises-CLIF:
#  districtin(xiufeng, guilin) and districtin(xiangshan, guilin) and districtin(diecai, guilin) and districtin(qixing, guilin) and city(guilin)
# not districtin(yangshuo, guilin)
# *** Conclusion-CLIF:
#  exists x (districtin(xiangshan, x) and districtin(diecai, x) and city(x))
# *** True Label:
#  T
# *** Predicted Label:
#  T
# *** Premises:
#  districtin(xiufeng, guilin) and districtin(xiangshan, guilin) and districtin(diecai, guilin) and districtin(qixing, guilin) and city(guilin)
# not districtin(yangshuo, guilin)
# *** Conclusion:
#  districtin(xiufeng, guilin)
# *** Premises-CLIF:
#  districtin(xiufeng, guilin) and districtin(xiangshan, guilin) and districtin(diecai, guilin) and districtin(qixing, guilin) and city(guilin)
# not districtin(yangshuo, guilin)
# *** Conclusion-CLIF:
#  districtin(xiufeng, guilin)
# *** True Label:
#  T
# *** Predicted Label:
#  T
# *** Premises:
#  districtin(xiufeng, guilin) and districtin(xiangshan, guilin) and districtin(diecai, guilin) and districtin(qixing, guilin) and city(guilin)
# not districtin(yangshuo, guilin)
# *** Conclusion:
#  districtin(kowloon, hongkong)
# *** Premises-CLIF:
#  districtin(xiufeng, guilin) and districtin(xiangshan, guilin) and districtin(diecai, guilin) and districtin(qixing, guilin) and city(guilin)
# not districtin(yangshuo, guilin)
# *** Conclusion-CLIF:
#  districtin(kowloon, hongkong)
# *** True Label:
#  U
# *** Predicted Label:
#  T
# *** Premises:
#  musicsupervisor(jasonkramer) and american(jasonkramer)
# exists x exists y (american(x) and musicsupervisor(x) and radiopersonality(x) and (not (x=y)) and american(y) and musicsupervisor(y) and radiopersonality(y))
# forall x forall y((hostshowon(x, y) and publicradiostation(x)) implies radiopersonality(x))
# radiopersonality(joerogan)
# exists x(hostshowon(jasonkramer, x) and publicradiostation(x))
# *** Conclusion:
#  american(joerogan)
# *** Premises-CLIF:
#  musicsupervisor(jasonkramer) and american(jasonkramer)
# exists x exists y (american(x) and musicsupervisor(x) and radiopersonality(x) and (not (x=y)) and american(y) and musicsupervisor(y) and radiopersonality(y))
# forall x forall y((hostshowon(x, y) and publicradiostation(x)) implies radiopersonality(x))
# radiopersonality(joerogan)
# exists x(hostshowon(jasonkramer, x) and publicradiostation(x))
# *** Conclusion-CLIF:
#  american(joerogan)
# *** True Label:
#  U
# *** Predicted Label:
#  T
# *** Premises:
#  musicsupervisor(jasonkramer) and american(jasonkramer)
# exists x exists y (american(x) and musicsupervisor(x) and radiopersonality(x) and (not (x=y)) and american(y) and musicsupervisor(y) and radiopersonality(y))
# forall x forall y((hostshowon(x, y) and publicradiostation(x)) implies radiopersonality(x))
# radiopersonality(joerogan)
# exists x(hostshowon(jasonkramer, x) and publicradiostation(x))
# *** Conclusion:
#  musicsupervisor(jasonkramer)
# *** Premises-CLIF:
#  musicsupervisor(jasonkramer) and american(jasonkramer)
# exists x exists y (american(x) and musicsupervisor(x) and radiopersonality(x) and (not (x=y)) and american(y) and musicsupervisor(y) and radiopersonality(y))
# forall x forall y((hostshowon(x, y) and publicradiostation(x)) implies radiopersonality(x))
# radiopersonality(joerogan)
# exists x(hostshowon(jasonkramer, x) and publicradiostation(x))
# *** Conclusion-CLIF:
#  musicsupervisor(jasonkramer)
# *** True Label:
#  T
# *** Predicted Label:
#  T
# *** Premises:
#  musicsupervisor(jasonkramer) and american(jasonkramer)
# exists x exists y (american(x) and musicsupervisor(x) and radiopersonality(x) and (not (x=y)) and american(y) and musicsupervisor(y) and radiopersonality(y))
# forall x forall y((hostshowon(x, y) and publicradiostation(x)) implies radiopersonality(x))
# radiopersonality(joerogan)
# exists x(hostshowon(jasonkramer, x) and publicradiostation(x))
# *** Conclusion:
#  radiopersonality(jasonkramer)
# *** Premises-CLIF:
#  musicsupervisor(jasonkramer) and american(jasonkramer)
# exists x exists y (american(x) and musicsupervisor(x) and radiopersonality(x) and (not (x=y)) and american(y) and musicsupervisor(y) and radiopersonality(y))
# forall x forall y((hostshowon(x, y) and publicradiostation(x)) implies radiopersonality(x))
# radiopersonality(joerogan)
# exists x(hostshowon(jasonkramer, x) and publicradiostation(x))
# *** Conclusion-CLIF:
#  radiopersonality(jasonkramer)
# *** True Label:
#  T
# *** Predicted Label:
#  T
# *** Premises:
#  village(gasteren) and province(drenthe) and in(gasteren, drenthe)
# province(drenthe) and in(drenthe, netherlands)
# forall x (city(x) implies not village(x))
# exists x (population(x, num155) and village(x) and in(x, drenthe))
# *** Conclusion:
#  village(gasteren) and in(gasteren, netherlands)
# *** Premises-CLIF:
#  village(gasteren) and province(drenthe) and in(gasteren, drenthe)
# province(drenthe) and in(drenthe, netherlands)
# forall x (city(x) implies not village(x))
# exists x (population(x, num155) and village(x) and in(x, drenthe))
# *** Conclusion-CLIF:
#  village(gasteren) and in(gasteren, netherlands)
# *** True Label:
#  U
# *** Predicted Label:
#  T
# *** Premises:
#  village(gasteren) and province(drenthe) and in(gasteren, drenthe)
# province(drenthe) and in(drenthe, netherlands)
# forall x (city(x) implies not village(x))
# exists x (population(x, num155) and village(x) and in(x, drenthe))
# *** Conclusion:
#  city(gasteren)
# *** Premises-CLIF:
#  village(gasteren) and province(drenthe) and in(gasteren, drenthe)
# province(drenthe) and in(drenthe, netherlands)
# forall x (city(x) implies not village(x))
# exists x (population(x, num155) and village(x) and in(x, drenthe))
# *** Conclusion-CLIF:
#  city(gasteren)
# *** True Label:
#  F
# *** Predicted Label:
#  T
# *** Premises:
#  village(gasteren) and province(drenthe) and in(gasteren, drenthe)
# province(drenthe) and in(drenthe, netherlands)
# forall x (city(x) implies not village(x))
# exists x (population(x, num155) and village(x) and in(x, drenthe))
# *** Conclusion:
#  population(gasteren, num155)
# *** Premises-CLIF:
#  village(gasteren) and province(drenthe) and in(gasteren, drenthe)
# province(drenthe) and in(drenthe, netherlands)
# forall x (city(x) implies not village(x))
# exists x (population(x, num155) and village(x) and in(x, drenthe))
# *** Conclusion-CLIF:
#  population(gasteren, num155)
# *** True Label:
#  U
# *** Predicted Label:
#  T
# *** Premises:
#  movie(endgame) and released(endgame, yr2006)
# setin(endgame, washington)
# not (filmedin(endgame, washington))
# exists xexists y(filmedin(x, newyork) and (not (x=y)) and filmedin(y, newyork))
# directed(andychang, endgame)
# from(andychang, hongkong)
# *** Conclusion:
#  filmedin(endgame, newyork)
# *** Premises-CLIF:
#  movie(endgame) and released(endgame, yr2006)
# setin(endgame, washington)
# not (filmedin(endgame, washington))
# exists xexists y(filmedin(x, newyork) and (not (x=y)) and filmedin(y, newyork))
# directed(andychang, endgame)
# from(andychang, hongkong)
# *** Conclusion-CLIF:
#  filmedin(endgame, newyork)
# *** True Label:
#  U
# *** Predicted Label:
#  T
# *** Premises:
#  movie(endgame) and released(endgame, yr2006)
# setin(endgame, washington)
# not (filmedin(endgame, washington))
# exists xexists y(filmedin(x, newyork) and (not (x=y)) and filmedin(y, newyork))
# directed(andychang, endgame)
# from(andychang, hongkong)
# *** Conclusion:
#  forall x (not (directed(x, endgame) and from(x, hongkong)))
# *** Premises-CLIF:
#  movie(endgame) and released(endgame, yr2006)
# setin(endgame, washington)
# not (filmedin(endgame, washington))
# exists xexists y(filmedin(x, newyork) and (not (x=y)) and filmedin(y, newyork))
# directed(andychang, endgame)
# from(andychang, hongkong)
# *** Conclusion-CLIF:
#  forall x (not (directed(x, endgame) and from(x, hongkong)))
# *** True Label:
#  F
# *** Predicted Label:
#  T
# *** Premises:
#  movie(endgame) and released(endgame, yr2006)
# setin(endgame, washington)
# not (filmedin(endgame, washington))
# exists xexists y(filmedin(x, newyork) and (not (x=y)) and filmedin(y, newyork))
# directed(andychang, endgame)
# from(andychang, hongkong)
# *** Conclusion:
#  forall x (directed(andychang, x) implies not (filmedin(x, washington)))
# *** Premises-CLIF:
#  movie(endgame) and released(endgame, yr2006)
# setin(endgame, washington)
# not (filmedin(endgame, washington))
# exists xexists y(filmedin(x, newyork) and (not (x=y)) and filmedin(y, newyork))
# directed(andychang, endgame)
# from(andychang, hongkong)
# *** Conclusion-CLIF:
#  forall x (directed(andychang, x) implies not (filmedin(x, washington)))
# *** True Label:
#  U
# *** Predicted Label:
#  T
# *** Premises:
#  proposed(justinkruger, naivecynicism) and exists y (colleagueofjustinkruger(y) and proposed(y, naivecynicism))
# colleagues(thomasgilovich, justinkruger)
# philosophyofmind(naivecynicism)
# *** Conclusion:
#  proposed(thomasgilovich, naivecynicism)
# *** Premises-CLIF:
#  proposed(justinkruger, naivecynicism) and exists y (colleagueofjustinkruger(y) and proposed(y, naivecynicism))
# colleagues(thomasgilovich, justinkruger)
# philosophyofmind(naivecynicism)
# *** Conclusion-CLIF:
#  proposed(thomasgilovich, naivecynicism)
# *** True Label:
#  U
# *** Predicted Label:
#  T
# *** Premises:
#  proposed(justinkruger, naivecynicism) and exists y (colleagueofjustinkruger(y) and proposed(y, naivecynicism))
# colleagues(thomasgilovich, justinkruger)
# philosophyofmind(naivecynicism)
# *** Conclusion:
#  exists x (proposed(justinkruger, x) and philosophyofmind(x))
# *** Premises-CLIF:
#  proposed(justinkruger, naivecynicism) and exists y (colleagueofjustinkruger(y) and proposed(y, naivecynicism))
# colleagues(thomasgilovich, justinkruger)
# philosophyofmind(naivecynicism)
# *** Conclusion-CLIF:
#  exists x (proposed(justinkruger, x) and philosophyofmind(x))
# *** True Label:
#  T
# *** Predicted Label:
#  T
# *** Premises:
#  proposed(justinkruger, naivecynicism) and exists y (colleagueofjustinkruger(y) and proposed(y, naivecynicism))
# colleagues(thomasgilovich, justinkruger)
# philosophyofmind(naivecynicism)
# *** Conclusion:
#  exists x (workedon(thomasgilovich, x) and philosophyofmind(x))
# *** Premises-CLIF:
#  proposed(justinkruger, naivecynicism) and exists y (colleagueofjustinkruger(y) and proposed(y, naivecynicism))
# colleagues(thomasgilovich, justinkruger)
# philosophyofmind(naivecynicism)
# *** Conclusion-CLIF:
#  exists x (workedon(thomasgilovich, x) and philosophyofmind(x))
# *** True Label:
#  U
# *** Predicted Label:
#  T
# *** Premises:
#  worldleadinglightingdesigner(hughvanstone)
# from(hughvanstone, unitedkingdom)
# exists x(greaterthan(x, num160) and litproductions(hughvanstone,x))
# exists x(hometown(hughvanstone,x) and attendedschoolin(hughvanstone,x))
# *** Conclusion:
#  worldleadinglightingdesigner(hughvanstone) and from(hughvanstone, unitedkingdom)
# *** Premises-CLIF:
#  worldleadinglightingdesigner(hughvanstone)
# from(hughvanstone, unitedkingdom)
# exists x(greaterthan(x, num160) and litproductions(hughvanstone,x))
# exists x(hometown(hughvanstone,x) and attendedschoolin(hughvanstone,x))
# *** Conclusion-CLIF:
#  worldleadinglightingdesigner(hughvanstone) and from(hughvanstone, unitedkingdom)
# *** True Label:
#  T
# *** Predicted Label:
#  T
# *** Premises:
#  worldleadinglightingdesigner(hughvanstone)
# from(hughvanstone, unitedkingdom)
# exists x(greaterthan(x, num160) and litproductions(hughvanstone,x))
# exists x(hometown(hughvanstone,x) and attendedschoolin(hughvanstone,x))
# *** Conclusion:
#  exists x(greaterthan(x, num170) and litproductions(hughvanstone,x))
# *** Premises-CLIF:
#  worldleadinglightingdesigner(hughvanstone)
# from(hughvanstone, unitedkingdom)
# exists x(greaterthan(x, num160) and litproductions(hughvanstone,x))
# exists x(hometown(hughvanstone,x) and attendedschoolin(hughvanstone,x))
# *** Conclusion-CLIF:
#  exists x(greaterthan(x, num170) and litproductions(hughvanstone,x))
# *** True Label:
#  U
# *** Predicted Label:
#  T
# *** Premises:
#  worldleadinglightingdesigner(hughvanstone)
# from(hughvanstone, unitedkingdom)
# exists x(greaterthan(x, num160) and litproductions(hughvanstone,x))
# exists x(hometown(hughvanstone,x) and attendedschoolin(hughvanstone,x))
# *** Conclusion:
#  attendedschoolin(hughvanstone, unitedstates)
# *** Premises-CLIF:
#  worldleadinglightingdesigner(hughvanstone)
# from(hughvanstone, unitedkingdom)
# exists x(greaterthan(x, num160) and litproductions(hughvanstone,x))
# exists x(hometown(hughvanstone,x) and attendedschoolin(hughvanstone,x))
# *** Conclusion-CLIF:
#  attendedschoolin(hughvanstone, unitedstates)
# *** True Label:
#  U
# *** Predicted Label:
#  T
# *** Premises:
#  bornin(josephkmak, napa)
# professionalbaseballplayer(josephkmak)
# forall x (professionalbaseballplayer(x) implies playinmlb(x))
# forall x (bornin(x, california) implies nationality(x, american))
# forall x (nationality(x, american)implies not nationality(x, german))
# *** Conclusion:
#  nationality(josephkmak, german)
# *** Premises-CLIF:
#  bornin(josephkmak, napa)
# professionalbaseballplayer(josephkmak)
# forall x (professionalbaseballplayer(x) implies playinmlb(x))
# forall x (bornin(x, california) implies nationality(x, american))
# forall x (nationality(x, american)implies not nationality(x, german))
# *** Conclusion-CLIF:
#  nationality(josephkmak, german)
# *** True Label:
#  U
# *** Predicted Label:
#  T
# *** Premises:
#  bornin(josephkmak, napa)
# professionalbaseballplayer(josephkmak)
# forall x (professionalbaseballplayer(x) implies playinmlb(x))
# forall x (bornin(x, california) implies nationality(x, american))
# forall x (nationality(x, american)implies not nationality(x, german))
# *** Conclusion:
#  playinmlb(josephkmak)
# *** Premises-CLIF:
#  bornin(josephkmak, napa)
# professionalbaseballplayer(josephkmak)
# forall x (professionalbaseballplayer(x) implies playinmlb(x))
# forall x (bornin(x, california) implies nationality(x, american))
# forall x (nationality(x, american)implies not nationality(x, german))
# *** Conclusion-CLIF:
#  playinmlb(josephkmak)
# *** True Label:
#  T
# *** Predicted Label:
#  T
# *** Premises:
#  bornin(josephkmak, napa)
# professionalbaseballplayer(josephkmak)
# forall x (professionalbaseballplayer(x) implies playinmlb(x))
# forall x (bornin(x, california) implies nationality(x, american))
# forall x (nationality(x, american)implies not nationality(x, german))
# *** Conclusion:
#  iscatcher(josephkmak)
# *** Premises-CLIF:
#  bornin(josephkmak, napa)
# professionalbaseballplayer(josephkmak)
# forall x (professionalbaseballplayer(x) implies playinmlb(x))
# forall x (bornin(x, california) implies nationality(x, american))
# forall x (nationality(x, american)implies not nationality(x, german))
# *** Conclusion-CLIF:
#  iscatcher(josephkmak)
# *** True Label:
#  U
# *** Predicted Label:
#  T
# *** Premises:
#  bornin(rafanadal, mallorca)
# professionaltennisplayer(rafanadal)
# highwinratio(rafanadal)
# forall x ((professionaltennisplayer(x) and inbig3(x)) implies highwinratio(x))
# *** Conclusion:
#  not bornin(rafanadal, mallorca)
# *** Premises-CLIF:
#  bornin(rafanadal, mallorca)
# professionaltennisplayer(rafanadal)
# highwinratio(rafanadal)
# forall x ((professionaltennisplayer(x) and inbig3(x)) implies highwinratio(x))
# *** Conclusion-CLIF:
#  not bornin(rafanadal, mallorca)
# *** True Label:
#  F
# *** Predicted Label:
#  T
# *** Premises:
#  bornin(rafanadal, mallorca)
# professionaltennisplayer(rafanadal)
# highwinratio(rafanadal)
# forall x ((professionaltennisplayer(x) and inbig3(x)) implies highwinratio(x))
# *** Conclusion:
#  inbig3(rafanadal)
# *** Premises-CLIF:
#  bornin(rafanadal, mallorca)
# professionaltennisplayer(rafanadal)
# highwinratio(rafanadal)
# forall x ((professionaltennisplayer(x) and inbig3(x)) implies highwinratio(x))
# *** Conclusion-CLIF:
#  inbig3(rafanadal)
# *** True Label:
#  U
# *** Predicted Label:
#  T
# *** Premises:
#  bornin(rafanadal, mallorca)
# professionaltennisplayer(rafanadal)
# highwinratio(rafanadal)
# forall x ((professionaltennisplayer(x) and inbig3(x)) implies highwinratio(x))
# *** Conclusion:
#  greatestofalltime(rafanadal)
# *** Premises-CLIF:
#  bornin(rafanadal, mallorca)
# professionaltennisplayer(rafanadal)
# highwinratio(rafanadal)
# forall x ((professionaltennisplayer(x) and inbig3(x)) implies highwinratio(x))
# *** Conclusion-CLIF:
#  greatestofalltime(rafanadal)
# *** True Label:
#  U
# *** Predicted Label:
#  T
# *** Premises:
#  forall x ((doesolympicsport(x) and goestoolympicgames(x)) implies olympian(x))
# doesolympicsport(carlosreyes)
# goestoolympicgames(carlosreyes)
# welterweight(carlosreyes)
# forall x (welterweight(x) implies not  heavyweight(x))
# *** Conclusion:
#  olympian(carlosreyes)
# *** Premises-CLIF:
#  forall x ((doesolympicsport(x) and goestoolympicgames(x)) implies olympian(x))
# doesolympicsport(carlosreyes)
# goestoolympicgames(carlosreyes)
# welterweight(carlosreyes)
# forall x (welterweight(x) implies not  heavyweight(x))
# *** Conclusion-CLIF:
#  olympian(carlosreyes)
# *** True Label:
#  T
# *** Predicted Label:
#  T
# *** Premises:
#  forall x ((doesolympicsport(x) and goestoolympicgames(x)) implies olympian(x))
# doesolympicsport(carlosreyes)
# goestoolympicgames(carlosreyes)
# welterweight(carlosreyes)
# forall x (welterweight(x) implies not  heavyweight(x))
# *** Conclusion:
#  heavyweight(carlosreyes)
# *** Premises-CLIF:
#  forall x ((doesolympicsport(x) and goestoolympicgames(x)) implies olympian(x))
# doesolympicsport(carlosreyes)
# goestoolympicgames(carlosreyes)
# welterweight(carlosreyes)
# forall x (welterweight(x) implies not  heavyweight(x))
# *** Conclusion-CLIF:
#  heavyweight(carlosreyes)
# *** True Label:
#  F
# *** Predicted Label:
#  T
# *** Premises:
#  forall x ((doesolympicsport(x) and goestoolympicgames(x)) implies olympian(x))
# doesolympicsport(carlosreyes)
# goestoolympicgames(carlosreyes)
# welterweight(carlosreyes)
# forall x (welterweight(x) implies not  heavyweight(x))
# *** Conclusion:
#  wonolympicmedal(carlosreyes)
# *** Premises-CLIF:
#  forall x ((doesolympicsport(x) and goestoolympicgames(x)) implies olympian(x))
# doesolympicsport(carlosreyes)
# goestoolympicgames(carlosreyes)
# welterweight(carlosreyes)
# forall x (welterweight(x) implies not  heavyweight(x))
# *** Conclusion-CLIF:
#  wonolympicmedal(carlosreyes)
# *** True Label:
#  U
# *** Predicted Label:
#  T
# *** Premises:
#  israpper(tyga)
# forall x forall y ((israpper(x) and releasedalbum(x, y)) implies israpalbum(y))
# releasedalbum(tyga, welldone3)
# forall x (israpper(x) implies not isoperasinger(x))
# *** Conclusion:
#  israpalbum(welldone3)
# *** Premises-CLIF:
#  israpper(tyga)
# forall x forall y ((israpper(x) and releasedalbum(x, y)) implies israpalbum(y))
# releasedalbum(tyga, welldone3)
# forall x (israpper(x) implies not isoperasinger(x))
# *** Conclusion-CLIF:
#  israpalbum(welldone3)
# *** True Label:
#  T
# *** Predicted Label:
#  T
# *** Premises:
#  israpper(tyga)
# forall x forall y ((israpper(x) and releasedalbum(x, y)) implies israpalbum(y))
# releasedalbum(tyga, welldone3)
# forall x (israpper(x) implies not isoperasinger(x))
# *** Conclusion:
#  isoperasinger(tyga)
# *** Premises-CLIF:
#  israpper(tyga)
# forall x forall y ((israpper(x) and releasedalbum(x, y)) implies israpalbum(y))
# releasedalbum(tyga, welldone3)
# forall x (israpper(x) implies not isoperasinger(x))
# *** Conclusion-CLIF:
#  isoperasinger(tyga)
# *** True Label:
#  F
# *** Predicted Label:
#  T
# *** Premises:
#  israpper(tyga)
# forall x forall y ((israpper(x) and releasedalbum(x, y)) implies israpalbum(y))
# releasedalbum(tyga, welldone3)
# forall x (israpper(x) implies not isoperasinger(x))
# *** Conclusion:
#  isworthlistening(welldone3)
# *** Premises-CLIF:
#  israpper(tyga)
# forall x forall y ((israpper(x) and releasedalbum(x, y)) implies israpalbum(y))
# releasedalbum(tyga, welldone3)
# forall x (israpper(x) implies not isoperasinger(x))
# *** Conclusion-CLIF:
#  isworthlistening(welldone3)
# *** True Label:
#  U
# *** Predicted Label:
#  T
# *** Premises:
#  forall x (sevendistinctworks(x) implies heptalogy(x))
# sevendistinctworks(harrypotter)
# sevendistinctworks(chroniclesofnarnia)
# *** Conclusion:
#  heptalogy(harrypotter)
# *** Premises-CLIF:
#  forall x (sevendistinctworks(x) implies heptalogy(x))
# sevendistinctworks(harrypotter)
# sevendistinctworks(chroniclesofnarnia)
# *** Conclusion-CLIF:
#  heptalogy(harrypotter)
# *** True Label:
#  T
# *** Predicted Label:
#  T
# *** Premises:
#  forall x (sevendistinctworks(x) implies heptalogy(x))
# sevendistinctworks(harrypotter)
# sevendistinctworks(chroniclesofnarnia)
# *** Conclusion:
#  not heptalogy(chroniclesofnarnia)
# *** Premises-CLIF:
#  forall x (sevendistinctworks(x) implies heptalogy(x))
# sevendistinctworks(harrypotter)
# sevendistinctworks(chroniclesofnarnia)
# *** Conclusion-CLIF:
#  not heptalogy(chroniclesofnarnia)
# *** True Label:
#  F
# *** Predicted Label:
#  F
# *** Premises:
#  forall x (sevendistinctworks(x) implies heptalogy(x))
# sevendistinctworks(harrypotter)
# sevendistinctworks(chroniclesofnarnia)
# *** Conclusion:
#  heptalogy(lordofrings)
# *** Premises-CLIF:
#  forall x (sevendistinctworks(x) implies heptalogy(x))
# sevendistinctworks(harrypotter)
# sevendistinctworks(chroniclesofnarnia)
# *** Conclusion-CLIF:
#  heptalogy(lordofrings)
# *** True Label:
#  U
# *** Predicted Label:
#  T
# *** Premises:
#  museum(metropolitanmuseumofart) and in(metropolitanmuseumofart, nyc)
# museum(whitneymuseumofamericanart) and in(metropolitanmuseumofart, nyc)
# museum(museumofmodernart) and in(museumofmodernart, nyc)
# include(metropolitanmuseumofart, byzantineart) and include(metropolitanmuseumofart, islamicart)
# include(whitneymuseumofamericanart, americanart)
# *** Conclusion:
#  exists x (museum(x) and in(x, nyc) and include(x, byzantineart) and include(x, islamicart))
# *** Premises-CLIF:
#  museum(metropolitanmuseumofart) and in(metropolitanmuseumofart, nyc)
# museum(whitneymuseumofamericanart) and in(metropolitanmuseumofart, nyc)
# museum(museumofmodernart) and in(museumofmodernart, nyc)
# include(metropolitanmuseumofart, byzantineart) and include(metropolitanmuseumofart, islamicart)
# include(whitneymuseumofamericanart, americanart)
# *** Conclusion-CLIF:
#  exists x (museum(x) and in(x, nyc) and include(x, byzantineart) and include(x, islamicart))
# *** True Label:
#  T
# *** Predicted Label:
#  T
# *** Premises:
#  museum(metropolitanmuseumofart) and in(metropolitanmuseumofart, nyc)
# museum(whitneymuseumofamericanart) and in(metropolitanmuseumofart, nyc)
# museum(museumofmodernart) and in(museumofmodernart, nyc)
# include(metropolitanmuseumofart, byzantineart) and include(metropolitanmuseumofart, islamicart)
# include(whitneymuseumofamericanart, americanart)
# *** Conclusion:
#  exists x (museum(x) and in(x, nyc) and include(x, americanart))
# *** Premises-CLIF:
#  museum(metropolitanmuseumofart) and in(metropolitanmuseumofart, nyc)
# museum(whitneymuseumofamericanart) and in(metropolitanmuseumofart, nyc)
# museum(museumofmodernart) and in(museumofmodernart, nyc)
# include(metropolitanmuseumofart, byzantineart) and include(metropolitanmuseumofart, islamicart)
# include(whitneymuseumofamericanart, americanart)
# *** Conclusion-CLIF:
#  exists x (museum(x) and in(x, nyc) and include(x, americanart))
# *** True Label:
#  T
# *** Predicted Label:
#  T
# *** Premises:
#  museum(metropolitanmuseumofart) and in(metropolitanmuseumofart, nyc)
# museum(whitneymuseumofamericanart) and in(metropolitanmuseumofart, nyc)
# museum(museumofmodernart) and in(museumofmodernart, nyc)
# include(metropolitanmuseumofart, byzantineart) and include(metropolitanmuseumofart, islamicart)
# include(whitneymuseumofamericanart, americanart)
# *** Conclusion:
#  exists x (museum(x) and in(x, nyc) and include(x, greekart))
# *** Premises-CLIF:
#  museum(metropolitanmuseumofart) and in(metropolitanmuseumofart, nyc)
# museum(whitneymuseumofamericanart) and in(metropolitanmuseumofart, nyc)
# museum(museumofmodernart) and in(museumofmodernart, nyc)
# include(metropolitanmuseumofart, byzantineart) and include(metropolitanmuseumofart, islamicart)
# include(whitneymuseumofamericanart, americanart)
# *** Conclusion-CLIF:
#  exists x (museum(x) and in(x, nyc) and include(x, greekart))
# *** True Label:
#  U
# *** Predicted Label:
#  T
# *** Premises:
#  produce(whitetown, yourwoman) and onepersonband(whitetown)
# peak(yourwoman, uksingleschart)
# forall x ((exists y(peak(x, y))) implies popular(x))
# peak(yourwoman, iceland) and peak(yourwoman, israel) and peak(yourwoman, spain)
# *** Conclusion:
#  popular(yourwoman)
# *** Premises-CLIF:
#  produce(whitetown, yourwoman) and onepersonband(whitetown)
# peak(yourwoman, uksingleschart)
# ...
# produces(paramount, tintin)
# adventurefilm(tintin)
# *** Conclusion-CLIF:
#  exists x (childrensfilm(x) and produces(paramount, x))
# *** True Label:
#  U
# *** Predicted Label:
#  T
# *** Premises:
#  dramafilm(adventuresofrusty) and childrensfilm(adventuresofrusty)
# produces(columbiapictures, adventuresofrusty)
# produces(paramount, tintin)
# adventurefilm(tintin)
# *** Conclusion:
#  exists x (adventurefilm(x) and produces(paramount, x))
# *** Premises-CLIF:
#  dramafilm(adventuresofrusty) and childrensfilm(adventuresofrusty)
# produces(columbiapictures, adventuresofrusty)
# produces(paramount, tintin)
# adventurefilm(tintin)
# *** Conclusion-CLIF:
#  exists x (adventurefilm(x) and produces(paramount, x))
# *** True Label:
#  T
# *** Predicted Label:
#  T
# *** Premises:
#  cricketeer(royrichardson) and playsfor(royrichardson, sintmaarten) and constituentcountry(sintmaarten)
# righthanded(royrichardson) and batsman(royrichardson) and mediumpacebowler(royrichardson)
# oldatdebut(royrichardson)
# dismisses(shervillehuggins, royrichardson)
# *** Conclusion:
#  forall x forall y ((consituentcountry(y) and playedfor(x, y)) implies  not dismissed(shervillehuggins, x))
# *** Premises-CLIF:
#  cricketeer(royrichardson) and playsfor(royrichardson, sintmaarten) and constituentcountry(sintmaarten)
# righthanded(royrichardson) and batsman(royrichardson) and mediumpacebowler(royrichardson)
# oldatdebut(royrichardson)
# dismisses(shervillehuggins, royrichardson)
# *** Conclusion-CLIF:
#  forall x forall y ((consituentcountry(y) and playedfor(x, y)) implies  not dismissed(shervillehuggins, x))
# *** True Label:
#  F
# *** Predicted Label:
#  T
# *** Premises:
#  cricketeer(royrichardson) and playsfor(royrichardson, sintmaarten) and constituentcountry(sintmaarten)
# righthanded(royrichardson) and batsman(royrichardson) and mediumpacebowler(royrichardson)
# oldatdebut(royrichardson)
# dismisses(shervillehuggins, royrichardson)
# *** Conclusion:
#  forall x ((righthanded(x) and mediumpacebowler(x)) implies not playedfor(x, sintmaarten))
# *** Premises-CLIF:
#  cricketeer(royrichardson) and playsfor(royrichardson, sintmaarten) and constituentcountry(sintmaarten)
# righthanded(royrichardson) and batsman(royrichardson) and mediumpacebowler(royrichardson)
# oldatdebut(royrichardson)
# dismisses(shervillehuggins, royrichardson)
# *** Conclusion-CLIF:
#  forall x ((righthanded(x) and mediumpacebowler(x)) implies not playedfor(x, sintmaarten))
# *** True Label:
#  F
# *** Predicted Label:
#  T
# *** Premises:
#  village(ainderbyquernhow) and civilparish(ainderbyquernhow) and in(ainderbyquernhow, hambletondistrict)
# in(hambletondistrict, northyorkshire)
# in(northyorkshire, england)
# forall x forall y forall z ((in(x, y) and in(y, z)) implies in(x, z))
# *** Conclusion:
#  exists x (village(x) and in(x, england))
# *** Premises-CLIF:
#  village(ainderbyquernhow) and civilparish(ainderbyquernhow) and in(ainderbyquernhow, hambletondistrict)
# in(hambletondistrict, northyorkshire)
# in(northyorkshire, england)
# forall x forall y forall z ((in(x, y) and in(y, z)) implies in(x, z))
# *** Conclusion-CLIF:
#  exists x (village(x) and in(x, england))
# *** True Label:
#  T
# *** Predicted Label:
#  T
# *** Premises:
#  village(ainderbyquernhow) and civilparish(ainderbyquernhow) and in(ainderbyquernhow, hambletondistrict)
# in(hambletondistrict, northyorkshire)
# in(northyorkshire, england)
# forall x forall y forall z ((in(x, y) and in(y, z)) implies in(x, z))
# *** Conclusion:
#  not (exists x (civilparish(x) and in(x, england)))
# *** Premises-CLIF:
#  village(ainderbyquernhow) and civilparish(ainderbyquernhow) and in(ainderbyquernhow, hambletondistrict)
# in(hambletondistrict, northyorkshire)
# in(northyorkshire, england)
# forall x forall y forall z ((in(x, y) and in(y, z)) implies in(x, z))
# *** Conclusion-CLIF:
#  not (exists x (civilparish(x) and in(x, england)))
# *** True Label:
#  F
# *** Predicted Label:
#  F
# *** Premises:
#  televisionseries(diray) and policeprocedural(diray)
# creates(maya, diray) and writes(maya, diray)
# produces(jed, diray)
# british(maya) and british(jed)
# *** Conclusion:
#  exists x (british(x) and creates(x, diray))
# *** Premises-CLIF:
#  televisionseries(diray) and policeprocedural(diray)
# creates(maya, diray) and writes(maya, diray)
# produces(jed, diray)
# british(maya) and british(jed)
# *** Conclusion-CLIF:
#  exists x (british(x) and creates(x, diray))
# *** True Label:
#  T
# *** Predicted Label:
#  T
# *** Premises:
#  televisionseries(diray) and policeprocedural(diray)
# creates(maya, diray) and writes(maya, diray)
# produces(jed, diray)
# british(maya) and british(jed)
# *** Conclusion:
#  exists x exists y(british(x) and televisionseries(y) and produces(x, y))
# *** Premises-CLIF:
#  televisionseries(diray) and policeprocedural(diray)
# creates(maya, diray) and writes(maya, diray)
# produces(jed, diray)
# british(maya) and british(jed)
# *** Conclusion-CLIF:
#  exists x exists y(british(x) and televisionseries(y) and produces(x, y))
# *** True Label:
#  T
# *** Predicted Label:
#  T
# *** Premises:
#  professionalwrestlingstable(diamondmine) and in(diamondmine, wwe)
# leads(roderickstrong, diamondmine)
# includes(diamondmine, creedbrothers) and includes(diamondmine, ivynile)
# feuds(imperium, diamondmine)
# *** Conclusion:
#  exists x (leads(roderickstrong, x) and professionalwrestlingstable(x))
# *** Premises-CLIF:
#  professionalwrestlingstable(diamondmine) and in(diamondmine, wwe)
# leads(roderickstrong, diamondmine)
# includes(diamondmine, creedbrothers) and includes(diamondmine, ivynile)
# feuds(imperium, diamondmine)
# *** Conclusion-CLIF:
#  exists x (leads(roderickstrong, x) and professionalwrestlingstable(x))
# *** True Label:
#  T
# *** Predicted Label:
#  T
# *** Premises:
#  professionalwrestlingstable(diamondmine) and in(diamondmine, wwe)
# leads(roderickstrong, diamondmine)
# includes(diamondmine, creedbrothers) and includes(diamondmine, ivynile)
# feuds(imperium, diamondmine)
# *** Conclusion:
#  leads(roderickstrong, creedbrothers)
# *** Premises-CLIF:
#  professionalwrestlingstable(diamondmine) and in(diamondmine, wwe)
# leads(roderickstrong, diamondmine)
# includes(diamondmine, creedbrothers) and includes(diamondmine, ivynile)
# feuds(imperium, diamondmine)
# *** Conclusion-CLIF:
#  leads(roderickstrong, creedbrothers)
# *** True Label:
#  U
# *** Predicted Label:
#  T
# *** Premises:
#  professionalwrestlingstable(diamondmine) and in(diamondmine, wwe)
# leads(roderickstrong, diamondmine)
# includes(diamondmine, creedbrothers) and includes(diamondmine, ivynile)
# feuds(imperium, diamondmine)
# *** Conclusion:
#  forall x ((professionalwrestlingstable(x) and includes(x, ivynile)) implies not feuds(imperium, x))
# *** Premises-CLIF:
#  professionalwrestlingstable(diamondmine) and in(diamondmine, wwe)
# leads(roderickstrong, diamondmine)
# includes(diamondmine, creedbrothers) and includes(diamondmine, ivynile)
# feuds(imperium, diamondmine)
# *** Conclusion-CLIF:
#  forall x ((professionalwrestlingstable(x) and includes(x, ivynile)) implies not feuds(imperium, x))
# *** True Label:
#  F
# *** Predicted Label:
#  T
# *** Premises:
#  bornin(deborahwallace, scotland) and actress(deborahwallace) and playwright(deborahwallace) and producer(deborahwallace)
# play(psyche) and basedon(psyche, lifeofjamesmirandabarry)
# play(homesick) and writtenby(homesick, deborahwallace) and play(psyche) and writtenby(psyche, deborahwallace) and play(thevoid) and writtenby(thevoid, deborahwallace)
# coproduce(deborahwallace, gasland)
# *** Conclusion:
#  exists x (coproduces(x, gasland) and writtenby(homesick, x))
# *** Premises-CLIF:
#  bornin(deborahwallace, scotland) and actress(deborahwallace) and playwright(deborahwallace) and producer(deborahwallace)
# play(psyche) and basedon(psyche, lifeofjamesmirandabarry)
# play(homesick) and writtenby(homesick, deborahwallace) and play(psyche) and writtenby(psyche, deborahwallace) and play(thevoid) and writtenby(thevoid, deborahwallace)
# coproduce(deborahwallace, gasland)
# *** Conclusion-CLIF:
#  exists x (coproduces(x, gasland) and writtenby(homesick, x))
# *** True Label:
#  T
# *** Predicted Label:
#  T
# *** Premises:
#  bornin(deborahwallace, scotland) and actress(deborahwallace) and playwright(deborahwallace) and producer(deborahwallace)
# play(psyche) and basedon(psyche, lifeofjamesmirandabarry)
# play(homesick) and writtenby(homesick, deborahwallace) and play(psyche) and writtenby(psyche, deborahwallace) and play(thevoid) and writtenby(thevoid, deborahwallace)
# coproduce(deborahwallace, gasland)
# *** Conclusion:
#  forall x (play(x) and writtenby(x, deborahwallace) implies not basedon(x, lifeofjamesmirandabarry))
# *** Premises-CLIF:
#  bornin(deborahwallace, scotland) and actress(deborahwallace) and playwright(deborahwallace) and producer(deborahwallace)
# play(psyche) and basedon(psyche, lifeofjamesmirandabarry)
# play(homesick) and writtenby(homesick, deborahwallace) and play(psyche) and writtenby(psyche, deborahwallace) and play(thevoid) and writtenby(thevoid, deborahwallace)
# coproduce(deborahwallace, gasland)
# *** Conclusion-CLIF:
#  forall x (play(x) and writtenby(x, deborahwallace) implies not basedon(x, lifeofjamesmirandabarry))
# *** True Label:
#  F
# *** Predicted Label:
#  T
# *** Premises:
#  bornin(deborahwallace, scotland) and actress(deborahwallace) and playwright(deborahwallace) and producer(deborahwallace)
# play(psyche) and basedon(psyche, lifeofjamesmirandabarry)
# play(homesick) and writtenby(homesick, deborahwallace) and play(psyche) and writtenby(psyche, deborahwallace) and play(thevoid) and writtenby(thevoid, deborahwallace)
# coproduce(deborahwallace, gasland)
# *** Conclusion:
#  play(gasland)
# *** Premises-CLIF:
#  bornin(deborahwallace, scotland) and actress(deborahwallace) and playwright(deborahwallace) and producer(deborahwallace)
# play(psyche) and basedon(psyche, lifeofjamesmirandabarry)
# play(homesick) and writtenby(homesick, deborahwallace) and play(psyche) and writtenby(psyche, deborahwallace) and play(thevoid) and writtenby(thevoid, deborahwallace)
# coproduce(deborahwallace, gasland)
# *** Conclusion-CLIF:
#  play(gasland)
# *** True Label:
#  U
# *** Predicted Label:
#  T
# *** Premises:
#  american(maggiefriedman) and screenwriter(maggiefriedman) and producer(maggiefriedman)
# showrunnerof(maggiefriedman, witchesofeastend) and executiveproducerof(maggiefriedman, witchesofeastend) and lifetimetelevisionseries(maggiefriedman)
# fantasydrama(witchesofeastend) and series(witchesofeastend)
# produces(maggiefriedman, eastwick) and develops(maggiefriedman, eastwick)
# series(eastwick) and airedon(eastwick, abc)
# *** Conclusion:
#  exists x exists y (series(x) and airedon(x, abc) and develops(y, x) and showrunnerof(y, witchesofeastend))
# *** Premises-CLIF:
#  american(maggiefriedman) and screenwriter(maggiefriedman) and producer(maggiefriedman)
# showrunnerof(maggiefriedman, witchesofeastend) and executiveproducerof(maggiefriedman, witchesofeastend) and lifetimetelevisionseries(maggiefriedman)
# fantasydrama(witchesofeastend) and series(witchesofeastend)
# produces(maggiefriedman, eastwick) and develops(maggiefriedman, eastwick)
# series(eastwick) and airedon(eastwick, abc)
# *** Conclusion-CLIF:
#  exists x exists y (series(x) and airedon(x, abc) and develops(y, x) and showrunnerof(y, witchesofeastend))
# *** True Label:
#  T
# *** Predicted Label:
#  T
# *** Premises:
#  american(maggiefriedman) and screenwriter(maggiefriedman) and producer(maggiefriedman)
# showrunnerof(maggiefriedman, witchesofeastend) and executiveproducerof(maggiefriedman, witchesofeastend) and lifetimetelevisionseries(maggiefriedman)
# fantasydrama(witchesofeastend) and series(witchesofeastend)
# produces(maggiefriedman, eastwick) and develops(maggiefriedman, eastwick)
# series(eastwick) and airedon(eastwick, abc)
# *** Conclusion:
#  forall x (series(x) and airedon(x, abc) and exists y(showrunnerof(y, witchesofeastend)) implies not develops(y, x))
# *** Premises-CLIF:
#  american(maggiefriedman) and screenwriter(maggiefriedman) and producer(maggiefriedman)
# showrunnerof(maggiefriedman, witchesofeastend) and executiveproducerof(maggiefriedman, witchesofeastend) and lifetimetelevisionseries(maggiefriedman)
# fantasydrama(witchesofeastend) and series(witchesofeastend)
# produces(maggiefriedman, eastwick) and develops(maggiefriedman, eastwick)
# series(eastwick) and airedon(eastwick, abc)
# *** Conclusion-CLIF:
#  forall x (series(x) and airedon(x, abc) and exists y(showrunnerof(y, witchesofeastend)) implies not develops(y, x))
# *** True Label:
#  F
# *** Predicted Label:
#  T
# *** Premises:
#  american(maggiefriedman) and screenwriter(maggiefriedman) and producer(maggiefriedman)
# showrunnerof(maggiefriedman, witchesofeastend) and executiveproducerof(maggiefriedman, witchesofeastend) and lifetimetelevisionseries(maggiefriedman)
# fantasydrama(witchesofeastend) and series(witchesofeastend)
# produces(maggiefriedman, eastwick) and develops(maggiefriedman, eastwick)
# series(eastwick) and airedon(eastwick, abc)
# *** Conclusion:
#  develops(maggiefriedman, witchesofeastend)
# *** Premises-CLIF:
#  american(maggiefriedman) and screenwriter(maggiefriedman) and producer(maggiefriedman)
# showrunnerof(maggiefriedman, witchesofeastend) and executiveproducerof(maggiefriedman, witchesofeastend) and lifetimetelevisionseries(maggiefriedman)
# fantasydrama(witchesofeastend) and series(witchesofeastend)
# produces(maggiefriedman, eastwick) and develops(maggiefriedman, eastwick)
# series(eastwick) and airedon(eastwick, abc)
# *** Conclusion-CLIF:
#  develops(maggiefriedman, witchesofeastend)
# *** True Label:
#  U
# *** Predicted Label:
#  T
# *** Premises:
#  largecomplex(shafaq-asiman) and largecomplex(shafaq-asiman) and offshore(shafaq-asiman) and geologicalstructures(shafaq-asiman) and in(shafaq-asiman, caspiansea)
# northwestof(baku, shafaq-asiman)
# forall x forall y (northwestof(x, y) implies southeastof(y, x))
# *** Conclusion:
#  southeastof(baku, shafaq-asiman)
# *** Premises-CLIF:
#  largecomplex(shafaq-asiman) and largecomplex(shafaq-asiman) and offshore(shafaq-asiman) and geologicalstructures(shafaq-asiman) and in(shafaq-asiman, caspiansea)
# northwestof(baku, shafaq-asiman)
# forall x forall y (northwestof(x, y) implies southeastof(y, x))
# *** Conclusion-CLIF:
#  southeastof(baku, shafaq-asiman)
# *** True Label:
#  U
# *** Predicted Label:
#  T
# *** Premises:
#  largecomplex(shafaq-asiman) and largecomplex(shafaq-asiman) and offshore(shafaq-asiman) and geologicalstructures(shafaq-asiman) and in(shafaq-asiman, caspiansea)
# northwestof(baku, shafaq-asiman)
# forall x forall y (northwestof(x, y) implies southeastof(y, x))
# *** Conclusion:
#  exists x (largecomplex(x) and southeastof(x, baku))
# *** Premises-CLIF:
#  largecomplex(shafaq-asiman) and largecomplex(shafaq-asiman) and offshore(shafaq-asiman) and geologicalstructures(shafaq-asiman) and in(shafaq-asiman, caspiansea)
# northwestof(baku, shafaq-asiman)
# forall x forall y (northwestof(x, y) implies southeastof(y, x))
# *** Conclusion-CLIF:
#  exists x (largecomplex(x) and southeastof(x, baku))
# *** True Label:
#  T
# *** Predicted Label:
#  T
# *** Premises:
#  largecomplex(shafaq-asiman) and largecomplex(shafaq-asiman) and offshore(shafaq-asiman) and geologicalstructures(shafaq-asiman) and in(shafaq-asiman, caspiansea)
# northwestof(baku, shafaq-asiman)
# forall x forall y (northwestof(x, y) implies southeastof(y, x))
# *** Conclusion:
#  forall x (geologicalstructures(x) and offshore(x) implies not northwestof(baku, x))
# *** Premises-CLIF:
#  largecomplex(shafaq-asiman) and largecomplex(shafaq-asiman) and offshore(shafaq-asiman) and geologicalstructures(shafaq-asiman) and in(shafaq-asiman, caspiansea)
# northwestof(baku, shafaq-asiman)
# forall x forall y (northwestof(x, y) implies southeastof(y, x))
# *** Conclusion-CLIF:
#  forall x (geologicalstructures(x) and offshore(x) implies not northwestof(baku, x))
# *** True Label:
#  F
# *** Predicted Label:
#  T
# Classification Report:               precision    recall  f1-score   support
#
#            F       0.84      0.38      0.52        69
#            T       0.44      0.98      0.61       122
#            U       0.00      0.00      0.00       110
#
#     accuracy                           0.48       301
#    macro avg       0.43      0.45      0.38       301
# weighted avg       0.37      0.48      0.37       301
#
# *************** INFERENCE COMPLETE ***************

# %%
# output results
print("***** ACCURACY *****")
print(acc_metric)
print("***** PRECISION *****")
print(pr_metric)
print("***** RECALL *****")
print(re_metric)
print("***** F1 *****")
print(f_metric)
eval_metrics_df
# Out:
# ***** ACCURACY *****
# 0.48172757475083056
# ***** PRECISION *****
# 0.4264834727200319
# ***** RECALL *****
# 0.4507404767561574
# ***** F1 *****
# 0.3757142857142857
#    Accuracy  Precision   Recall        F1
# 0  0.481728   0.426483  0.45074  0.375714

# %%
# empty torch cuda cache
torch.cuda.empty_cache()

# delete model from cpu
del(model)
