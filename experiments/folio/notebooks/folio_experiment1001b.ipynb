# %%
'''
task: classify syllogism validity with CLIF notation
models: gemma-2-2b-it
dataset: folio
evaluation: zero-shot + sef
'''
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# benchmark experiment runtime
# !pip install ipython-autotime
# %load_ext autotime
# Out:
# Collecting ipython-autotime
#   Downloading ipython_autotime-0.3.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: ipython in /usr/local/lib/python3.12/dist-packages (from ipython-autotime) (7.34.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-autotime) (75.2.0)
# Collecting jedi>=0.16 (from ipython->ipython-autotime)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-autotime) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-autotime) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-autotime) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-autotime) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-autotime) (2.20.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-autotime) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-autotime) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-autotime) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython->ipython-autotime) (0.8.6)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython->ipython-autotime) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->ipython-autotime) (0.6.0)
# Downloading ipython_autotime-0.3.2-py2.py3-none-any.whl (7.0 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 21.7 MB/s eta 0:00:00
# Installing collected packages: jedi, ipython-autotime
# Successfully installed ipython-autotime-0.3.2 jedi-0.19.2
# time: 256 µs (started: 2026-04-20 06:41:45 +00:00)

# %%
# start preparing for QA pipeline
! pip install -U accelerate
! pip install -U transformers
# !pip install transformers
# !pip install evaluate
# Out:
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.13.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from accelerate) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (26.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate) (6.0.3)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (2.10.0+cu128)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (1.10.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate) (0.7.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (0.28.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (4.67.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.0.0->accelerate) (1.5.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (0.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.3)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub>=0.21.0->accelerate) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub>=0.21.0->accelerate) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub>=0.21.0->accelerate) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub>=0.21.0->accelerate) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub>=0.21.0->accelerate) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub>=0.21.0->accelerate) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface_hub>=0.21.0->accelerate) (0.1.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.0.0)
# Collecting transformers
#   Downloading transformers-5.5.4-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (1.10.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers) (0.1.2)
# Downloading transformers-5.5.4-py3-none-any.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 69.9 MB/s eta 0:00:00
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
# Successfully installed transformers-5.5.4
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.5.4)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (1.10.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers) (0.1.2)
# Collecting evaluate
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (4.0.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.0.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.32.4)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.12/dist-packages (from evaluate) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from evaluate) (3.6.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (1.10.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from evaluate) (26.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (3.25.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (18.1.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (3.13.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2026.2.25)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2026.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.23.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.7.0->evaluate) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.7.0->evaluate) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.7.0->evaluate) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.7.0->evaluate) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.7.0->evaluate) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.7.0->evaluate) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.7.0->evaluate) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub>=0.7.0->evaluate) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub>=0.7.0->evaluate) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub>=0.7.0->evaluate) (0.1.2)
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 3.5 MB/s eta 0:00:00
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.6
# time: 29.1 s (started: 2026-04-20 06:41:45 +00:00)

# %%
import pandas as pd

folio_train_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/folio/data/folio_kr_gold_train_sef.csv")
folio_test_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/folio/data/folio_kr_gold_test_sef.csv")
folio_val_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/folio/data/folio_kr_gold_valid_sef.csv")
# merge splits into one dataframe
folio_df = pd.concat([folio_train_df, folio_test_df, folio_val_df], ignore_index=True, sort=False)
# check if merge worked
print("*** TRAIN SPLIT LEN:", len(folio_train_df))
print("*** TEST SPLIT LEN:", len(folio_test_df))
print("*** VALIDATION SPLIT LEN:", len(folio_val_df))
print("*** MERGED SPLIT LEN:", len(folio_df))
# Out:
# *** TRAIN SPLIT LEN: 800
# *** TEST SPLIT LEN: 201
# *** VALIDATION SPLIT LEN: 203
# *** MERGED SPLIT LEN: 1204
# time: 1.7 s (started: 2026-04-20 06:42:14 +00:00)

# %%
# evaluation metrics

import numpy as np
import re
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report

def predict_answer(model, tokenizer, obj, subject, sef, ref_relation=None, source_knowledge=None):
  # define sef categories
  sef_disjunctive = r"""
  A disjunctive syllogism contains "∨" or "⊕". Here is an example:
  <PREMISES>forall x (kid(x) implies young(x))
forall x (toddler(x) implies kid(x))
forall x (young(x) implies not elderly(x))
forall x (pirate(x) implies seafarer(x))
not pirate(nancy) implies young(nancy)
not toddler(nancy) implies seafarer(nancy)</PREMISES>
  <CONCLUSION>not (pirate(nancy) xor toddler(nancy))</CONCLUSION>
  """

  sef_complex = r"""
  A complex syllogism has more than 2 premises. Here is an example:
  <PREMISES>woncup(aberdeen, year2013final)
woncup(rangers, year2014final)
not (aberdeen=rangers)
forall x forall y forall z forall w (not (x=y) and woncup(x, z) and woncup(y, w) implies not (z=w))</PREMISES>
  <CONCLUSION>exists x (woncup(aberdeen, x))</CONCLUSION>
  """

  sef_categorical = r"""
  A categorical syllogism contains any word from the list ["all", "any", "some", "no", "few", "most", "none", "several"]. Here is an example:
  <PREMISES>unincorporatedcommunity(ordinary)
locatedin(ordinary, elliotcounty) and on(ordinary, kentuckyroute32)
locatednorthwestof(ordinary, sandyhook)</PREMISES>
  <CONCLUSION>exists x (unincorporatedcommunity(x) and locatedin(x, elliotcounty))</CONCLUSION>
  """

  sef_hypothetical = r"""
  A hypothetical syllogism is not disjunctive, complex or categorical. Here is an example:
  <PREMISES>forall x (homework(x) implies not fun(x))
exists x (reading(x) and homework(x))</PREMISES>
  <CONCLUSION>exists x (reading(x) and fun(x))</CONCLUSION>
  """

  sef_categories = dict()
  sef_categories["disjunctive"] = sef_disjunctive
  sef_categories["complex"] = sef_complex
  sef_categories["categorical"] = sef_categorical
  sef_categories["hypothetical"] = sef_hypothetical

  # define notation grammar
  grammar = r"""
    start: program
    program: [stat]+
    stat: proposition newline | keyword* quantifier* symbol* leftparen* (quantifier symbol)* proposition rightparen* newline | keyword* (quantifier symbol)* leftparen* (quantifier symbol)* proposition rightparen* newline
    proposition: atomicproposition | complexproposition
    complexproposition: keyword* proposition keyword leftparen* (quantifier symbol)* proposition rightparen*
    atomicproposition: leftparen* term* leftparen* term* rightparen*
    # !term: (LETTER+) (LETTER+|DIGIT+|"=" | "+" | "-" | "," | "≠")* | (DIGIT+) (LETTER+|DIGIT+|"=" | "+" | "-" | "," | "≠")*
    # !leftparen: "("
    # !rightparen: ")"
    # !keyword: "and" | "not" | "implies" | "or" | "xor" | "implies" | "implies"
    # !quantifier: "exists" | "forall"
    symbol: LETTER
    newline: /\n/

    # %import common.LETTER
    # %import common.DIGIT
    # %import common.INT -> NUMBER
    # %import common.ESCAPED_STRING -> STRING
    # %import common.WS
    # %ignore WS
"""
  # prepare prompt
  rag_prompt = f"""
  <start_of_turn>user
  You are an expert logician. You are given a syllogism in CLIF with premises between <PREMISES></PREMISES> and conclusion between <CONCLUSION></CONCLUSION> tags.
  The CLIF BNF grammar to understand and reason in the language is given in the <GRAMMAR></GRAMMAR> tags.
  <GRAMMAR>{grammar}</GRAMMAR>
  <PREMISES>{subject}</PREMISES>
  <CONCLUSION>{obj}</CONCLUSION>
  You are also given the category of the syllogism to help you understand it: {sef_categories[sef]}.
  Classify the conclusion as "True" if true, "False" if false or "Uncertain" if uncertain based on the premises. Present your answer only between <output></output> tags.
  <end_of_turn>
  <start_of_turn>model
  """
  input_ids = tokenizer(rag_prompt, return_tensors="pt").to(model.device)
  response = model.generate(**input_ids, max_new_tokens=500)
  predicted_relation = tokenizer.decode(response[0])
  matches = re.findall('<output>(.*)</output>', predicted_relation, flags=re.DOTALL)
  res = re.findall(r"<output>(.*)", matches[-1])  # from ['</output> tags.\n  <end_of_turn>\n  <start_of_turn>model\n  <output>T'] to ['T']
  predicted_label = res[0] if res else "None" # take first element from list ['T'] to get 'T'

  print("*** Premises: \n", subject)
  print("*** Conclusion: \n", obj)
  print("*** True Label: \n", ref_relation)
  print("*** Predicted Label: \n", predicted_label)
  return predicted_label
# Out:
# time: 1.08 s (started: 2026-04-20 06:42:16 +00:00)

# %%
def infer_from_ontology(dataset, model, tokenizer, mode='default', notation='NL'):
  evaluation_metrics_df = pd.DataFrame(columns=["Accuracy", "Precision", "Recall", "F1"])
  reference_labels = []
  predicted_labels = []
  for index, row in dataset.iterrows():
      if notation == "NL":
        conclusion = row["conclusion"]
        premises = row["premises"]
      else:
        conclusion = row["conclusion-" + notation]
        premises = row["premises-" + notation]
      sef_category = row["sef"]
      label = row["label"]
      if mode.lower() == "grammar":
        # conduct query with RAG retrival of sources
        # set number of candidate answers to consider as half the total triple store axioms
        source_information = """BNF GRAMMAR"""
        print("*** RAG INFORMATION:", source_information)
      # predict answer with model
      predicted_label = predict_answer(model, tokenizer, conclusion, premises, sef_category, label)
      reference_labels.append(label)
      predicted_labels.append(predicted_label)
  # fill evaluation metrics dataframe
  accuracy_metric = accuracy_score(reference_labels, predicted_labels)
  precision_metric = precision_score(reference_labels, predicted_labels, average="macro")
  recall_metric = recall_score(reference_labels, predicted_labels, average="macro")
  f1_metric = f1_score(reference_labels, predicted_labels, average="macro")
  evaluation_metrics_df["Accuracy"] = [accuracy_metric]
  evaluation_metrics_df["Precision"] = [precision_metric]
  evaluation_metrics_df["Recall"] = [recall_metric]
  evaluation_metrics_df["F1"] = [f1_metric]
  print("Classification Report:", classification_report(reference_labels, predicted_labels))
  print("*************** INFERENCE COMPLETE ***************")
  return reference_labels, predicted_labels, evaluation_metrics_df, accuracy_metric, precision_metric, recall_metric, f1_metric
# Out:
# time: 2.21 ms (started: 2026-04-20 06:42:17 +00:00)

# %%
import torch
import json
from tqdm import tqdm
import torch.nn as nn
from torch.optim import Adam
import nltk
import spacy
import string
import evaluate  # Bleu
from torch.utils.data import Dataset, DataLoader, RandomSampler
import pandas as pd
import numpy as np
import transformers
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from transformers import AutoTokenizer, AutoModelForCausalLM

import warnings
warnings.filterwarnings("ignore")
# Out:
# time: 20.8 s (started: 2026-04-20 06:42:17 +00:00)

# %%
# login to hugging face to have access to the model
# !pip install huggingface_hub
from huggingface_hub import notebook_login
notebook_login()
# Out:
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (1.10.1)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.67.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub) (0.16.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface_hub) (0.1.2)
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…
# time: 4.67 s (started: 2026-04-20 06:42:38 +00:00)

# %%
# try rag search with gemma
tokenizer = AutoTokenizer.from_pretrained("google/gemma-2b-it")
# CPU Enabled uncomment below 👇🏽
#model = AutoModelForCausalLM.from_pretrained("google/gemma-2b-it")
# GPU Enabled use below 👇🏽
model = AutoModelForCausalLM.from_pretrained("google/gemma-2b-it", device_map="auto")
# Out:
# config.json:   0%|          | 0.00/627 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/164 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]
# time: 20.9 s (started: 2026-04-20 06:42:55 +00:00)

# %%
# experiment: ZS prediction without Grammar
ref_labels, pred_labels, eval_metrics_df, acc_metric, pr_metric, re_metric, f_metric = infer_from_ontology(folio_df, model, tokenizer, mode='default', notation='CLIF')
# Out:
# Streaming output truncated to the last 5000 lines.
# married(katherinhafer, walterbrown)
# *** Conclusion:
#  graduatedwith(walterbrown, bachelorsofart)
# *** True Label:
#  True
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (convictedcriminal(x) and innocent(x) implies not trulyguilty(x))
# forall x (convictedcriminal(x) and not commitcrime(x) implies innocent(x))
# forall x (convictedcriminal(x) and (trulyguilty(x) or foundguilty(x)))
# forall x (convictedcriminal(x) and foundguilty(x) implies sentencedtopunishment(x))
# forall x (convictedcriminal(x) and foundguilty(x) implies canargueagainst(x, punishment))
# convictedcriminal(garry) and (not (foundguilty(garry) or sentencedtopunishment(garry)))
# *** Conclusion:
#  sentencedtopunishment(garry)
# *** True Label:
#  Uncertain
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (have(x, authorization, studyin, unitedstates) implies enrolledin(x, academicprogram))
# forall x (enrolledin(x, academicprogram) implies not work(x, fulltime))
# forall x (studyin(x, unitedstates) implies have(x, authorization, studyin, unitedstates))
# forall x (phdgraduate(x) implies work(x, fulltime))
# not studyin(x, unitedstates) implies enrolledin(x, academicprogram)
# *** Conclusion:
#  studyin(tom, unitedstates)
# *** True Label:
#  Uncertain
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (memberof(x, universityfaculty) implies professor(x))
# forall x (principalinvestigator(x) implies memberof(x, universityfaculty))
# forall x (professor(x) implies not undergraduatestudent(x))
# forall x (pursuing(x, bachelor) implies undergraduatestudent(x))
# not (pursuing(leon, bachelor) xor principalinvestigator(leon))
# not pursuing(leon, bachelor) implies professor(leon)
# *** Conclusion:
#  not undergraduatestudent(leon) and not principalinvestigator(leon)
# *** True Label:
#  True
# *** Predicted Label:
#  False
# *** Premises:
#  forall x (at(x, businessconference) implies (investor(x) xor entrepreneur(x)))
# forall x ((at(x, businessconference) and enjoy(x, opportunityofstartingownbusiness)) implies not prefer(x, plannedeconomy))
# forall x ((at(x, businessconference) and entrepreneur(x)) implies enjoy(x, opportunityofstartingownbusiness))
# forall x ((at(x, businessconference) and enjoy(x, stateownershipofmeansofproduction)) implies prefer(x, plannedeconomy))
# forall x ((at(x, businessconference) and ardentcommunist(x)) implies prefer(x, stateownershipofmeansofproduction))
# at(ho, businessconference) and prefer(ho, stateownershipofmeansofproduction)
# *** Conclusion:
#  not ardentcommunist(ho)
# *** True Label:
#  Uncertain
# *** Predicted Label:
#  False
# *** Premises:
#  exists x (song(x) and by(x, boneym,) and number1germansingle(x))
# song(hoorayhoorayitsaholiholiday) and hitallovereurope(hoorayhoorayitsaholiholiday)
# song(hoorayhoorayitsaholiholiday) and not number1germansingle(hoorayhoorayitsaholiholiday)
# forall x (peakbelowon(x, number1, germanchart) implies not number1germansingle(x))
# *** Conclusion:
#  song(hoorayhoorayitsaholiholiday) and number1germansingle(hoorayhoorayitsaholiholiday)
# *** True Label:
#  False
# *** Predicted Label:
#  True
# *** Premises:
#
# givenname(namedagfinn) and named(dagfinnaarskog, namedagfinn) and notableperson(dagfinnaarskog) and named(dagfinnbakke, namedagfinn) and notableperson(dagfinnbakke)  and named(dagfinndahl, namedagfinn) and notableperson(dagfinndahl)
# norwegian(dagfinnaarskog) and physician(dagfinnaarskog)
# norwegian(dagfinndahl) and barrister(dagfinndahl)
# *** Conclusion:
#  notableperson(dagfinnaarskog)
# *** True Label:
#  True
# *** Predicted Label:
#  True
# *** Premises:
#  island(luzon) and in(luzon, philippines)
# exists x (earthquake(x) and strikeinyr(x, year1999) and strikeinmo(x, december) and strikeincity(x, luzon))
# exists x (earthquake(x) and strikeinyr(x, year1999) and strikeinmo(x, december) and strikeincity(x, luzon) and deadly(x))
# *** Conclusion:
#  exists x exists y (earthquake(x) and strikeinyr(x, year1999) and strikeinmo(x, december) and strikeincity(x, y) and in(y, philippines))
# *** True Label:
#  True
# *** Predicted Label:
#  True
# *** Premises:
#  forall x forall y ((summerolympicsin(x,y) and in(x, unitedstates)) implies summerolympicsin(x, unitedstates))
# forall x forall y ((in(x, y) and in(y, unitedstates)) implies in(x, unitedstates))
# forall x forall y forall z ((in(x, z) and state(z) and summerolympicsin(x,y)) implies summerolympicsin(z, y))
# summerolympicsin(losangeles, yr2028)
# in(losangeles, california)
# in(atlanta, unitedstates)
# in(california, unitedstates)
# in(atlanta, georgia)
# not insummerolympicsin(boxing, yr2028) and (not insummerolympicsin(modern_pentathlon, yr2028)) and (not insummerolympicsin(weightlifting, yr2028))
# summerolympicsin(atlanta, yr1996)
# *** Conclusion:
#  summerolympicsin(unitedstates, yr2028)
# *** True Label:
#  True
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (human(x) and canturninto(x, wolf) implies werewolf(x))
# forall x exists y (werewolf(x) implies (bittenby(x, y) or scratchedby(x, y)) and werewolf(y))
# forall x exists y (bittenby(x, y) or scratchedby(x, y)) implies attackedby(x,y)
# *** Conclusion:
#  forall x (werewolf(x) implies wolf(x))
# *** True Label:
#  Uncertain
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (not cleanoften(x, home) implies not have(x, tidyhouse))
# forall x (not prioritize(x, cleaning) implies not cleanoften(x, home))
# forall x (hire(x, maid) or hire(x, cleaningservice) implies have(x, tidyhouse))
# forall x (not careabout(x, cleanliness) implies not prioritize(x, cleaning))
# not (hire(x, maid) or hire(x, cleaningservice)) xor not cleanoften(jack, home))
# *** Conclusion:
#  have(jack, tidyhouse)
# *** True Label:
#  Uncertain
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (believein(x, santaclaus) xor thinkmadeup(x, santaclaus))
# forall x (believein(x, santaclaus) implies expect(x, present, christmasmorning))
# forall x (thinkmadeup(x, santaclaus) implies wouldbesurprisedtoseein(x, santaclaus, house))
# forall x (expect(x, present, christmasmorning) implies excitedfor(x, christmas))
# forall x (wouldbesurprisedtoseein(x, santaclaus, house) implies not leaveout(x, cookies))
# not (expect(marcy, present, christmasmorning) and excitedfor(marcy, christmas) and believein(marcy, santaclaus))
# *** Conclusion:
#  not (leaveout(marcy, cookies) and thinkmadeup(marcy, santaclaus)) or believein(marcy, santaclaus)
# *** True Label:
#  False
# *** Predicted Label:
#  True
# *** Premises:
#  prehistoric(ambiortus) and birdgenus(ambiortus)
# forall x(knownspeciesof(x, ambiortus) implies isspecies(x, ambiortusdementjevi))
# livein(ambiortusdementjevi, mongolia)
# discover(yevgenykurochkin, ambiortus)
# *** Conclusion:
#  exists x (knownspeciesof(x, ambiortus) and not livein(x, mongolia))
# *** True Label:
#  False
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (cancer(x) implies have(x, mutation))
# forall x (have(x, mutation) implies not canbetreatedathome(x))
# forall x (colorectalcancer(x) implies cancer(x))
# forall x (cold(x) implies canbetreatedathome(x))
# not (cold(arthritis) xor have(arthritis, mutation))
# *** Conclusion:
#  not colorectalcancer(arthritis)
# *** True Label:
#  True
# *** Predicted Label:
#  False
# *** Premises:
#  forall x (inurbanarea(x) implies not mansionhouse(x))
# forall x (skyscraper(x) implies inurbanarea(x))
# forall x (creepyhauntedhouse(x) implies mansionhouse(x))
# forall x (terrifyingbuilding(x) and onhalloween(x) implies creepyhauntedhouse(x))
# creepyhauntedhouse(lalauriehouse) or terrifyingbuilding(lalauriehouse) and onhalloween(lalauriehouse)
# *** Conclusion:
#  skyscraper(lalauriehouse) xor mansionhouse(lalauriehouse) implies not (creepyhauntedhouse(lalauriehouse) or terrifyingbuilding(lalauriehouse) and onhalloween(lalauriehouse))
# *** True Label:
#  False
# *** Predicted Label:
#  True
# *** Premises:
#  british(williamdickinson) and politician(williamdickinson) and satin(williamdickinson, houseofcommons)
# attended(williamdickinson, westminsterschool) and highschool(westminsterschool) and attended(williamdickinson, universityofedinburgh)
# university(universityofedinburgh) and locatedin(universityofedinburgh, unitedkingdom)
# supported(williamdickinson, portlandwhigs)
# forall x (supported(x, portlandwhigs) implies not satin(x, parliament))
# *** Conclusion:
#  exists x exists y (attended(williamdickinson, x) and highschool(x) and locatedin(x, unitedkingdom) and attended(williamdickinson, y) and university(y) and locatedin(y, unitedkingdom))
# *** True Label:
#  Uncertain
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (exists y (livein(x, y) and place(y) and named(y, galicia)) implies livein(x, spain) xor livein(x, poland))
# forall x (livein(x, spain) implies livein(x, europe))
# forall x (livein(x, poland) implies livein(x, europe))
# livein(rochelle, europe)
# not livein(dominique, europe)
# exists y (livein(alfonso, y) and place(y) and named(y, galicia))
# *** Conclusion:
#  forall x (live(alfonso, x) implies in(x, europe))
# *** True Label:
#  True
# *** Predicted Label:
#  True
# *** Premises:
#  provide(party, strawberry) and provide(party, orange) and provide(party, blueberry) and provide(party, grape) and provide(party, cherry)
# forall x (lowestweightremainingat(x, endofparty) implies mostpopular(x))
# lowestweightremainingat(strawberries, endofparty)
# lowerweightat(blueberry, cherry, endofparty)
# eat(benjamin, orange) and eat(benjamin, grape) and not eat(benjamin, blueberry) and not eat(benjamin, cherry) and not eat(benjamin, strawberry)
# *** Conclusion:
#  mostpopular(blueberry)
# *** True Label:
#  Uncertain
# *** Predicted Label:
#  True
# *** Premises:
#  forall x ((doesolympicsport(x) and goestoolympicgames(x)) implies olympian(x))
# doesolympicsport(carlosreyes)
# goestoolympicgames(carlosreyes)
# welterweight(carlosreyes)
# forall x (welterweight(x) implies not  heavyweight(x))
# *** Conclusion:
#  olympian(carlosreyes)
# *** True Label:
#  True
# *** Predicted Label:
#  True
# *** Premises:
#  producedby(luminaapv, chevrolet)
# producedby(astro, chevrolet) and van(astro)
# forall x (vehicle(x) and producedby(x, chevrolet) and inthisbatch(x) implies (car(x) xor van(x)))
# *** Conclusion:
#  van(astro)
# *** True Label:
#  True
# *** Predicted Label:
#  True
# *** Premises:
#  formerswimmer(barbaraannmarshall) and formerworldrecordholder(barbaraannmarshall)
# participatedin(barbaraannmarshall, 1972summerolympics)
# homecountry(barbaraannmarshall, unitedstates)
# forall x exists y (participatedin(x, 1972summerolympics) and homecountry(x, y) implies represented(x, y))
# participatedin(barbaraannmarshall, preliminaryheatfreestylerelay)
# not participatedin(barbaraannmarshall, finalheatfreestylerelay)
# forall x ((participatedin(x, 1972summerolympics) and relayswimmer(x) and not participatedin(x, finalheatfreestylerelay)) ↔ not recieved(x, medal)))
# *** Conclusion:
#  represented(barbaraannmarshall, unitedstates)
# *** True Label:
#  True
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (professionalathlete(x) implies spendon(x, mostoftheirtime, sports))
# forall x (olympicgoldmedalwinner(x) implies professionalathlete(x))
# forall x (fulltimescientist(x) implies not spendon(x, mostoftheirtime, sports))
# forall x (nobelphysicslaureate(x) implies fulltimescientist(x))
# spendon(amy, mostoftheirtime, sports) or olympicgoldmedalwinner(amy)
# not nobelphysicslaureate(amy) implies not olympicgoldmedalwinner(amy)
# *** Conclusion:
#  not olympicgoldmedalwinner(amy) implies nobelphysicslaureate(amy)
# *** True Label:
#  False
# *** Predicted Label:
#  False
# *** Premises:
#  forall x (model(x) and summarization(x) and onlyuseinputdocument(x) implies faithful(x))
# forall x (model(x) and extractive(x) implies model(x) and summarization(x))
# forall x (model(x) and extractive(x) implies onlyuseinputdocument(x))
# *** Conclusion:
#  forall x (model(x) and extractive(x) implies faithful(x))
# *** True Label:
#  True
# *** Predicted Label:
#  True
# *** Premises:
#  forall x ((customer(x) and in(x, jamesfamily) and subscribedto(x, amcalist)) implies  eligibleforthreefreemovieseveryweekwithoutadditionalfees(x))
# exists x exists y (customer(x) and in(x, jamesfamily) and gotoeveryweek(x, cinema) and (not (x=y)) and customer(y) and in(y, jamesfamily) and gotoeveryweek(y, cinema))
# forall x (customer(x) and in(x, jamesfamily) and (subscribedto(x, amcalist) or subscribedto(x, hbo)))
# forall x ((customer(x) and in(x, jamesfamily) and prefer(x, tvseries)) implies (not watchin(x, tv, cinema)))
# forall x ((customer(x) and in(x, jamesfamily) and  subscribedto(x, hbo)) implies prefer(x, tvseries))
# customer(lily) and in(lily, jamesfamily and watchin(lily, tv, cinema)
# *** Conclusion:
#  (eligibleforthreefreemovieseveryweekwithoutadditionalfees(lily) and watchin(lily, tv, cinema)) implies (gotoeveryweek(lily, cinema) and prefer(lily, tvseries))
# *** True Label:
#  False
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (not cleanoften(x, home) implies not have(x, tidyhouse))
# forall x (not prioritize(x, cleaning) implies not cleanoften(x, home))
# forall x (hire(x, maid) or hire(x, cleaningservice) implies have(x, tidyhouse))
# forall x (not careabout(x, cleanliness) implies not prioritize(x, cleaning))
# not (hire(x, maid) or hire(x, cleaningservice)) xor not cleanoften(jack, home))
# *** Conclusion:
#  not (not careabout(jack, cleanliness) or not cleanoften(jack, home)
# *** True Label:
#  True
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (cdplayer(x) implies delicatemechanism(x))
# forall x (delicatemechanism(x) implies not (toy(x) and suitablefor(x, children)))
# *** Conclusion:
#  exists x exists y (cdplayer(x) and cdplayer(y) and toy(x) and toy(y) and suitablefor(x, children) and suitablefor(y, children) and not (x=y))
# *** True Label:
#  Uncertain
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (have(x, corporatejob) implies not take(x, financialrisk))
# forall x (entrepreneur(x) implies take(x, financialrisk))
# forall x (riskaverse(x) implies have(x, corporatejob))
# forall x (exists y exists z (not (y=x) and not (z=x) and not (y=z) and hateworkingfor(x, y) and hateworkingfor(x, z)) implies entrepreneur(x))
# not entrepreneur(markzuckerberg) and not (exists y exists z (not (y=markzuckerberg) and not (z=markzuckerberg) and not (y=z) and hateworkingfor(markzuckerberg, y) and hateworkingfor(markzuckerberg, z))) implies not riskaverse(markzuckerberg)
# *** Conclusion:
#  riskaverse(markzuckerberg)
# *** True Label:
#  False
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (man(x) implies not runfasterthan(xm bolt))
# not man(superman)
# *** Conclusion:
#  runfasterthan(superman, bolt)
# *** True Label:
#  Uncertain
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (batterypoweredwatch(x) implies not automaticwatch(x))
# forall x (digitalwatch(x) implies batterypoweredwatch(x))
# exists x (mechanicalwatch(x) and automaticwatch(x))
# forall x (smartwatch(x) implies digitalwatch(x))
# not (digitalwatch(moonwatch) xor automaticwatch(moonwatch))
# *** Conclusion:
#  smartwatch(moonwatch) and mechanicalwatch(moonwatch) implies not mechanicalwatch(moonwatch)
# *** True Label:
#  True
# *** Predicted Label:
#  True
# *** Premises:
#  building(blakemcfallcompanybuilding) and addedtoin(blakemcfallcompanybuilding, thenationalregisterofhistoricplaces, year1990)
# building(emmetbuilding) and five-story(emmetbuilding) and locatedin(emmetbuilding, portland) and locatedin(portland, oregon))
# builtin(emmetbuilding, year1915)
# emmetbuiling=blakemcfallcompanybuilding
# workat(john, emmetbuilding)
# *** Conclusion:
#  startcurrentjobin(john, year1990)
# *** True Label:
#  Uncertain
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (thisbrand(x) and product(x) implies (producedin(x, china) xor producedin(x, us)))
# forall x ((thisbrand(x) and product(x) and producedin(x, china)) implies labeled(x))
# forall x ((thisbrand(x) and product(x) and producedin(x, us)) implies soldin(x, us))
# forall x ((thisbrand(x) and product(x) and labeled(x)) implies cheaper(x))
# forall x ((thisbrand(x) and product(x) and soldin(x, us)) implies soldin(x, walmart))
# forall x (thisbrand(x) and product(x) and displayedin(x, homepage) implies soldin(x, walmart))
# forall x (thisbrand(x) and product(x) and returnedby(x, customer) implies not soldin(x, walmart))
# product(g910) and thisbrand(g910) and (not (displayedin(g910, homepage) xor cheaper(g910)))
# *** Conclusion:
#  returnedby(g910, customer) xor soldin(g910, walmart)
# *** True Label:
#  True
# *** Predicted Label:
#  True
# *** Premises:
#  speedway(islip) and smallestracetrack(islip)
# exists x exists y (demolitionderby(x) and smallestracetrack(y) and on(x, y))
# demolished(islip) xor stillused(islip)
# forall x (speedway(x) and stillused(x) implies have(races, heldat, x))
# not have(races, heldat, islip)
# *** Conclusion:
#  stillused(islip)
# *** True Label:
#  False
# *** Predicted Label:
#  True
# *** Premises:
#  directedby(aftertiller, lanawilson) and directedby(thedeparture, lanawilson) and directedby(missamericana, lanawilson)
# forall x forall y (directedby(x, y) implies filmmaker(y))
# documentary(aftertiller)
# forall x (documentary(x) implies film(x))
# from(lanawilson, kirkland)
# in(kirkland, unitedstates)
# forall x forall y forall z ((from(x, y) and in(y, z)) implies from(x, z))
# nomination(aftertiller, theindependentspiritawardforbestdocumentary)
# *** Conclusion:
#  filmmakeraward(lanawilson, theindependentspiritawardforbestdocumentary)
# *** True Label:
#  Uncertain
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (maxlistento(x) implies (classicalmusic(x) xor rap(x)))
# forall x (maxlistento(x) and classicalmusic(x) implies song(x) and from(x, 12thcentury))
# forall x (maxlistento(x) and rap(x) implies song(x) and by(x, kanyewest))
# forall x (song(x) and by(x, kanyewest) implies song(x) and fulloflyrics(x))
# forall x (song(x) and fulloflyrics(x) implies needtobewrittenwith(x, words))
# not (classicalmusic(asitwasbyharrystyles) and song(asitwasbyharrystyles) and from(asitwasbyharrystyles, 12thcentury))
# maxlistento(asitwasbyharrystyles)
# *** Conclusion:
#  not (song(asitwasbyharrystyles) and by(asitwasbyharrystyles, kanyewest) and needtobewrittenwith(asitwasbyharrystyles, words))
# *** True Label:
#  False
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (shoe(x) implies not food(x))
# forall x (slipper(x) implies shoe(x))
# forall x (donatedto(x, homelesscharity) implies food(x) xor clothes(x))
# forall x (wearable(x) implies not edible(x))
# forall x (clothes(x) implies wearable(x))
# donatedto(watch, homelesscharify)
# not (edible(watch) and clothes(watch)) implies not (edible(watch) xor clothes(watch))
# *** Conclusion:
#  not edible(watch) and not slipper(watch)
# *** True Label:
#  True
# *** Predicted Label:
#  False
# *** Premises:
#  forall x (tiger(x) implies cat(x))
# forall x (cat(x) implies not dog(x))
# forall x (bengaltiger(x) implies tiger(x))
# forall x (husky(x) implies dog(x))
# bengaltiger(fido) xor cat(fido)
# *** Conclusion:
#  not husky(fido)
# *** True Label:
#  True
# *** Predicted Label:
#  False
# *** Premises:
#  forall x (repayontime(x) implies has(x, highcreditscore))
# exists x ((has(x, highcreditscore) and has(x, highsalary)) implies approvedfor(x, mortgage))
# has(john, highsalary)
# *** Conclusion:
#  repayontime(john) implies approvedfor(john, mortgage)
# *** True Label:
#  Uncertain
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (hodophiles(x) and enjoyeating(x, gelato) implies enjoy(x, vacationtoitaly))
# forall x (hodophiles(x) and not (exists y (resist(x, y) and hallmark(y) and delectabl(y) and dessert(y) and famousin(y, italy))))
# forall x (hodophiles(x) implies (enjoyeating(x, gelato) or lovetotraveloften(x))
# forall x (hodophiles(x) and takein(x, studyabroadsemester, europe) implies not regret(x, collegeexperience))
# forall x (hodophiles(x) and lovetotraveloften(x) implies takein(x, studyabroadsemester, europe))
# hodophiles(robert) and not (enjoyeating(robert, gelato) xor lovetotraveloften(robert))
# *** Conclusion:
#  (exists y (resist(robert, y) and hallmark(y) and delectabl(y) and dessert(y) and famousin(y, italy))) and regret(robert, collegeexperience)) implies (enjoyeating(robert, gelato) xor (enjoy(robert, vacation) and in(vacation, italy))
# *** True Label:
#  False
# *** Predicted Label:
#  True
# *** Premises:
#  japanese(koeitecmo) and videogameholdingcompany(koeitecmo) and animeholdingcompany(koeitecmo) and holdingcompany(x)
# forall x (holdingcompany(x) implies exists y(company(y) and holds(x, y)))
# disbandsin(tecmo, japan) and survives(koei) and renames(koei)
# forall x (videogameholdingcompany(x) implies holdingcompany(x))
# *** Conclusion:
#  exists x (company(x) and holds(koeitecmo, x))
# *** True Label:
#  True
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (animal(x) implies not plant(x))
# forall x (human(x) implies animal(x))
# forall x (pupil(x) implies human(x))
# forall x (flower(x) implies plant(x))
# not (human(bailey) xor flower(bailey))
# *** Conclusion:
#  pupil(bailey)
# *** True Label:
#  False
# *** Predicted Label:
#  True
# *** Premises:
#  british(james) and lawyer(james)
# whig(james) and politician(james) and satinhouseofcommons(james)
# forall x (british(x) implies european(x))
# forall x (lawyer(x) implies familiarwithlaws(x))
# exists x exists y (whig(x) and speakfrench(x)) and (not (x=y)) and (whig(y) and speakfrench(y))
# *** Conclusion:
#  exists x (european(x) and familiarwithlaws(x))
# *** True Label:
#  True
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (easy(x) implies exists y (lessthan(y, percent20) and acrate(x,y)))
# forall x (recommended(x) implies easy(x))
# forall x (easy(x) xor hard(x))
# forall x (starred(x)) implies hard(x))
# recommended(twosum)
# starred(foursum)
# *** Conclusion:
#  exists y(greaterthan(y, percent20) and acrate(2sum,y))
# *** True Label:
#  False
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (soccerplayer(x) implies have(x, leftfoot) and have(x, rightfoot))
# forall x (soccerplayer(x) and useefficiently(x, leftfoot) and useefficiently(x, rightfoot) implies topsoccerplayer(x))
# forall x (soccerplayer(x) and scoreusing(x, manygoals, leftfoot) implies useefficiently(x, leftfoot))
# forall x (soccerplayer(x) and scoreusing(x, manygoals, rightfoot) implies useefficiently(x, rightfoot))
# soccerplayer(ronaldo)
# useefficiently(ronaldo, rightfoot)
# scoreusing(ronaldo, manygoals, leftfoot)
# *** Conclusion:
#  topsoccerplayer(ronaldo)
# *** True Label:
#  True
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (soccerplayer(x) implies have(x, leftfoot) and have(x, rightfoot))
# forall x (soccerplayer(x) and useefficiently(x, leftfoot) and useefficiently(x, rightfoot) implies topsoccerplayer(x))
# forall x (soccerplayer(x) and scoreusing(x, manygoals, leftfoot) implies useefficiently(x, leftfoot))
# forall x (soccerplayer(x) and scoreusing(x, manygoals, rightfoot) implies useefficiently(x, rightfoot))
# soccerplayer(ronaldo)
# useefficiently(ronaldo, rightfoot)
# scoreusing(ronaldo, manygoals, leftfoot)
# *** Conclusion:
#  not topsoccerplayer(ronaldo)
# *** True Label:
#  False
# *** Predicted Label:
#  False
# *** Premises:
#  ownedby(sat, collegeboard) and developedby(sat, collegeboard) and not (exists y (not (y=collegeboard) and (ownedby(sat, y) or developedby(sat, y)))
# intendedtoassess(sat, studentsreadinessforcollege)
# originallydesignedtobealignedwith(sat, highschoolcurricula)
# adjustmentmadein(sat, 2016, toalignwithhighschoolcurriculum)
# *** Conclusion:
#  ownedby(sat, collegeboard) and ownedby(sat, otherthirdparties)
# *** True Label:
#  False
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (havein(x, alotofmusicdecoration, room) implies not moveouteasily(x))
# forall x (ambitious(x) implies moveouteasily(x))
# forall x (bigfanofmusic(x) implies musicdecorations(x, room))
# forall x (attendfrequently(x, musicfestival) and youngteenagegirl(x) implies bigfanofpopband(x) and bigfanofpopsinger(x))
# ambitious(sam) implies bbigfanofpopband(sam) and bigfanofpopsinger(sam)
# *** Conclusion:
#  bigfanofmusic(sam)
# *** True Label:
#  Uncertain
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (inemmasfamily(x) and upgradetoeveryyear(x, newestiphonemodel) implies not savingmoneyforon(x, downpayment, newhouse))
# forall x (inemmasfamily(x) and enjoyreading(x, techspec) and keepupdatedon(x, latesttechnology) implies upgradetoeveryyear(x, newestiphonemodel))
# forall x (inemmasfamily(x) and (savingmoneyforon(x, downpayment, newhouse) or livein(x, apartment, bigmetropolitancity)))
# forall x (inemmasfamily(x) and (exists y (livewith(x, y) and roommate(y))) implies not (exists y (own(x, y) and pet(y))))
# forall x (inemmasfamily(x) and (exists y (own(x, y) and pet(y))) implies (exists y (livewith(x, y) and roommate(y))))
# inemmasfamily(emily)
# ((exists y (own(emily, y) and roommate(y))) and livein(emily, apartment, bigmetropolitancity)) implies ((exists y (own(emily, y) and pet(y))) and livein(emily, apartment, bigmetropolitancity)) xor not ((exists y (own(emily, y) and roommate(y))) or livein(emily, apartment, bigmetropolitancity))
# *** Conclusion:
#  enjoyreading(emily, techspec) and keepupdatedon(emily, latesttechnology)
# *** True Label:
#  False
# *** Predicted Label:
#  True
# *** Premises:
#  heavycruiser(usssalem) and builtfor(usssalem, unitedstatesnavy)
# lastheavycruisertoenterservice(usssalem)
# museumship(usssalem)
# forall x (museumship(x) implies opentopublic(x))
# servedin(usssalem, atlantic) and servedin(usssalem, mediterranean)
# *** Conclusion:
#  not lastheavycruisertoenterservice(usssalem)
# *** True Label:
#  False
# *** Predicted Label:
#  False
# *** Premises:
#  forall x ((bag(x) and hermès(x)) implies not madein(x, italy))
# forall x ((bag(x) and birkin(x)) implies hermès(x))
# forall x (ferrari(x) implies madein(x, italy))
# forall x ((car(x) and carry(x, ferrariv12engine)) implies ferrrari(x))
# forall x ((car(x) and madein(x, maranello)) implies carry(x, ferrariv12engine))
# not (ferrari(lamborghinisuv) and madein(lamborghinisuv, maranello))
# (bag(kelly) and hermès(kelly)) or (bag(kelly) and car(kelly) and carry(kelly, ferrariv12engine))
# *** Conclusion:
#  madein(lamborghinisuv, italy)
# *** True Label:
#  Uncertain
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (cancer(x) implies have(x, mutation))
# forall x (have(x, mutation) implies not canbetreatedathome(x))
# forall x (colorectalcancer(x) implies cancer(x))
# forall x (cold(x) implies canbetreatedathome(x))
# not (cold(arthritis) xor have(arthritis, mutation))
# *** Conclusion:
#  canbetreatedathome(arthritis)
# *** True Label:
#  Uncertain
# *** Predicted Label:
#  True
# *** Premises:
#  surname(nameodell) and from(nameodell, odellbedfordshire)
# mistakenspellingof(nameo'dell, nameodell) and (exists xexists y(family(x) and named(x, nameo'dell) and (not (x=y)) and family(y) and named(y, nameo'dell))
# named(amyodell, nameodell) and notableperson(amyodell) and named(jackodell, nameodell) and notableperson(jackodell) and named(matsodell, nameodell) and notableperson(matsodell)
# british(amyodell) and singer(amyodell) and songwriter(amyodell)
# english(jackodell) and toyinventor(jackodell)
# *** Conclusion:
#  english(amyodell) and toyinventor(amyodell)
# *** True Label:
#  Uncertain
# *** Predicted Label:
#  True
# *** Premises:
#  musicsupervisor(jasonkramer) and american(jasonkramer)
# exists x exists y (american(x) and musicsupervisor(x) and radiopersonality(x) and (not (x=y)) and american(y) and musicsupervisor(y) and radiopersonality(y))
# forall x forall y((hostshowon(x, y) and publicradiostation(x)) implies radiopersonality(x))
# radiopersonality(joerogan)
# exists x(hostshowon(jasonkramer, x) and publicradiostation(x))
# *** Conclusion:
#  musicsupervisor(jasonkramer)
# *** True Label:
#  True
# *** Predicted Label:
#  True
# *** Premises:
#  ownedby(sat, collegeboard) and developedby(sat, collegeboard) and not (exists y (not (y=collegeboard) and (ownedby(sat, y) or developedby(sat, y)))
# intendedtoassess(sat, studentsreadinessforcollege)
# originallydesignedtobealignedwith(sat, highschoolcurricula)
# adjustmentmadein(sat, 2016, toalignwithhighschoolcurriculum)
# *** Conclusion:
#  intendedtoassess(sat, studentsmathskill)
# *** True Label:
#  Uncertain
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (plant(x) implies not cuteanimal(x))
# forall x (flower(x) implies plant(x))
# forall x (kitten(x) implies cuteanimal(x))
# forall x (grownin(x, garden) implies flower(x))
# kitten(piper) or cuteanimal(piper)
# *** Conclusion:
#  not grownin(piper, garden)
# *** True Label:
#  True
# *** Predicted Label:
#  False
# *** Premises:
#  american(imaginedragon) and rockband(imaginedragon)
# leadsinger(imaginedragon, dan)
# songwriter(dan)
# forall x forall y (leadsinger(x, y) implies singer(y))
# forall x (singer(x) implies musician(x))
# popularsingle(imaginedragon, demons)
# exists x exists y (popularsingle(imaginedragon, x) and billboardhot100(x)) and (not (x=y)) and (popularsingle(imaginedragon, y) and billboardhot100(y))
# *** Conclusion:
#  not musician(dan)
# *** True Label:
#  False
# *** Predicted Label:
#  False
# *** Premises:
#  forall x (human(x) implies capableof(x, abstractthought))
# forall x (plant(x) implies not capableof(x, abstractthought))
# forall x (multicellularcreature(x) and (autotrophic(x) or digestfoodinternally (x)) implies plant(x) xor animal(x))
# forall x (goat(x) implies animal(x))
# forall x (dirt(x) implies not animal(x))
# goat(hulu) or humanbeing(hulu)
# (multicellularcreature(hulu) and (autotrophic(hulu) or digestfoodinternally (hulu))
# *** Conclusion:
#  dirt(hulu)
# *** True Label:
#  False
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (emilysfriend(x) and publish(x, journal) implies not workin(x, entertainmentindustry))
# forall x (emilysfriend(x) and awardwinningnovelist(x) implies publish(x, journal))
# forall x (emilysfriend(x) implies workin(x, entertainmentindustry) or highlyacclaimedin(x, theirprofession))
# forall x (emilysfriend(x) and highlyacclaimedin(x, theirprofession) implies exists y (holdat(x, y, workplace) and tenured(y) and highranking(y) and position(y)))
# forall x (emilysfriend(x) and highlyacclaimedin(x, theirprofession) implies receivefrom(x, glowingfeedback, colleague) and receivefrom(x, glowingrecommendation, colleague))
# emilysfriends(taylor)
# not (highlyacclaimedin(taylor, theirprofession) and (exists y (holdat(taylor, y, workplace) and tenured(y) and highranking(y) and position(y)))
# *** Conclusion:
#  emilysfriends(taylor) and (exists y (holdat(taylor, y, workplace) and tenured(y) and highranking(y) and position(y)))
# *** True Label:
#  Uncertain
# *** Predicted Label:
#  True
# *** Premises:
#  forall x ((grownin(x, bensyard) and redfruit(x)) implies contain(x, vitaminc))
# forall x (grownin(x, bensyard) and is(x, apple) implies redfruit(x))
# forall x ((grownin(x, bensyard) and contain(x, vitaminc)) implies healthy(x))
# forall x ((grownin(x, bensyard) and healthy(x)) implies not on(x, warninglist))
# grownin(cherry, bensyard)
# not (healthy(cherry) and is(cherry, apple)) implies redfruit(cherry)
#
# *** Conclusion:
#  contain(cherry, vitaminc) xor on(cherry, warninglist)
# *** True Label:
#  True
# *** Predicted Label:
#  True
# *** Premises:
#  forall x ((fruit(x) and soldat(x, nicasmarket)) implies shippedfrom(x, colombia))
# exists x exists y (fruit(x) and soldin(x, newhaven) and shippedfrom(x, mexico) and (not (x=y)) and fruit(y) and soldin(y, newhaven) and shippedfrom(y, mexico))
# forall x ((fruit(x) and shippedfrom(x, colombia)) implies not (soldat(x, localfarmersmarket)))
# fruit(avocado) and (soldat(avocado, localfarmersmarket) or soldat(avocado, nica'smarket))
# not (shippedfrom(avocado, colombia) xor soldin(avocado, newhaven))
# *** Conclusion:
#  soldat(avocado, localfarmersmarket) xor soldin(avocado, newhaven)
# *** True Label:
#  True
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (usedin(x, labcomputer) and unixoperatingsystem(x) implies software(x))
# forall x (usedin(x, labcomputer) and macos(x) implies unixoperatingsystem(x))
# forall x (usedin(x, labcomputer) implies macos(x) xor linux(x))
# forall x (usedin(x, labcomputer) and linux(x) implies convenient(x))
# forall x (usedin(x, labcomputer) and software(x) implies writtenwithcode(x))
# forall x (usedin(x, labcomputer) and convenient(x) implies popular(x))
# usedin(burger, labcomputer) and writtenwithcode(burger) and macos(burger))
# usedin(pytorch, labcomputer) and not (linux(pytorch) xor software(pytorch))
# *** Conclusion:
#  not popular(burger)
# *** True Label:
#  Uncertain
# *** Predicted Label:
#  False
# *** Premises:
#  medication(diethylcarbamazine) and discoversin(diethylcarbamazine, yr1947)
# treats(diethylcarbamazine, riverblindness)
# preferredtreatmentfor(riverblindness, ivermectin)
# not (is(diethylcarbamazine, ivermectin))
# *** Conclusion:
#  not (preferredtreatmentfor(riverblindness, diethylcarbamazine))
# *** True Label:
#  True
# *** Predicted Label:
#  False
# *** Premises:
#  exists x exists y (employeein(x, jamesstown) and workin(x, businessanalysis) and goodat(x, math) and (not (x=y)) and employeein(y, jamesstown) and workin(y, businessanalysis) and goodat(y, math))
# forall x ((employeein(x, jamesstown) and workin(x, businessanalysis)) implies workfor(x, thiscompany))
# forall x ((employeein(x, jamesstown) and workfor(x, thiscompany)) implies not from(x, china))
# forall x (employeein(x, jamesstown) and workin(x, softwareengineering) implies from(x, china))
# employeein(leif, jamesstown) and workin(leif, softwareengineering)
# *** Conclusion:
#  not (goodat(leif, math) and workin(leif, businessanalysis))
# *** True Label:
#  False
# *** Predicted Label:
#  False
# *** Premises:
#  worldleadinglightingdesigner(hughvanstone)
# from(hughvanstone, unitedkingdom)
# exists x(greaterthan(x, num160) and litproductions(hughvanstone,x))
# exists x(hometown(hughvanstone,x) and attendedschoolin(hughvanstone,x))
# *** Conclusion:
#  attendedschoolin(hughvanstone, unitedstates)
# *** True Label:
#  Uncertain
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (take(x, barexam) implies canread(x))
# forall x (lawyer(x) implies take(x, barexam))
# forall x (take(x, barexam) implies knowledgeableabout(x, criminalproceeder))
# forall x (geton(x, scoreof180, lsat) implies canread(x))
# forall x (elephant(x) implies not canread(x))
# not (canread(mike) and elephant(mike)) implies take(mike, barexam) xor canread(mike)
# *** Conclusion:
#  take(mike, barexam)
# *** True Label:
#  False
# *** Predicted Label:
#  True
# *** Premises:
#  forall x ((lipstick(x) and in(x, rougediorset) and in(x, lunarnewyearlimitededition) and velvetfinish(x)) implies refillable(x))
# forall x ((lipstick(x) and in(x, rougediorset) and in(x, lunarnewyearlimitededition)) implies (velvetfinish(x) xor satinfinish(x))
# forall x ((lipstick(x) and in(x, rougediorset) and in(x, lunarnewyearlimitededition) and satinfinish(x)) implies not rosewoodindescription(x))
# forall x ((lipstick(x) and in(x, rougediorset) and in(x, lunarnewyearlimitededition)) implies (rosewoodindescription(x) xor not rosewoodindescription(x)))
# lipstick(rougediorcoloredlipbalm999) and in(rougediorcoloredlipbalm999, rougediorset) and in(rougediorcoloredlipbalm999, lunarnewyearlimitededition) and (rosewoodindescription(rougediorcoloredlipbalm999) xor velvetfinish(rougediorcoloredlipbalm999))
# *** Conclusion:
#  not ((lipstick(rougediorcoloredlipbalm999) and in(rougediorcoloredlipbalm999, rougediorset) and in(rougediorcoloredlipbalm999, lunarnewyearlimitededition) and velvetfinish(rougediorcoloredlipbalm999) and refillable(rougediorcoloredlipbalm999)) implies (not refillable(rougediorcoloredlipbalm999) and not rosewoodindescription(rougediorcoloredlipbalm999)))
# *** True Label:
#  True
# *** Predicted Label:
#  False
# *** Premises:
#  from(edwinsmith, newzealand) and rower(edwinsmith) and from(edwinsmith, auckland)
# edwinsmith=tedsmith
# goto(edwinsmith, roseroadprimaryschool) and locatedin(roseroadprimaryschool, greylynn)
# sergeant(edwinsmith) and servewith(edwinsmith, newzealand24thbattalion) and servein(edwinsmith, italy) and servein(edwinsmith, egypt)
# buisness(broadwaysheetmetals) and run(edwinsmith, broadwaysheetmetals) and own(edwinsmith, broadwaysheetmetals) and sheetmetalworker(edwinsmith)
# *** Conclusion:
#  forall x (sergeant(x) implies not from(x, auckland))
# *** True Label:
#  False
# *** Predicted Label:
#  True
# *** Premises:
#  exists x (bric(x) and not (x=china) and bric(china) and emerging(chinaeconomy))
# forall x (from(x, china) implies from(x, bric))
# bric(india) and emerging(indiaeconomy)
# forall x (from(x, india) implies from(x, bric))
# forall x (from(x, china) implies chinese(x))
# forall x (from(x, india) implies indian(x))
# exists x (from(x, india))
# *** Conclusion:
#  forall x (from(x, countryofbrics) implies not indianpeople(x))
# *** True Label:
#  False
# *** Predicted Label:
#  True
# *** Premises:
#  forall x ((fruit(x) and soldat(x, nicasmarket)) implies shippedfrom(x, colombia))
# exists x exists y (fruit(x) and soldin(x, newhaven) and shippedfrom(x, mexico) and (not (x=y)) and fruit(y) and soldin(y, newhaven) and shippedfrom(y, mexico))
# forall x ((fruit(x) and shippedfrom(x, colombia)) implies not (soldat(x, localfarmersmarket)))
# fruit(avocado) and (soldat(avocado, localfarmersmarket) or soldat(avocado, nica'smarket))
# not (shippedfrom(avocado, colombia) xor soldin(avocado, newhaven))
# *** Conclusion:
#  soldin(avocado, newhaven) xor soldat(x, nica'smarket)
# *** True Label:
#  False
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (havein(x, alotofmusicdecoration, room) implies not moveouteasily(x))
# forall x (ambitious(x) implies moveouteasily(x))
# forall x (bigfanofmusic(x) implies musicdecorations(x, room))
# forall x (attendfrequently(x, musicfestival) and youngteenagegirl(x) implies bigfanofpopband(x) and bigfanofpopsinger(x))
# ambitious(sam) implies bbigfanofpopband(sam) and bigfanofpopsinger(sam)
# *** Conclusion:
#  attend(sam, festival) and youngteenagegirl(sam) implies not (ambitious(sam) or (bigfanofpopband(sam) and bigfanofpopsinger(sam)))
# *** True Label:
#  True
# *** Predicted Label:
#  True
# *** Premises:
#  exists x exists y exists y exists w (game(x) and stagenumber(x,3) and stage(y) and stage(z) and stage(w) and not (y=z) and not (z=w) and not (y=w) and red(y) and yellow(z) and green(w))
# forall x (player(x) implies startred(x))
# forall x (player(x) and not reachyellow(x) implies not reachgreen(x))
# forall x (player(x) and startred(x) implies reachyellow(x))
# forall x (player(x) and startred(x) and not reachyellow(x) implies not reachgreen(x))
# *** Conclusion:
#  exists x (player(x) and completegame(x))
# *** True Label:
#  Uncertain
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (workin(x, office) implies commuter(x))
# forall x (workin(x, office) xor workfrom(x, home))
# forall x (workfrom(x, home) implies have(x, relaxedschedule))
# commuter(george) xor have(george, homeoffice)
# (workfrom(george, home) xor have(george, homeoffice)) implies not workfrom(george, home) and commuter(george)
# *** Conclusion:
#  workfrom(george, home)
# *** True Label:
#  Uncertain
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (superhero(x) and american(x) implies comefrom(x, dcuniverse) xor comefrom(x, marveluniverse))
# american(captainamerica) and toptenfavorite(captainamerica) and superhero(captainamerica)
# not comefrom(captainamerica, dcuniverse)
# forall x (american(x) and toptenfavorite(x) and superhero(x)  implies speak(x, english))
# exists x (superhero(x) implies (speak(x, english) and speak(x, spanish)))
# *** Conclusion:
#  not speak(captainamerica, english)
# *** True Label:
#  False
# *** Predicted Label:
#  False
# *** Premises:
#  forall x ((customer(x) and in(x, jamesfamily) and subscribedto(x, amcalist)) implies  eligibleforthreefreemovieseveryweekwithoutadditionalfees(x))
# exists x exists y (customer(x) and in(x, jamesfamily) and gotoeveryweek(x, cinema) and (not (x=y)) and customer(y) and in(y, jamesfamily) and gotoeveryweek(y, cinema))
# forall x (customer(x) and in(x, jamesfamily) and (subscribedto(x, amcalist) or subscribedto(x, hbo)))
# forall x ((customer(x) and in(x, jamesfamily) and prefer(x, tvseries)) implies (not watchin(x, tv, cinema)))
# forall x ((customer(x) and in(x, jamesfamily) and  subscribedto(x, hbo)) implies prefer(x, tvseries))
# customer(lily) and in(lily, jamesfamily and watchin(lily, tv, cinema)
# *** Conclusion:
#  gotoeveryweek(lily, cinema) or eligibleforthreefreemovieswithoutadditionalfees(lily)
# *** True Label:
#  True
# *** Predicted Label:
#  True
# *** Premises:
#  exists x (monitor(x) and producedby(x, lg) and have(x, typecport) and (not (x=y)) and monitor(y) and producedby(y, lg) and have(y, typecport))
# forall x (have(x, typecport) implies not producedbefore(x, yr2010))
# forall x ((monitor(x) and in(x, library)) implies producedbefore(x, yr2010))
# monitor(l-2021) and (in(l-2021, library) xor have(l-2021, typecport))
# not (producedbefore(l-2021, yr2010) xor producedby(l-2021, lg))
# *** Conclusion:
#  not (in(l-2021, library) xor producedby(l-2021, lg)) implies (not have(x, typecport) and not producedby(x, lg))
# *** True Label:
#  False
# *** Predicted Label:
#  True
# *** Premises:
#  surname(nameodell) and from(nameodell, odellbedfordshire)
# mistakenspellingof(nameo'dell, nameodell) and (exists xexists y(family(x) and named(x, nameo'dell) and (not (x=y)) and family(y) and named(y, nameo'dell))
# named(amyodell, nameodell) and notableperson(amyodell) and named(jackodell, nameodell) and notableperson(jackodell) and named(matsodell, nameodell) and notableperson(matsodell)
# british(amyodell) and singer(amyodell) and songwriter(amyodell)
# english(jackodell) and toyinventor(jackodell)
# *** Conclusion:
#  named(amyodell, nameodell) and named(amyodell, nameo'dell)
# *** True Label:
#  Uncertain
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (take(x, barexam) implies canread(x))
# forall x (lawyer(x) implies take(x, barexam))
# forall x (take(x, barexam) implies knowledgeableabout(x, criminalproceeder))
# forall x (geton(x, scoreof180, lsat) implies canread(x))
# forall x (elephant(x) implies not canread(x))
# not (canread(mike) and elephant(mike)) implies take(mike, barexam) xor canread(mike)
# *** Conclusion:
#  not take(mike, barexam) and not (knowledgeableabout(mike, criminalprocedures)and geton(mike, 180, lsat))
# *** True Label:
#  True
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (at(x, boardgamenight) implies (interestedin(x, puzzle) or badat(x, chess)))
# forall x ((at(x, boardgamenight) and badat(x, chess)) implies not playsoften(x, chess))
# exists x (at(x, boardgamenight) and (planner(x) or creative(x)))
# at(erica, boardgamenight) and playsoften(erica, chess)
# (at(erica, boardgamenight) and (not (badat(erica, chess) or creative(erica)))) implies not (planner(erica) xor  creative(erica))
# *** Conclusion:
#  planner(erica)
# *** True Label:
#  Uncertain
# *** Predicted Label:
#  True
# *** Premises:
#
# givenname(namedagfinn) and named(dagfinnaarskog, namedagfinn) and notableperson(dagfinnaarskog) and named(dagfinnbakke, namedagfinn) and notableperson(dagfinnbakke)  and named(dagfinndahl, namedagfinn) and notableperson(dagfinndahl)
# norwegian(dagfinnaarskog) and physician(dagfinnaarskog)
# norwegian(dagfinndahl) and barrister(dagfinndahl)
# *** Conclusion:
#  norwegian(dagfinndahl) and physician(dagfinndahl)
# *** True Label:
#  Uncertain
# *** Predicted Label:
#  True
# *** Premises:
#  dramafilm(adventuresofrusty) and childrensfilm(adventuresofrusty)
# produces(columbiapictures, adventuresofrusty)
# produces(paramount, tintin)
# adventurefilm(tintin)
# *** Conclusion:
#  exists x (childrensfilm(x) and produces(paramount, x))
# *** True Label:
#  Uncertain
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (reptile(x) implies not have(x, fur))
# forall x (snake(x) implies reptile(x))
# *** Conclusion:
#  exists x (snake(x) and have(x, fur))
# *** True Label:
#  False
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (socialmedia(x) and application(x) and contain(x, chatfeature) implies software(x))
# forall x (socialmedia(x) and application(x) and allowtosendto(x, user, message) implies contain(x, chatfeature))
# forall x (socialmedia(x) and application(x) implies contain(x, chatfeature) or contain(x, videofeature))
# forall x (socialmedia(x) and application(x) and contain(x, videofeature) implies allow(x, user, uploadvideo))
# forall x (socialmedia(x) and application(x) and software(x) implies computerprogram(x))
# forall x (socialmedia(x) and application(x) andhave(x, highengagementmetric) implies addictive(x))
# forall x (socialmedia(x) and application(x) and addictive(x) implies not idealfor(x, preteen))
# socialmedia(tiktok) and application(tiktok) and not idealfor(tiktok, preteen)
# *** Conclusion:
#  not contain(tiktok, chatfeature) or not computerprogram(tiktok))
# *** True Label:
#  False
# *** Predicted Label:
#  False
# *** Premises:
#  forall x (tippedemployee(x) implies not entitledto(x, federalminimumwage))
# forall x (whitecollarworker(x) implies entitledto(x, federalminimumwage))
# forall x (lawyer(x) implies whitecollarworker(x))
# forall x (advocate(x) implies lawyer(x))
# not (lawyer(mary) xor tippedemployee(mary))
# *** Conclusion:
#  not advocate(mary)
# *** True Label:
#  True
# *** Predicted Label:
#  False
# *** Premises:
#  forall x (leader(x) implies havepower(x))
# forall x (leader(x) implies (king(x) xor queen(x)))
# forall x (queen(x) implies female(x))
# forall x (king(x) implies male(x))
# queen(elizabeth)
# leader(elizabeth)
# *** Conclusion:
#  king(elizabeth)
# *** True Label:
#  False
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (elephantopus(x) implies (genus(x, perennialplants) and belongto(x, daisyfamily)))
# exists x exists y exists z(elephantopus(x) and in(x,africa) and (not (x=y)) and elephantopus(y) and in(y, southernasia) and (not (x=z)) and (not (y=z)) and elephantopus(z) and in(z, australia))
# exists x exists y (elephantopus(x) and nativeto(x, southeasternunitedstates) and (not (x=y)) and elephantopus(y) and nativeto(y, southeasternunitedstates))
# forall x (elephantopusscaber(x) implies traditionalmedicine(x))
# *** Conclusion:
#  forall x (elephantopus(x) implies not nativeto(x, southeasternunitedstates))
# *** True Label:
#  False
# *** Predicted Label:
#  False
# *** Premises:
#  forall x (like(x, financialrisk) implies investinregularly(x, publicstockmarket) or enjoyregularly(x, gambling))
# forall x (investinregularly(x, publicstockmarket) implies readtokeepupdatedon(x, thewallstreetjournal, financialmetric) or (exists y (not (y=thewallstreetjournal) and newspaper(y) and readtokeepupdatedon(x, y, financialmetric))))
# forall x (enjoyregularly(x, gambling) implies spendat(x, alotofmoney, casino) or (exists y (not (y=casino) and bettinggame(y) and spendat(x, alotofmoney, y)))
# forall x (spendat(x, alotofmoney, casino) or (exists y (not (y=casino) and bettinggame(y) and spendat(x, alotofmoney, y))) implies enjoyvisiting(x, thelasvegasstrip))
# forall x (spendat(x, alotofmoney, casino) or (exists y (not (y=casino) and bettinggame(y) and spendat(x, alotofmoney, y)) implies atriskof(x, gamblingaddiction))
# investinregularly(matt, publicstockmarket)
# like(matt, financialrisk)
# *** Conclusion:
#  not atriskof(matt, gamblingaddiction) and not (readtokeepupdatedon(x, thewallstreetjournal, financialmetric) or (exists y (not (y=thewallstreetjournal) and newspaper(y) and readtokeepupdatedon(x, y, financialmetric))) and enjoyvisiting(matt, thelasvegasstrip))
# *** True Label:
#  False
# *** Predicted Label:
#  True
# *** Premises:
#  british(michael) and physician(michael) and journalist(michael) and author(michael) and broadcaster(michael)
# wordsetter(michael)
# magazine(worldmedicine) and editedby(worldmedicine, michael)
# bornin(michael, yorkshire) and exists x(sonof(michael, x) and generalpractitioner(x))
# *** Conclusion:
#  not magazine(worldmedicine)
# *** True Label:
#  False
# *** Predicted Label:
#  False
# *** Premises:
#  forall x ((mammal(x) and layegg(x)) implies (platypus(x) xor echidna(x)))
# forall x (platypuses(x) implies not hyrax(x))
# forall x (echidnas(x) implies not hyrax(x))
# forall x (mammal(x) implies not invertebrate(x))
# forall x (animal(x) implies (vertebrate(x) or invertebrate(x)))
# forall x (mammal(x) implies animal(x))
# forall x (hyrax(x) implies mammal(x))
# forall x (grebes(x) implies layegg(x))
# forall x (grebes(x) implies (not platypuses(x) and not echidnas(x)))
# *** Conclusion:
#  forall x (grebes(x) implies not mammal(x))
# *** True Label:
#  True
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (emilysfriend(x) and publish(x, journal) implies not workin(x, entertainmentindustry))
# forall x (emilysfriend(x) and awardwinningnovelist(x) implies publish(x, journal))
# forall x (emilysfriend(x) implies workin(x, entertainmentindustry) or highlyacclaimedin(x, theirprofession))
# ...
# *** True Label:
#  Uncertain
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (deadlydiseases(x) implies comewith(x, lowsurvivalrate))
# forall x (severecancer(x) implies deadlydiseases(x))
# forall x (bileductcancer(x) implies severecancer(x))
# forall x (cholangiocarcinoma(x) implies bileductcancer(x))
# forall x (mildflu(x) implies not comewith(x, lowsurvivalrate))
# not (bileductcancer(colorectalcancer) and comewith(colorectalcancer, lowsurvivalrate))
# *** Conclusion:
#  not (bileductcancer(colorectalcancer) or cholangiocarcinoma(colorectalcancer)) or (bileductcancer(colorectalcancer) and mildflu(colorectalcancer))
# *** True Label:
#  True
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (deadlydiseases(x) implies comewith(x, lowsurvivalrate))
# forall x (severecancer(x) implies deadlydiseases(x))
# forall x (bileductcancer(x) implies severecancer(x))
# forall x (cholangiocarcinoma(x) implies bileductcancer(x))
# forall x (mildflu(x) implies not comewith(x, lowsurvivalrate))
# not (bileductcancer(colorectalcancer) and comewith(colorectalcancer, lowsurvivalrate))
# *** Conclusion:
#  cholangiocarcinoma(colorectalcancer) and (mildflu(colorectalcancer) or bileductcancer(colorectalcancer))
# *** True Label:
#  False
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (regularlyeat(x, salad) implies consciousabout(x, health) and consciousabout(x, eatingghabit))
# forall x (grewupin(x, health-consciouschildhoodhome) implies regularlyeat(x, salad))
# forall x (fulfill(x, dailynutritionalintake) implies grewupin(x, health-consciouschildhoodhome))
# forall x (disregard(x, physicalwellbeing) implies not (consciousabout(x, health) and consciousabout(x, eatinghabit)))
# forall x (visitdaily(x, gym) implies fulfill(x, dailynutritionalintake))
# not (growupin(taylor, health-consciouschildhoodhome) xor disregard(taylor, physicalwellbeing))
# *** Conclusion:
#  regularlyeat(taylor, salad)
# *** True Label:
#  Uncertain
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (regularlyeat(x, salad) implies consciousabout(x, health) and consciousabout(x, eatingghabit))
# forall x (grewupin(x, health-consciouschildhoodhome) implies regularlyeat(x, salad))
# forall x (fulfill(x, dailynutritionalintake) implies grewupin(x, health-consciouschildhoodhome))
# forall x (disregard(x, physicalwellbeing) implies not (consciousabout(x, health) and consciousabout(x, eatinghabit)))
# forall x (visitdaily(x, gym) implies fulfill(x, dailynutritionalintake))
# not (growupin(taylor, health-consciouschildhoodhome) xor disregard(taylor, physicalwellbeing))
# *** Conclusion:
#  visitdaily(taylor, gym)
# *** True Label:
#  False
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (regularlyeat(x, salad) implies consciousabout(x, health) and consciousabout(x, eatingghabit))
# forall x (grewupin(x, health-consciouschildhoodhome) implies regularlyeat(x, salad))
# forall x (fulfill(x, dailynutritionalintake) implies grewupin(x, health-consciouschildhoodhome))
# forall x (disregard(x, physicalwellbeing) implies not (consciousabout(x, health) and consciousabout(x, eatinghabit)))
# forall x (visitdaily(x, gym) implies fulfill(x, dailynutritionalintake))
# not (growupin(taylor, health-consciouschildhoodhome) xor disregard(taylor, physicalwellbeing))
# *** Conclusion:
#  not growupin(taylor, health-consciouschildhoodhome) and not visitdaily(taylor, gym))
# *** True Label:
#  True
# *** Predicted Label:
#  False
# *** Premises:
#  sportingevent(olympics)
# lastsummerolympics(tokyo)
# mostmedals(unitedstates, tokyo)
# *** Conclusion:
#  sportingevent(champs)
# *** True Label:
#  Uncertain
# *** Predicted Label:
#  True
# *** Premises:
#  sportingevent(olympics)
# lastsummerolympics(tokyo)
# mostmedals(unitedstates, tokyo)
# *** Conclusion:
#  not lastsummerolympics(tokyo)
# *** True Label:
#  False
# *** Predicted Label:
#  False
# *** Premises:
#  sportingevent(olympics)
# lastsummerolympics(tokyo)
# mostmedals(unitedstates, tokyo)
# *** Conclusion:
#  exists x (lastsummerolympics(x) and mostmedals(unitedstates, x))
# *** True Label:
#  True
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (horse(x) implies exists y exists z (not (y=z) and hoof(y) and hoof(z) and have(x, y) and have(x, z)))
# forall x (human(x) implies not (exists y exists z (not (y=z) and hoof(y) and hoof(z) and have(x, y) and have(x, z))))
# *** Conclusion:
#  exists x (human(x) and human(y) and horse(x) and horse(y) and not (x=y))
# *** True Label:
#  False
# *** Predicted Label:
#  True
# *** Premises:
#  flyto(susan, lgaairport)
# forall x forall y (flyfrom(x, y) xor flyto(x, y))
# flyfrom(john, lgaairport)
# *** Conclusion:
#  flyfrom(susan, lgaairport)
# *** True Label:
#  False
# *** Predicted Label:
#  True
# *** Premises:
#  flyto(susan, lgaairport)
# forall x forall y (flyfrom(x, y) xor flyto(x, y))
# flyfrom(john, lgaairport)
# *** Conclusion:
#  flyto(john, lgaairport)
# *** True Label:
#  False
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (niceto(x, animal) implies not meanto(x, animal))
# exists x (grumpy(x) and meanto(x, animal))
# forall x (animallover(x) implies niceto(x, animal))
# forall x (petowner(x) implies animallover(x))
# petowner(tom)
# *** Conclusion:
#  grumpy(tom)
# *** True Label:
#  Uncertain
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (niceto(x, animal) implies not meanto(x, animal))
# exists x (grumpy(x) and meanto(x, animal))
# forall x (animallover(x) implies niceto(x, animal))
# forall x (petowner(x) implies animallover(x))
# petowner(tom)
# *** Conclusion:
#  not (grumpy(tom) and meanto(tom, animal))
# *** True Label:
#  True
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (niceto(x, animal) implies not meanto(x, animal))
# exists x (grumpy(x) and meanto(x, animal))
# forall x (animallover(x) implies niceto(x, animal))
# forall x (petowner(x) implies animallover(x))
# petowner(tom)
# *** Conclusion:
#  not (grumpy(tom) and meanto(tom, animal)) implies not grumpy(tom) and not animallover(tom))
# *** True Label:
#  False
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (podcast(x) implies not novel(x))
# forall x((exists y(bornin(x, y) and city(y) and locatedin(y,america)) implies american(x))
# forall x forall y ((novel(x) and writtenby(x, y)) implies writesnovel(y))
# american(dani_shapiro) and writer(dani_shapiro)
# writtenby(family_history, dani_shapiro)
# novel(family_history) and writtenin(family_history, yr2003)
# podcast(family_secrets) and createdby(family_secrets, dani_shapiro)
# city(boston) and american(boston)
# *** Conclusion:
#  writesnovel(dani_shapiro)
# *** True Label:
#  True
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (podcast(x) implies not novel(x))
# forall x((exists y(bornin(x, y) and city(y) and locatedin(y,america)) implies american(x))
# forall x forall y ((novel(x) and writtenby(x, y)) implies writesnovel(y))
# american(dani_shapiro) and writer(dani_shapiro)
# writtenby(family_history, dani_shapiro)
# novel(family_history) and writtenin(family_history, yr2003)
# podcast(family_secrets) and createdby(family_secrets, dani_shapiro)
# city(boston) and american(boston)
# *** Conclusion:
#  isnovel(family_secrets)
# *** True Label:
#  False
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (podcast(x) implies not novel(x))
# forall x((exists y(bornin(x, y) and city(y) and locatedin(y,america)) implies american(x))
# forall x forall y ((novel(x) and writtenby(x, y)) implies writesnovel(y))
# american(dani_shapiro) and writer(dani_shapiro)
# writtenby(family_history, dani_shapiro)
# novel(family_history) and writtenin(family_history, yr2003)
# podcast(family_secrets) and createdby(family_secrets, dani_shapiro)
# city(boston) and american(boston)
# *** Conclusion:
#  bornin(dani_shapiro, boston)
# *** True Label:
#  Uncertain
# *** Predicted Label:
#  True
# *** Premises:
#  exists x (professional(x) and basketballplayer(x) and not americannational(x))
# forall x (professional(x) and basketballplayer(x) implies cando(x, jumpshot))
# forall x (cando(x, jumpshot) implies leapstraightintoair(x))
# forall x (leapstraightintoair(x) implies activate(x, legmuscle))
# not activate(yuri, legmuscle)
# *** Conclusion:
#  americannational(yuri)
# *** True Label:
#  Uncertain
# *** Predicted Label:
#  True
# *** Premises:
#  exists x (professional(x) and basketballplayer(x) and not americannational(x))
# forall x (professional(x) and basketballplayer(x) implies cando(x, jumpshot))
# forall x (cando(x, jumpshot) implies leapstraightintoair(x))
# forall x (leapstraightintoair(x) implies activate(x, legmuscle))
# not activate(yuri, legmuscle)
# *** Conclusion:
#  not (americannational(yuri) and professional(yuri) and basketballplayer(yuri))
# *** True Label:
#  True
# *** Predicted Label:
#  False
# *** Premises:
#  exists x (professional(x) and basketballplayer(x) and not americannational(x))
# forall x (professional(x) and basketballplayer(x) implies cando(x, jumpshot))
# forall x (cando(x, jumpshot) implies leapstraightintoair(x))
# forall x (leapstraightintoair(x) implies activate(x, legmuscle))
# not activate(yuri, legmuscle)
# *** Conclusion:
#  americannational(yuri) and professional(yuri) and basketballplayer(yuri)
# *** True Label:
#  False
# *** Predicted Label:
#  True
# *** Premises:
#  exists x (professional(x) and basketballplayer(x) and not americannational(x))
# forall x (professional(x) and basketballplayer(x) implies cando(x, jumpshot))
# forall x (cando(x, jumpshot) implies leapstraightintoair(x))
# forall x (leapstraightintoair(x) implies activate(x, legmuscle))
# not activate(yuri, legmuscle)
# *** Conclusion:
#  not leapstraightintoair(yuri) implies (americannational(yuri) and professional(yuri) and basketballplayer(yuri))
# *** True Label:
#  False
# *** Predicted Label:
#  True
# *** Premises:
#  exists x (professional(x) and basketballplayer(x) and not americannational(x))
# forall x (professional(x) and basketballplayer(x) implies cando(x, jumpshot))
# forall x (cando(x, jumpshot) implies leapstraightintoair(x))
# forall x (leapstraightintoair(x) implies activate(x, legmuscle))
# not activate(yuri, legmuscle)
# *** Conclusion:
#  not (americannational(yuri) and professional(yuri) and basketballplayer(yuri)) implies (professional(yuri) and basketballplayer(yuri))
# *** True Label:
#  False
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (event(x) implies happy(x) xor sad(x))
# exists x (event(x) and happy(x))
# *** Conclusion:
#  forall x (event(x) implies sad(x))
# *** True Label:
#  False
# *** Predicted Label:
#  True
# *** Premises:
#  winnerof(steinhauer, dumaurierclassic, year1992)
# participate(dumaurierclassic, steinhauer, year1992)
# exists x exists y (onleaderboardof(x, dumaurierclassic) and sixwaytie(x)) and in(y, sixwaytie) and belgium(y))
# from(descampe, belgium) and onleaderboardof(descampe, dumaurierclassic)
# forall x (leaderboard(maurier, x) implies participate(maurier, x))
# *** Conclusion:
#  not winnerof(steinhauer, dumaurierclassic, year1992)
# *** True Label:
#  False
# *** Predicted Label:
#  False
# *** Premises:
#  winnerof(steinhauer, dumaurierclassic, year1992)
# participate(dumaurierclassic, steinhauer, year1992)
# exists x exists y (onleaderboardof(x, dumaurierclassic) and sixwaytie(x)) and in(y, sixwaytie) and belgium(y))
# from(descampe, belgium) and onleaderboardof(descampe, dumaurierclassic)
# forall x (leaderboard(maurier, x) implies participate(maurier, x))
# *** Conclusion:
#  sixwaytie(descampe)
# *** True Label:
#  Uncertain
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (animal(x) and bark(x) implies not like(jane, x))
# forall x (dog(x) implies animal(x) and bark(x))
# forall x (animal(x) and jump(x) implies like(jane, x))
# forall x (exists y exists z (not (y=z) and leg(y) and leg(z) and have(x, y) and have(x, z)) implies jump(x))
# forall x (terricolous(x) implies exists y exists z (not (y=z) and leg(y) and leg(z) and have(x, y) and have(x, z)))
# animal(kiki)
# not jump(kiki) and not (exists y exists z (not (y=z) and leg(y) and leg(z) and have(kiki, y) and have(kiki, z))) implies terricolous(kiki) or exists y exists z (not (y=z) and leg(y) and leg(z) and have(kiki, y) and have(kiki, z))
# *** Conclusion:
#  terricolous(kiki)
# *** True Label:
#  Uncertain
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (animal(x) and bark(x) implies not like(jane, x))
# forall x (dog(x) implies animal(x) and bark(x))
# forall x (animal(x) and jump(x) implies like(jane, x))
# forall x (exists y exists z (not (y=z) and leg(y) and leg(z) and have(x, y) and have(x, z)) implies jump(x))
# forall x (terricolous(x) implies exists y exists z (not (y=z) and leg(y) and leg(z) and have(x, y) and have(x, z)))
# animal(kiki)
# not jump(kiki) and not (exists y exists z (not (y=z) and leg(y) and leg(z) and have(kiki, y) and have(kiki, z))) implies terricolous(kiki) or exists y exists z (not (y=z) and leg(y) and leg(z) and have(kiki, y) and have(kiki, z))
# *** Conclusion:
#  bark(kiki) and dog(kiki)
# *** True Label:
#  False
# *** Predicted Label:
#  True
# *** Premises:
#  forall x (animal(x) and bark(x) implies not like(jane, x))
# forall x (dog(x) implies animal(x) and bark(x))
# forall x (animal(x) and jump(x) implies like(jane, x))
# forall x (exists y exists z (not (y=z) and leg(y) and leg(z) and have(x, y) and have(x, z)) implies jump(x))
# forall x (terricolous(x) implies exists y exists z (not (y=z) and leg(y) and leg(z) and have(x, y) and have(x, z)))
# animal(kiki)
# not jump(kiki) and not (exists y exists z (not (y=z) and leg(y) and leg(z) and have(kiki, y) and have(kiki, z))) implies terricolous(kiki) or exists y exists z (not (y=z) and leg(y) and leg(z) and have(kiki, y) and have(kiki, z))
# *** Conclusion:
#  not bark(kiki) and not dog(kiki)
# *** True Label:
#  True
# *** Predicted Label:
#  False
# *** Premises:
#  bornin(ailtonsilva, year1995) and commonlyknownas(ailtonsilva, ailton)
# footballplayer(ailton) and loanedto(ailton, braga)
# brazilian(ailtonsilva) and footballplayer(ailtonsilva) and playfor(ailtonsilva, nautico)
# footballclub(nautico) and footballclub(braga)
# footballclub(fluminense)
# *** Conclusion:
#  forall x (playfor(x, nautico) implies not brazilian(x))
# *** True Label:
#  False
# *** Predicted Label:
#  True
# *** Premises:
#  bornin(ailtonsilva, year1995) and commonlyknownas(ailtonsilva, ailton)
# footballplayer(ailton) and loanedto(ailton, braga)
# brazilian(ailtonsilva) and footballplayer(ailtonsilva) and playfor(ailtonsilva, nautico)
# footballclub(nautico) and footballclub(braga)
# footballclub(fluminense)
# *** Conclusion:
#  forall x (footballclub(x) implies not playfor(ailtonsilva, x))
# *** True Label:
#  False
# *** Predicted Label:
#  True
# *** Premises:
#  bornin(ailtonsilva, year1995) and commonlyknownas(ailtonsilva, ailton)
# footballplayer(ailton) and loanedto(ailton, braga)
# brazilian(ailtonsilva) and footballplayer(ailtonsilva) and playfor(ailtonsilva, nautico)
# footballclub(nautico) and footballclub(braga)
# footballclub(fluminense)
# *** Conclusion:
#  forall x (footballclub(x) implies not loanedto(ailton, x))
# *** True Label:
#  False
# *** Predicted Label:
#  True
# *** Premises:
#  bornin(ailtonsilva, year1995) and commonlyknownas(ailtonsilva, ailton)
# footballplayer(ailton) and loanedto(ailton, braga)
# brazilian(ailtonsilva) and footballplayer(ailtonsilva) and playfor(ailtonsilva, nautico)
# footballclub(nautico) and footballclub(braga)
# footballclub(fluminense)
# *** Conclusion:
#  playfor(ailtonsilva, fluminense)
# *** True Label:
#  Uncertain
# *** Predicted Label:
#  True
# *** Premises:
#  bornin(ailtonsilva, year1995) and commonlyknownas(ailtonsilva, ailton)
# footballplayer(ailton) and loanedto(ailton, braga)
# brazilian(ailtonsilva) and footballplayer(ailtonsilva) and playfor(ailtonsilva, nautico)
# footballclub(nautico) and footballclub(braga)
# footballclub(fluminense)
# *** Conclusion:
#  exists x (footballclub(x) and loanedto(ailtonsilva, x))
# *** True Label:
#  Uncertain
# *** Predicted Label:
#  True
# Classification Report:               precision    recall  f1-score   support
#
#        False       0.48      0.20      0.28       351
#         True       0.38      0.88      0.54       460
#    Uncertain       0.00      0.00      0.00       393
#
#     accuracy                           0.40      1204
#    macro avg       0.29      0.36      0.27      1204
# weighted avg       0.29      0.40      0.29      1204
#
# *************** INFERENCE COMPLETE ***************
# time: 35min 18s (started: 2026-04-20 06:43:16 +00:00)

# %%
# output results
print("***** ACCURACY *****")
print(acc_metric)
print("***** PRECISION *****")
print(pr_metric)
print("***** RECALL *****")
print(re_metric)
print("***** F1 *****")
print(f_metric)
eval_metrics_df
# Out:
# ***** ACCURACY *****
# 0.3961794019933555
# ***** PRECISION *****
# 0.2880467151772535
# ***** RECALL *****
# 0.36140426937528386
# ***** F1 *****
# 0.27264067496768046
#    Accuracy  Precision    Recall        F1
# 0  0.396179   0.288047  0.361404  0.272641
# time: 19.6 ms (started: 2026-04-20 07:18:35 +00:00)

# %%
# empty torch cuda cache
torch.cuda.empty_cache()

# delete model from cpu
del(model)
