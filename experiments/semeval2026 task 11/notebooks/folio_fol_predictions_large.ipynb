# %%
'''
task: FOL classification based on NL + CLIF text
model: FOLIO NL + CLIF t5-large
dataset: SemEval-2026
evaluation: supervised fine-tuning
'''
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# load train, val and test splits
train = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SemEval2026/data/train.csv")
val = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SemEval2026/data/val.csv")
test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SemEval2026/data/test.csv")

# transform data to acceptable format for model training
train_df = pd.DataFrame(train)
val_df = pd.DataFrame(val)
test_df = pd.DataFrame(test)

train_df = train_df.applymap(str)
val_df = val_df.applymap(str)
test_df = test_df.applymap(str)
# Out:
# /tmp/ipython-input-1243017007.py:13: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   train_df = train_df.applymap(str)
# /tmp/ipython-input-1243017007.py:14: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   val_df = val_df.applymap(str)
# /tmp/ipython-input-1243017007.py:15: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   test_df = test_df.applymap(str)

# %%
# start preparing for QA pipeline
# !pip install datasets
! pip install -U accelerate
! pip install -U transformers
# !pip install transformers
# !pip install evaluate
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets) (3.20.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.36.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.13.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2026.1.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.12.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from accelerate) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate) (6.0.3)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (2.9.0+cu126)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (0.36.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate) (0.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (3.20.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (2025.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (1.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.21.0->accelerate) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.21.0->accelerate) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.21.0->accelerate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.21.0->accelerate) (2026.1.4)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.3)
# Collecting transformers
#   Downloading transformers-4.57.6-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2026.1.4)
# Downloading transformers-4.57.6-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 50.2 MB/s eta 0:00:00
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.57.3
#     Uninstalling transformers-4.57.3:
#       Successfully uninstalled transformers-4.57.3
# Successfully installed transformers-4.57.6
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2026.1.4)
# Collecting evaluate
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (4.0.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.0.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.32.4)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.12/dist-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from evaluate) (3.6.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.36.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from evaluate) (25.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (3.20.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (18.1.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (3.13.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2026.1.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2025.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 6.8 MB/s eta 0:00:00
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.6

# %%
import torch
import json
from tqdm import tqdm
import torch.nn as nn
from torch.optim import Adam
import nltk
import spacy
import string
import evaluate  # Bleu
from torch.utils.data import Dataset, DataLoader, RandomSampler
import pandas as pd
import numpy as np
import transformers
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from transformers import T5Tokenizer, T5Model, T5ForConditionalGeneration, T5TokenizerFast

import warnings
warnings.filterwarnings("ignore")

# %%
MODEL = T5ForConditionalGeneration.from_pretrained("/content/drive/MyDrive/Colab Notebooks/folio/models/flan-t5-large_logic_nl_clif_model")
TOKENIZER = T5TokenizerFast.from_pretrained("/content/drive/MyDrive/Colab Notebooks/folio/models/flan-t5-large_logic_nl_clif_tokenizer")

# %%
# set model parameters
Q_LEN = 512   # Question Length
T_LEN = 512    # Target Length
BATCH_SIZE = 4
DEVICE = "cuda:0"
OPTIMIZER = Adam(MODEL.parameters(), lr=0.00001)

# %%
class QA_Dataset(Dataset):
    def __init__(self, tokenizer, dataframe, q_len, t_len):
        self.tokenizer = tokenizer
        self.q_len = q_len
        self.t_len = t_len
        self.data = dataframe
        self.subject = self.data["syllogism"]  + " " + self.data["clif"]
        self.relation = self.data['validity']

    def __len__(self):
        return len(self.subject)

    def __getitem__(self, idx):
        subject = self.subject[idx]
        relation = self.relation[idx]

        subject_tokenized = self.tokenizer(subject, max_length=self.q_len, padding="max_length",
                                                    truncation=True, add_special_tokens=True)
        relation_tokenized = self.tokenizer(relation, max_length=self.t_len, padding="max_length",
                                          truncation=True, add_special_tokens=True)

        labels = torch.tensor(relation_tokenized["input_ids"], dtype=torch.long)
        labels[labels == 0] = -100

        return {
            "input_ids": torch.tensor(subject_tokenized["input_ids"], dtype=torch.long),
            "attention_mask": torch.tensor(subject_tokenized["attention_mask"], dtype=torch.long),
            "labels": labels,
            "decoder_attention_mask": torch.tensor(relation_tokenized["attention_mask"], dtype=torch.long)
        }

# %%
train_dataset = QA_Dataset(TOKENIZER, train_df, Q_LEN, T_LEN)
val_dataset = QA_Dataset(TOKENIZER, val_df, Q_LEN, T_LEN)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)

# %%
#torch.cuda.empty_cache()
MODEL.to('cuda')
# Out:
# T5ForConditionalGeneration(
#   (shared): Embedding(32128, 1024)
#   (encoder): T5Stack(
#     (embed_tokens): Embedding(32128, 1024)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=1024, bias=False)
#               (k): Linear(in_features=1024, out_features=1024, bias=False)
#               (v): Linear(in_features=1024, out_features=1024, bias=False)
#               (o): Linear(in_features=1024, out_features=1024, bias=False)
#               (relative_attention_bias): Embedding(32, 16)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=1024, out_features=2816, bias=False)
#               (wi_1): Linear(in_features=1024, out_features=2816, bias=False)
#               (wo): Linear(in_features=2816, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-23): 23 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=1024, bias=False)
#               (k): Linear(in_features=1024, out_features=1024, bias=False)
#               (v): Linear(in_features=1024, out_features=1024, bias=False)
#               (o): Linear(in_features=1024, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=1024, out_features=2816, bias=False)
#               (wi_1): Linear(in_features=1024, out_features=2816, bias=False)
#               (wo): Linear(in_features=2816, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): T5Stack(
#     (embed_tokens): Embedding(32128, 1024)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=1024, bias=False)
#               (k): Linear(in_features=1024, out_features=1024, bias=False)
#               (v): Linear(in_features=1024, out_features=1024, bias=False)
#               (o): Linear(in_features=1024, out_features=1024, bias=False)
#               (relative_attention_bias): Embedding(32, 16)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=1024, bias=False)
#               (k): Linear(in_features=1024, out_features=1024, bias=False)
#               (v): Linear(in_features=1024, out_features=1024, bias=False)
#               (o): Linear(in_features=1024, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=1024, out_features=2816, bias=False)
#               (wi_1): Linear(in_features=1024, out_features=2816, bias=False)
#               (wo): Linear(in_features=2816, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-23): 23 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=1024, bias=False)
#               (k): Linear(in_features=1024, out_features=1024, bias=False)
#               (v): Linear(in_features=1024, out_features=1024, bias=False)
#               (o): Linear(in_features=1024, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=1024, bias=False)
#               (k): Linear(in_features=1024, out_features=1024, bias=False)
#               (v): Linear(in_features=1024, out_features=1024, bias=False)
#               (o): Linear(in_features=1024, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=1024, out_features=2816, bias=False)
#               (wi_1): Linear(in_features=1024, out_features=2816, bias=False)
#               (wo): Linear(in_features=2816, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=1024, out_features=32128, bias=False)
# )

# %%
train_loss = 0
val_loss = 0
train_batch_count = 0
val_batch_count = 0

for epoch in range(5):
    MODEL.train()
    for batch in tqdm(train_loader, desc="Training batches"):
        input_ids = batch["input_ids"].to(DEVICE)
        attention_mask = batch["attention_mask"].to(DEVICE)
        labels = batch["labels"].to(DEVICE)
        decoder_attention_mask = batch["decoder_attention_mask"].to(DEVICE)

        outputs = MODEL(
                          input_ids=input_ids,
                          attention_mask=attention_mask,
                          labels=labels,
                          decoder_attention_mask=decoder_attention_mask
                        )

        OPTIMIZER.zero_grad()
        outputs.loss.backward()
        OPTIMIZER.step()
        train_loss += outputs.loss.item()
        train_batch_count += 1

    #Evaluation
    MODEL.eval()
    for batch in tqdm(val_loader, desc="Validation batches"):
        input_ids = batch["input_ids"].to(DEVICE)
        attention_mask = batch["attention_mask"].to(DEVICE)
        labels = batch["labels"].to(DEVICE)
        decoder_attention_mask = batch["decoder_attention_mask"].to(DEVICE)

        outputs = MODEL(
                          input_ids=input_ids,
                          attention_mask=attention_mask,
                          labels=labels,
                          decoder_attention_mask=decoder_attention_mask
                        )

        OPTIMIZER.zero_grad()
        outputs.loss.backward()
        OPTIMIZER.step()
        val_loss += outputs.loss.item()
        val_batch_count += 1

    print(f"{epoch+1}/{5} -> Train loss: {train_loss / train_batch_count}\tValidation loss: {val_loss/val_batch_count}")
# Out:
# Training batches: 100%|██████████| 141/141 [02:00<00:00,  1.17it/s]
# Validation batches: 100%|██████████| 94/94 [01:16<00:00,  1.22it/s]
# 1/5 -> Train loss: 0.2569494254834263	Validation loss: 0.18509430644359995
# Training batches: 100%|██████████| 141/141 [01:58<00:00,  1.19it/s]
# Validation batches: 100%|██████████| 94/94 [01:16<00:00,  1.22it/s]
# 2/5 -> Train loss: 0.2057889081233888	Validation loss: 0.12858134963762688
# Training batches: 100%|██████████| 141/141 [01:58<00:00,  1.19it/s]
# Validation batches: 100%|██████████| 94/94 [01:16<00:00,  1.22it/s]
# 3/5 -> Train loss: 0.1761155630083178	Validation loss: 0.09253512000381668
# Training batches: 100%|██████████| 141/141 [01:58<00:00,  1.19it/s]
# Validation batches: 100%|██████████| 94/94 [01:16<00:00,  1.22it/s]
# 4/5 -> Train loss: 0.155366232762351	Validation loss: 0.07005575726917085
# Training batches: 100%|██████████| 141/141 [01:58<00:00,  1.19it/s]
# Validation batches: 100%|██████████| 94/94 [01:16<00:00,  1.22it/s]
# 5/5 -> Train loss: 0.13904053923890244	Validation loss: 0.05631557094096779

# %%
MODEL.save_pretrained("/content/drive/MyDrive/Colab Notebooks/SemEval2026/models/flan-t5-large_folio_nl_clif_model")
TOKENIZER.save_pretrained("/content/drive/MyDrive/Colab Notebooks/SemEval2026/models/flan-t5-large_folio_nl_clif_tokenizer")
# Out:
# ('/content/drive/MyDrive/Colab Notebooks/SemEval2026/models/flan-t5-large_folio_nl_clif_tokenizer/tokenizer_config.json',
#  '/content/drive/MyDrive/Colab Notebooks/SemEval2026/models/flan-t5-large_folio_nl_clif_tokenizer/special_tokens_map.json',
#  '/content/drive/MyDrive/Colab Notebooks/SemEval2026/models/flan-t5-large_folio_nl_clif_tokenizer/spiece.model',
#  '/content/drive/MyDrive/Colab Notebooks/SemEval2026/models/flan-t5-large_folio_nl_clif_tokenizer/added_tokens.json',
#  '/content/drive/MyDrive/Colab Notebooks/SemEval2026/models/flan-t5-large_folio_nl_clif_tokenizer/tokenizer.json')

# %%
# evaluation metrics

import numpy as np
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report


def predict_answer(subject, ref_relation=None):
    inputs = TOKENIZER(subject, return_tensors="pt").to(MODEL.device)

    outputs = MODEL.generate(input_ids=inputs["input_ids"], max_new_tokens=10)

    predicted_relation = TOKENIZER.batch_decode(outputs.detach().cpu().numpy(), skip_special_tokens=True)[0]

    print("syllogism: \n", subject)
    print("true label: \n", ref_relation)
    print("predicted label: \n", predicted_relation)

    return predicted_relation

# %%
# test predictions
reference_labels = []
predicted_labels = []
for index, row in test_df.iterrows():
  premises = row["syllogism"] + " " + row["clif"]
  label = row["validity"]

  predicted_label = predict_answer(premises, label)
  reference_labels.append(label)
  predicted_labels.append(predicted_label)

# calculate classification metrics
print("Accuracy:", accuracy_score(reference_labels, predicted_labels))
print("Precision:", precision_score(reference_labels, predicted_labels, average="macro"))
print("Recall:", recall_score(reference_labels, predicted_labels, average="macro"))
print("F1:", f1_score(reference_labels, predicted_labels, average="macro"))
print("Classification Report:", classification_report(reference_labels, predicted_labels))
# Out:
# syllogism:
#  All forms of bacteria are classified as communities. There are some organs that do not belong to the category of communities. Therefore, some organs are not types of bacteria. forall x (formofbacteria(x) implies classifiedascommunitie(x))
#  exists x (organthatdonot(x) and categoryofcommunitie(x))
#  forall x (someorgan(x) implies nottypeofbacteria(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Every cat is a mammal. The set of dolphins contains no cats. Every single dolphin is a mammal. forall x (cat(x) implies mammal(x))
#  forall x (setofdolphincontainnocat(x))
#  forall x (singledolphin(x) implies mammal(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Anything that is a tomato is also a planet. There is no planet that is a food. It is thus the case that no food is a tomato. forall x (anythingthat(x) implies tomatoalsoaplanet(x))
#  forall x (there(x) implies noplanetthatafood(x))
#  forall x (it(x) implies thing(x))
#  forall x (casethatnofood(x) implies tomato(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Every single eagle is a bird. Nothing that is a bat is a bird. From this, it can be concluded that no bat is an eagle. forall x (singleeagle(x) implies bird(x))
#  forall x (nothingthat(x) implies batabird(x))
#  forall x (fromthiitcanbeconcludedthatnobat(x) implies eagle(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Any creature that is a bird is an animal. A portion of animals are kept as pets. Some pets are not birds. forall x (creaturethat(x) implies birdananimal(x))
#  exists x (animal(x) and keptaspet(x))
#  exists x (pet(x) and notbird(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Anything which is a cloud is made of rock. Some weather phenomena are known to be clouds. Consequently, some weather phenomena are made of rock. forall x (anythingwhich(x) implies cloudmadeofrock(x))
#  exists x (weatherphenomena(x) and knowntobecloud(x))
#  forall x (someweatherphenomena(x) implies madeofrock(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  It is true that some things that are trees do not have roots. Everything that is a tree is a plant. It logically follows that there are some plants that do not have roots. exists x (thingthat(x) and treedonothaverooteverythingthatatreeaplantitlogicallyfollowthattheresomeplantthatdonothaveroot(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Anything that is a table is not a tree. There are tables, and some of them can be identified as furniture. Based on this, a portion of furniture pieces must not be trees. forall x (anythingthat(x) implies tablenotatree(x))
#  forall x (there(x) implies tableandsomeofthemcanbeidentifiedasfurniture(x))
#  exists x (basedonth(x) and not aportionoffurniturepiecemustnotbetree(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Every single dog is a mammal. All mammals are birds. Consequently, every single bird is a dog. forall x (singledog(x) implies mammal(x))
#  forall x (mammal(x) implies bird(x))
#  forall x (everysinglebird(x) implies dog(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Anything that is a human is a primate. Every single whale is a mammal. Not a single whale is a human. forall x (anythingthat(x) implies humanaprimate(x))
#  forall x (singlewhale(x) implies mammal(x))
#  forall x (whale(x) implies not human(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  The category of moons and the category of celestial bodies do not overlap. All celestial bodies are planets. A subset of planets are moons. forall x (categoryofmoonandthecategoryofcelestialbodiedonotoverlap(x))
#  forall x (celestialbodie(x) implies planet(x))
#  exists x (planet(x) and moon(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Every single person is a human. Anything that is a human is a husband. Consequently, it follows that all husbands are people. forall x (singleperson(x) implies human(x))
#  forall x (anythingthat(x) implies humanahusband(x))
#  forall x (itfollowthatallhusband(x) implies people(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Teapots are never classified as utensils. Some soldiers are not considered utensils. Consequently, some soldiers are indeed teapots. forall x (teapot(x) implies neverclassifiedasutensil(x))
#  exists x (soldier(x) and notconsideredutensil(x))
#  forall x (somesoldier(x) implies indeedteapot(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Every single star is a planet. No planets are suns. It is therefore a sound deduction that some suns are not stars. forall x (singlestar(x) implies planet(x))
#  forall x (planet(x) implies not sun(x))
#  forall x (it(x) implies thing(x))
#  forall x (sounddeductionthatsomesun(x) implies notstar(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  All fish are birds. It is true that no bird is aquatic. It follows that no aquatic thing is a fish. forall x (fish(x) implies bird(x))
#  forall x (bird(x) implies not aquaticitfollowthatnoaquaticthingafish(x))
#
# true label:
#  True
# predicted label:
#  False
# syllogism:
#  A group of numbers are planets. Every planet is a celestial body. As a result, a portion of celestial bodies are numbers. forall x (groupofnumber(x) implies planet(x))
#  forall x (planet(x) implies celestialbody(x))
#  forall x (aportionofcelestialbodie(x) implies number(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Every single mammal is an animal. There are no fish which are mammals. Consequently, there are no fish which are animals. forall x (singlemammal(x) implies animal(x))
#  exists x (nofishwhich(x) and mammal(x))
#  forall x (there(x) implies nofishwhichanimal(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  None of the items that are carrots are bell peppers. There are vegetables that are bell peppers. It is correct to infer that some vegetables are not carrots. forall x (of(x) implies not itemthatcarrotbellpepper(x))
#  exists x (vegetablethat(x) and bellpepper(x))
#  forall x (it(x) implies correcttoinferthatsomevegetablenotcarrot(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  All things that are made of wood can catch on fire. There are some chairs that are wooden objects. It follows, then, that some chairs can be set on fire. forall x (thingthat(x) implies madeofwoodcancatchonfire(x))
#  exists x (chairthat(x) and woodenobject(x))
#  forall x (thenthatsomechaircanbesetonfire(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  All things that are cars are vehicles. There is no vehicle that is a bicycle. Therefore, there is no bicycle that is a car. forall x (thingthat(x) implies carvehicle(x))
#  forall x (there(x) implies novehiclethatabicycle(x))
#  forall x (there(x) implies nobicyclethatacar(x))
#
# true label:
#  True
# predicted label:
#  False
# syllogism:
#  Every single four-sided-shape is a rectangle. All four-sided-shapes are squares. It follows from this that some squares are not rectangles. forall x (singlefoursidedshape(x) implies rectangle(x))
#  forall x (foursidedshape(x) implies square(x))
#  forall x (fromthithatsomesquare(x) implies notrectangle(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  It's the case that all furniture is made of wood. Anything that is a chair is also made of wood. Some chairs fail to be furniture. forall x (itsthecasethatallfurniture(x) implies madeofwood(x))
#  forall x (anythingthat(x) implies chairalsomadeofwood(x))
#  forall x (chairfailtobefurniture(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Nothing that is an emotion is a feeling. Certain emotions are classified as sadness. It must be the case that some sadness is not a feeling. forall x (nothingthat(x) implies emotionafeeling(x))
#  exists x (emotion(x) and classifiedassadnes(x))
#  forall x (itmustbethecasethatsomesadnes(x) implies notafeeling(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  There are some mammals that can fly. It is the case that no bird can fly. Therefore, all birds are mammals. forall x (there(x) implies mammalthatcanfly(x))
#  forall x (it(x) implies casethatnobirdcanfly(x))
#  forall x (allbird(x) implies mammal(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  A group of animals are vertebrates. It is a fact that some animals are not insects. It is necessarily true that no insects are vertebrates. forall x (groupofanimal(x) implies vertebrate(x))
#  exists x (animal(x) and notinsectitnecessarilytruethatnoinsectvertebrate(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Some animals are human. There are politicians who are human. This means that some politicians are animals. exists x (animal(x) and human(x))
#  exists x (politicianwho(x) and human(x))
#  forall x (thimeanthatsomepolitician(x) implies animal(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Every single thing that is a bird is an animal. Anything that is a pigeon is, without exception, a bird. This means that all pigeons are animals. forall x (singlethingthat(x) implies birdananimal(x))
#  forall x (anythingthat(x) implies pigeonwithoutexceptionabird(x))
#  forall x (thimeanthatallpigeon(x) implies animal(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  It is impossible for a spider to be a bird. A portion of spiders are considered arachnids. It is necessarily the case that some arachnids are not birds. forall x (it(x) implies impossibleforaspidertobeabird(x))
#  exists x (spider(x) and consideredarachnid(x))
#  forall x (it(x) implies necessarilythecasethatsomearachnidnotbird(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Every airplane is a cloud. It is true that every bird is a cloud. This means that every single bird is an airplane. forall x (airplane(x) implies cloud(x))
#  forall x (bird(x) implies cloudthimeanthateverysinglebirdanairplane(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Anything that is a car is not an airplane. There are no vehicles that are cars. Consequently, every vehicle is an airplane. forall x (anythingthat(x) implies carnotanairplane(x))
#  exists x (novehiclethat(x) and car(x))
#  forall x (everyvehicle(x) implies airplane(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Rockets are in no way considered vehicles. Every single rocket functions as a scavenger. A portion of scavengers exists that are not vehicles. forall x (rocket(x) implies innowayconsideredvehicle(x))
#  forall x (singlerocketfunctionasascavenger(x))
#  exists x (scavengerexistthat(x) and notvehicle(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  There are some capitals that are polluted. All capitals are, by definition, cities. One must conclude that some cities are polluted. exists x (capitalthat(x) and polluted(x))
#  forall x (capital(x) implies bydefinitioncitie(x))
#  forall x (onemustconcludethatsomecitie(x) implies polluted(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  It is a fact that every single dog is a mammal. Likewise, it is true that all poodles are mammals. Therefore, it has been asserted that every poodle is a dog. forall x (singledog(x) implies mammallikewiseittruethatallpoodlemammalthereforeithasbeenassertedthateverypoodleadog(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  It is the case that no creature that is a mammal is a fish. There exists at least one creature that is a mammal and also a dolphin. This proves that at least one dolphin is not a fish. forall x (it(x) implies casethatnocreaturethatamammalafish(x))
#  forall x (thereexistatleastonecreaturethat(x) implies mammalandalsoadolphin(x))
#  forall x (thiprovethatatleastonedolphin(x) implies notafish(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Every single dog is an animal. Everything that is an animal is a mammal. It must therefore be true that every mammal is an animal. forall x (singledog(x) implies animal(x))
#  forall x (everythingthat(x) implies animalamammal(x))
#  forall x (itmust(x))
#  forall x (betruethateverymammal(x) implies animal(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Arrangements cannot be formations. A subset of vases exists that are not formations. Therefore, all things classified as arrangements are vases. forall x (arrangementcannotbeformation(x))
#  exists x (vaseexistthat(x) and notformation(x))
#  forall x (allthingclassifiedasarrangement(x) implies vase(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Anything which is an ocean is a desert. There are no Atlantic Oceans that are not oceans. There exists at least one Atlantic Ocean that is a desert. forall x (anythingwhich(x) implies oceanadesert(x))
#  exists x (noatlanticoceanthat(x) and notocean(x))
#  forall x (thereexistatleastoneatlanticoceanthat(x) implies desert(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  There are no squares which are round. There are no circles which are squares. It follows, then, that some circles are square. exists x (nosquarewhich(x) and round(x))
#  exists x (nocirclewhich(x) and square(x))
#  forall x (thenthatsomecircle(x) implies square(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  It is not the case that every human is a male. Every single human is a creature with ten legs. From this, it follows that some creatures with ten legs are males. forall x (it(x) implies notthecasethateveryhumanamale(x))
#  forall x (singlehuman(x) implies creaturewithtenleg(x))
#  forall x (fromth(x) implies thing(x))
#  exists x (creaturewithtenleg(x) and male(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  There are no chairs that can be considered musical instruments. Certain chairs exist that are also antiques. The conclusion that a portion of antiques are not musical instruments is inescapable. exists x (nochairthat(x) and musicalinstrument(x))
#  exists x (chairexistthat(x) and alsoantique(x))
#  forall x (conclusionthataportionofantique(x) implies notmusicalinstrumentinescapable(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Any golden retriever is a mammal. It is the case that some golden retrievers are dogs. This means that a few dogs are mammals. forall x (goldenretriever(x) implies mammal(x))
#  forall x (it(x) implies casethatsomegoldenretrieverdog(x))
#  forall x (thimeanthatafewdog(x) implies mammal(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  It is a fact that every tulip is a flower. It is also true that all roses are flowers. Therefore, it is concluded that a few flowers are roses. forall x (tulip(x) implies floweritalsotruethatallroseflowerthereforeitconcludedthatafewflowerrose(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  No giant balls of gas are stars. Suns are, without exception, giant balls of gas. No star can be considered a sun. forall x (giant(x) implies not ballofgasstar(x))
#  forall x (sun(x) implies withoutexceptiongiantballofgas(x))
#  forall x (star(x) implies not consideredasun(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Every poodle is a dog. No cat is a poodle. Therefore, no cat is a dog. forall x (poodle(x) implies dog(x))
#  forall x (cat(x) implies not poodle(x))
#  forall x (nocat(x) implies dog(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  There is no table that is a desk. No desks are chairs whatsoever. Therefore, we can conclude that no chair is a table. forall x (there(x) implies notablethatadesk(x))
#  forall x (desk(x) implies not chairwhatsoever(x))
#  forall x (wecanconcludethatnochair(x) implies table(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Some aquatic animals can be considered fish. Not a single human is an aquatic animal. As a result, no human is a fish. exists x (aquaticanimal(x) and fish(x))
#  forall x (human(x) implies not aquaticanimal(x))
#  forall x (nohuman(x) implies fish(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Each and every kitchen is a room. Each and every kitchen is a place for cooking. This implies that some places for cooking are rooms. forall x (kitchen(x) implies room(x))
#  forall x (kitchen(x) implies placeforcooking(x))
#  forall x (thiimpliethatsomeplaceforcooking(x) implies room(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  There are no objects that are furniture. Each and every table is an object. It follows that no table can be an item of furniture. exists x (noobjectthat(x) and furniture(x))
#  forall x (table(x) implies object(x))
#  forall x (table(x) implies not itemoffurniture(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Every single country has a capital city. The entity known as France is a country. There is at least some part of France that has a capital city. forall x (singlecountryhasacapitalcity(x))
#  forall x (entityknownasfrance(x) implies country(x))
#  forall x (there(x) implies atleastsomepartoffrancethathasacapitalcity(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  It is true that all fish live in water. No birds are fish. Therefore, no bird lives in water. forall x (fishliveinwaternobird(x) implies fishthereforenobirdliveinwater(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  It is not true that any dog is an animal. Nothing that is a mammal is a dog. This leads to the conclusion that no mammal is an animal. forall x (it(x) implies nottruethatanydogananimal(x))
#  forall x (nothingthat(x) implies mammaladog(x))
#  forall x (thileadtotheconclusionthatnomammal(x) implies animal(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  It is a fact that all birds can fly. There are some animals which are birds. Therefore, every single animal can fly. forall x (birdcanflythere(x) implies animalwhichbirdthereforeeverysingleanimalcanfly(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  There are some researchers who are also academics. A person who is an academic is also part of the university faculty. Therefore, some university faculty are researchers. exists x (researcherwho(x) and alsoacademic(x))
#  forall x (personwho(x) implies academicalsopartoftheuniversityfaculty(x))
#  forall x (someuniversityfaculty(x) implies researcher(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  A car is never an airplane. It is also the case that no boat is an airplane. Consequently, all boats are cars. forall x (car(x) implies neveranairplane(x))
#  forall x (it(x) implies alsothecasethatnoboatanairplane(x))
#  forall x (allboat(x) implies car(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Every single feline is a mammal. Anything that is a cat is a feline. At least one cat is a mammal. forall x (singlefeline(x) implies mammal(x))
#  forall x (anythingthat(x) implies catafeline(x))
#  forall x (atleastonecat(x) implies mammal(x))
#
# true label:
#  True
# predicted label:
#  False
# syllogism:
#  Every single creature that lives in water is a high-speed projectile. All groups involved in manufacturing are aquatic creatures. It logically follows that all entities that manufacture things are high-speed projectiles. forall x (singlecreaturethatliveinwater(x) implies highspeedprojectile(x))
#  forall x (groupinvolvedinmanufacturing(x) implies aquaticcreature(x))
#  forall x (entitiethatmanufacturething(x) implies highspeedprojectile(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  There are some animals that are not mammals. Everything that is a dog is a mammal. Thus, every dog is an animal. exists x (animalthat(x) and notmammal(x))
#  forall x (everythingthat(x) implies dogamammal(x))
#  forall x (everydog(x) implies animal(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  There are certain leaders who are politicians. All of those who are politicians are also human beings. Hence, a group of human beings are leaders. exists x (leaderwho(x) and politician(x))
#  forall x (ofthosewho(x) implies politicianalsohumanbeing(x))
#  forall x (henceagroupofhumanbeing(x) implies leader(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Every single thing that is a dog is a mammal. Every mammal is an animal. From this, it follows that some animals are indeed dogs. forall x (singlethingthat(x) implies dogamammal(x))
#  forall x (mammal(x) implies animal(x))
#  forall x (fromth(x) implies thing(x))
#  exists x (animal(x) and indeeddog(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  There exist vegetables that grow. Every single vegetable is a plant. It follows that not a single plant is a vegetable. forall x (thereex(x) implies tvegetablethatgrow(x))
#  forall x (singlevegetable(x) implies plant(x))
#  forall x (plant(x) implies not vegetable(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Every doctor is a professional. The set of children does not contain professionals. At least one child is not a doctor. forall x (doctor(x) implies professional(x))
#  forall x (setofchildrendoenotcontainprofessional(x))
#  forall x (atleastonechild(x) implies notadoctor(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Every object that is a car has an engine. Some motorized vehicles are cars. Therefore, all motorized vehicles have engines. forall x (objectthat(x) implies carhasanengine(x))
#  exists x (motorizedvehicle(x) and car(x))
#  forall x (allmotorizedvehicle(x) implies engine(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Everything that is a chair is furniture. Every single table is furniture. It follows from this that some tables are chairs. forall x (everythingthat(x) implies chairfurniture(x))
#  forall x (singletable(x) implies furniture(x))
#  forall x (fromthithatsometable(x) implies chair(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Any celestial body which is a planet is a cube. A portion of celestial bodies are planets. Consequently, some celestial bodies are cubes. forall x (celestialbodywhich(x) implies planetacube(x))
#  exists x (celestialbodie(x) and planet(x))
#  forall x (somecelestialbodie(x) implies cube(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  There are no dogs who are cats. A few dogs are pets. This implies that some pets are cats. exists x (nodogwho(x) and cat(x))
#  forall x (fewdog(x) implies pet(x))
#  forall x (thiimpliethatsomepet(x) implies cat(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Every sparrow is a type of animal. Some sparrows can be described as birds. Therefore, a certain number of birds are animals. forall x (sparrow(x) implies typeofanimal(x))
#  forall x (sparrowcanbedescribedasbird(x))
#  forall x (acertainnumberofbird(x) implies animal(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  The category of fish is a subset of the category of animals. All animals that are dogs are also animals. Nothing that is a dog is a fish. forall x (categoryoffish(x) implies subsetofthecategoryofanimal(x))
#  forall x (animalthat(x) implies dogalsoanimal(x))
#  forall x (nothingthat(x) implies dogafish(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Everything that is a human is also a primate. Everything that is a human is also a bipedal animal. Consequently, some bipedal animals are primates. forall x (everythingthat(x) implies humanalsoaprimate(x))
#  forall x (everythingthat(x) implies humanalsoabipedalanimal(x))
#  forall x (somebipedalanimal(x) implies primate(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Some things that are potatoes are not living things. Every single thing that is a potato is a human. A logical consequence of this is that some humans are not living things. exists x (thingthat(x) and potatoenotlivingthing(x))
#  forall x (singlethingthat(x) implies potatoahuman(x))
#  forall x (logicalconsequenceofthi(x) implies thatsomehumannotlivingthing(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Not a single mammal is an object that can think. The entire group of objects that can think is a subset of people. It is a logical consequence that some people are not mammals. forall x (mammal(x) implies not objectthatcanthink(x))
#  forall x (entiregroupofobjectthatcanthink(x) implies subsetofpeople(x))
#  forall x (it(x) implies logicalconsequencethatsomepeoplenotmammal(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Every single writing tool is a pencil. No pen is a pencil. This means no pen is a writing tool. forall x (singlewritingtool(x) implies pencil(x))
#  forall x (pen(x) implies not pencil(x))
#  forall x (thimeannopen(x) implies writingtool(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Some fruits are bicycles. Every bicycle is a vehicle. Therefore, some vehicles are fruits. exists x (fruit(x) and bicycle(x))
#  forall x (bicycle(x) implies vehicle(x))
#  forall x (somevehicle(x) implies fruit(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Anything that is a bicycle is a vehicle. It is known that no trucks are bicycles. This leads to the conclusion that no truck is a vehicle. forall x (anythingthat(x) implies bicycleavehicle(x))
#  forall x (it(x) implies knownthatnotruckbicycle(x))
#  forall x (thileadtotheconclusionthatnotruck(x) implies vehicle(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Everything that is a vehicle is a magical item. A portion of vehicles are cars. It necessarily follows that some cars are magical items. forall x (everythingthat(x) implies vehicleamagicalitem(x))
#  exists x (vehicle(x) and car(x))
#  forall x (itnecessarilyfollowthatsomecar(x) implies magicalitem(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Anything that is a animal is an idea. There are no ideas that are dogs. This necessarily suggests that some dogs are not animals. forall x (anythingthat(x) implies animalanidea(x))
#  exists x (noideathat(x) and dog(x))
#  forall x (thinecessarilysuggestthatsomedog(x) implies notanimal(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Anything that is a mammal is warm-blooded. Every single dog is a mammal. At least one dog is warm-blooded. forall x (anythingthat(x) implies mammalwarmblooded(x))
#  forall x (singledog(x) implies mammal(x))
#  forall x (atleastonedog(x) implies warmblooded(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Anything that is an elephant is a mammal. Every whale is also a mammal. From this, it is concluded that no whale is an elephant. forall x (anythingthat(x) implies elephantamammal(x))
#  forall x (whale(x) implies alsoamammal(x))
#  forall x (fromthiit(x) implies concludedthatnowhaleanelephant(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  All of the things that are robins are birds. There are no birds whatsoever that are fish. It logically follows that no fish are robins. forall x (ofthethingthat(x) implies robinbird(x))
#  exists x (nobirdwhatsoeverthat(x) and fish(x))
#  forall x (fish(x) implies not robin(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Every bird is a fish. There are no fish which are sparrows. This necessarily suggests that some sparrows are not birds. forall x (bird(x) implies fish(x))
#  exists x (nofishwhich(x) and sparrow(x))
#  forall x (thinecessarilysuggestthatsomesparrow(x) implies notbird(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Anything that can be called a musician is also an artist. A portion of artists are painters. A certain portion of painters are not musicians. forall x (anythingthatcanbecalledamusician(x) implies alsoanartist(x))
#  exists x (artist(x) and painter(x))
#  forall x (certainportionofpainter(x) implies notmusician(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  It is the case that no cars are bicycles. Every single thing that is a Ferrari is a car. Therefore, some Ferraris are not bicycles. forall x (it(x) implies casethatnocarbicycle(x))
#  forall x (singlethingthat(x) implies ferrariacar(x))
#  forall x (someferrari(x) implies notbicycle(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  It is not the case that animals are non-birds. Of the items that are hummingbirds, some are non-birds. It must be the case that every single hummingbird is not an animal. forall x (it(x) implies notthecasethatanimalnonbird(x))
#  forall x (oftheitemthat(x) implies hummingbirdsomenonbird(x))
#  forall x (itmustbethecasethateverysinglehummingbird(x) implies notananimal(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  There are some celestial bodies that are stars. There are some planets which are celestial bodies. Planets are in no way stars. exists x (celestialbodiethat(x) and star(x))
#  exists x (planetwhich(x) and celestialbodie(x))
#  forall x (planet(x) implies innowaystar(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Drums are completely separate from trumpets. A trumpet is, without exception, a musical instrument. Some musical instruments cannot be classified as drums. forall x (drum(x) implies completelyseparatefromtrumpet(x))
#  forall x (trumpet(x) implies withoutexceptionamusicalinstrument(x))
#  forall x (musicalinstrumentcannotbeclassifiedasdrum(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  The group of professionals is a subset of the group of people. Everything that is a doctor is a professional. Therefore, there are some people who are not doctors. forall x (groupofprofessional(x) implies subsetofthegroupofpeople(x))
#  forall x (everythingthat(x) implies doctoraprofessional(x))
#  forall x (there(x) implies peoplewhonotdoctor(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  There are no animals that are also plants. At least one tree is a plant. At least one tree is not an animal. exists x (noanimalthat(x) and alsoplant(x))
#  forall x (atleastonetree(x) implies plant(x))
#  forall x (atleastonetree(x) implies notananimal(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  There are no fiction books that are not non-fiction. Anything that is a novel is a fiction book. Therefore, some novels are non-fiction. exists x (nofictionbookthat(x) and notnonfiction(x))
#  forall x (anythingthat(x) implies novelafictionbook(x))
#  forall x (somenovel(x) implies nonfiction(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  There exist no machines that are also humans. Anything that can be called a student is, without exception, a human. No students are machines. exists x (nomachinethat(x) and alsohuman(x))
#  forall x (anythingthatcanbecalledastudent(x) implies withoutexceptionahuman(x))
#  forall x (student(x) implies not machine(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  It is true that anything that is an apple is an edible thing. Every apple is a fruit. It follows that some fruits are edible things. forall x (anythingthat(x) implies appleanediblethingeveryappleafruititfollowthatsomefruitediblething(x))
#
# true label:
#  False
# predicted label:
#  True
# syllogism:
#  There are some creatures that are animals and not vertebrates. All cats are also vertebrates. This leads to the conclusion that there are some cats which are animals. exists x (creaturethat(x) and animalandnotvertebrate(x))
#  forall x (cat(x) implies alsovertebrate(x))
#  forall x (thileadtotheconclusionthatthere(x) implies catwhichanimal(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  There are some animals that are sparrows. All things that are sparrows are birds. Consequently, every single thing that is a bird is an animal. exists x (animalthat(x) and sparrow(x))
#  forall x (thingthat(x) implies sparrowbird(x))
#  forall x (everysinglethingthat(x) implies birdananimal(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Every single integer is divisible by two. All integers are even numbers. It follows from this that some even numbers are not divisible by two. forall x (singleinteger(x) implies divisiblebytwo(x))
#  forall x (integer(x) implies evennumber(x))
#  forall x (fromthithatsomeevennumber(x) implies notdivisiblebytwo(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Nothing that is a pet animal is also a feline. Some cats happen to be pet animals. This leads to the conclusion that a certain number of cats are not felines. forall x (nothingthat(x) implies petanimalalsoafeline(x))
#  forall x (cathappentobepetanimal(x))
#  forall x (thileadtotheconclusionthatacertainnumberofcat(x) implies notfeline(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  Any and all reptiles are lizards. There are reptiles that are mammals. It must follow that all mammals are lizards. forall x (andallreptile(x) implies lizard(x))
#  exists x (reptilethat(x) and mammal(x))
#  forall x (itmustfollowthatallmammal(x) implies lizard(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Dogs are never cats. Some domestic animals are indeed felines. Therefore, a portion of domestic animals is not dogs. forall x (dog(x) implies nevercat(x))
#  exists x (domesticanimal(x) and indeedfeline(x))
#  forall x (aportionofdomesticanimal(x) implies notdog(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  There are no birds which are cats. There are no dogs that are birds. It follows, then, that some dogs are cats. exists x (nobirdwhich(x) and cat(x))
#  exists x (nodogthat(x) and bird(x))
#  forall x (thenthatsomedog(x) implies cat(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  There are no dogs that are reptiles. Everything that is a fish is a dog. Thus, every fish is a reptile. exists x (nodogthat(x) and reptile(x))
#  forall x (everythingthat(x) implies fishadog(x))
#  forall x (everyfish(x) implies reptile(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Every item that is a mammal is an animal. Some lions are mammals. Therefore, all lions can be said to be animals. forall x (itemthat(x) implies mammalananimal(x))
#  exists x (lion(x) and mammal(x))
#  forall x (alllioncanbesaidtobeanimal(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Every single cat is an animal. Anything that can be called a dog is, without exception, an animal. Every dog is a cat. forall x (singlecat(x) implies animal(x))
#  forall x (anythingthatcanbecalledadog(x) implies withoutexceptionananimal(x))
#  forall x (dog(x) implies cat(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  There exist cats that are also mammals. A subset of dogs can be classified as mammals. It follows that at least some dogs are not cats. exists x (catthat(x) and alsomammal(x))
#  forall x (subsetofdogcanbeclassifiedasmammal(x))
#  forall x (atleastsomedog(x) implies notcat(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  Humans are in no way animals. Anything that is a human is a mammal. There are some mammals which are not animals. forall x (human(x) implies innowayanimal(x))
#  forall x (anythingthat(x) implies humanamammal(x))
#  exists x (mammalwhich(x) and notanimal(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  It is the case that every fish lives in a tree. There exist some sea basses which do not live in trees. It necessarily follows that some sea basses are not fish. forall x (it(x) implies casethateveryfishliveinatree(x))
#  exists x (thereex(x) and not tsomeseabassewhichdonotliveintree(x))
#  forall x (itnecessarilyfollowthatsomeseabasse(x) implies notfish(x))
#
# true label:
#  True
# predicted label:
#  True
# syllogism:
#  There are some dogs that are cats. There are no cats that are reptiles. As a result, some reptiles are dogs. exists x (dogthat(x) and cat(x))
#  exists x (nocatthat(x) and reptile(x))
#  forall x (somereptile(x) implies dog(x))
#
# true label:
#  False
# predicted label:
#  False
# syllogism:
#  There are some individuals who find pleasure in reading who are librarians. Every single person who is a librarian is a student. It is the case that some of the people who are students are people who enjoy reading. exists x (individualwhofindpleasureinreadingwho(x) and librarian(x))
#  forall x (singlepersonwho(x) implies librarianastudent(x))
#  forall x (it(x) implies casethatsomeofthepeoplewhostudentpeoplewhoenjoyreading(x))
#
# true label:
#  True
# predicted label:
#  True
# Accuracy: 0.9519230769230769
# Precision: 0.9520902700702922
# Recall: 0.9519230769230769
# F1: 0.951918631530282
# Classification Report:               precision    recall  f1-score   support
#
#        False       0.94      0.96      0.95        52
#         True       0.96      0.94      0.95        52
#
#     accuracy                           0.95       104
#    macro avg       0.95      0.95      0.95       104
# weighted avg       0.95      0.95      0.95       104
